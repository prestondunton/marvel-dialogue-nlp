# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Script to CSV Process
#
# 1. Load script `.txt` file.  Use [PDF Extractor](https://pdfextractor.com/) to convert any `.pdf`s to `.txt`s.
# 2. Remove garbage rows
# 3. Inspect rows removed
# 4. Format lines
# 5. Create `uppercase_unique_form.csv`
# 6. Manually fill out `uppercase_unique_form.csv` columns `is_character_name` and `is_dialogue` in Excel or other `.csv` editor.
# 7. Load `uppercase_unique.csv` and filter out rows
# 8. Inspect rows removed
# 9. Merge lines into best guesses for columns "character" and "line"
# 10. Manually clean the "line" column by removing text that is not dialogue.  There will be a lot, so nearly every cell will have to be cleaned!
#
#
# See the Avengers Endgame script at the end of this notebook for an example of this process.

# %% [markdown]
# ## Remove Garbage Rows

# %%
def remove_whitespace_rows(df):
    whitespace_rows = df["line"].str.isspace()
    print(whitespace_rows.sum(),"whitespace rows removed")
    return df[~whitespace_rows], df[whitespace_rows]

def remove_int_ext_rows(df):
    int_rows = df["line"].str.contains("^INT\.",case=True)
    ext_rows = df["line"].str.contains("^EXT\.",case=True)
    
    print(int_rows.sum(),"INT. rows removed")
    print(ext_rows.sum(),"EXT. rows removed")
    
    removed_rows = int_rows | ext_rows
    
    return df[~removed_rows], df[removed_rows]

def remove_movie_text_rows(df):
    time_cut_rows = df["line"].str.contains("TIME CUT:",case=True)
    intercut_rows = df["line"].str.contains("INTERCUT:",case=True)
    title_rows = df["line"].str.contains("TITLE:",case=True)
    marvel_rows = df["line"].str.contains("MARVEL FLIP",case=True)
    cut_to_rows = df["line"].str.contains("CUT TO",case=True)
    slam_to_rows = df["line"].str.contains("SLAM TO",case=True)
    dissolve_to_rows = df["line"].str.contains("DISSOLVE TO",case=True)
    the_end_rows = df["line"].str.contains("^THE END",case=True)
    screenplay_rows = df["line"].str.contains("BEST ADAPTED SCREENPLAY",case=True)
    fade_to_black_rows = df["line"].str.contains("FADE TO BLACK",case=True)
    cue_music_rows = df["line"].str.contains("CUE MUSIC",case=True)
    
    print(time_cut_rows.sum(),"TIME CUT rows removed")
    print(intercut_rows.sum(),"INTERCUT rows removed")
    print(title_rows.sum(),"TITILE rows removed")
    print(marvel_rows.sum(),"MARVEL FLIP rows removed")
    print(cut_to_rows.sum(),"CUT TO rows removed")
    print(slam_to_rows.sum(),"SLAM TO rows removed")
    print(dissolve_to_rows.sum(),"DISSOLVE TO rows removed")
    print(the_end_rows.sum(),"THE END rows removed")
    print(screenplay_rows.sum(),"BEST ADAPTED SCREENPLAY rows removed")
    print(fade_to_black_rows.sum(),"FADE TO BLACK rows removed")
    print(cue_music_rows.sum(),"CUE MUSIC rows removed")
    
    removed_rows = time_cut_rows | title_rows | marvel_rows | cut_to_rows | \
              slam_to_rows | dissolve_to_rows | the_end_rows | intercut_rows | \
            screenplay_rows | fade_to_black_rows | cue_music_rows
    
    return df[~removed_rows], df[removed_rows]


def remove_page_number_rows(df):
    page_rows = df["line"].str.isnumeric()
    print(page_rows.sum(),"page number rows removed")
    
    return df[~page_rows], df[page_rows]

def remove_garbage_rows(df):
    df, int_ext_rows = remove_int_ext_rows(df)
    df, whitespace_rows = remove_whitespace_rows(df)
    df, page_number_rows = remove_page_number_rows(df)
    df, movie_text_rows = remove_movie_text_rows(df)
    
    garbage_rows = pd.concat([int_ext_rows, whitespace_rows, page_number_rows, movie_text_rows], 
                            keys = ["int_ext","whitespace","page_numbers","movie_text"])
    
    print("-----------------------------------------")
    print(garbage_rows.shape[0],"total rows removed\n")
    
    return df, garbage_rows

# %% [markdown]
# ## Format Character Lines

# %%
def remove_cont_os(df):
    result = df
    result["line"] = result["line"].str.replace("(CONT'D)","",case=True,regex=False)
    result["line"] = result["line"].str.replace("(O.S.)","",case=True,regex=False)
    result["line"] = result["line"].str.replace("(O.S)","",case=True,regex=False)
    result["line"] = result["line"].str.replace("(ON SCREEN)","",case=True,regex=False)
    return result

def remove_coms_holo(df):
    result = df
    result["line"] = result["line"].str.replace("(OVER COM)","",case=True,regex=False)
    result["line"] = result["line"].str.replace("(ON COM)","",case=True,regex=False)
    result["line"] = result["line"].str.replace("(INTO COM)","",case=True,regex=False)
    result["line"] = result["line"].str.replace("(OVER SPEAKER)","",case=True,regex=False)
    result["line"] = result["line"].str.replace("(INTO PHONE)","",case=True,regex=False)
    result["line"] = result["line"].str.replace("(OVER PHONE)","",case=True,regex=False)
    result["line"] = result["line"].str.replace("(HOLO)","",case=True,regex=False)
    return result

def remove_leading_trailing_whitespace(df):
    result = df
    result["line"] = result["line"].str.replace("[ \t]+$","")
    result["line"] = result["line"].str.replace("^[ \t]+","")
    return result

def format_lines(df):

    df = remove_leading_trailing_whitespace(df)
    df = remove_cont_os(df)
    df = remove_coms_holo(df)
    df = remove_leading_trailing_whitespace(df)
    
    return df

# %% [markdown]
# ## Remove Non Dialogue Uppercase Rows

# %%
def uppercase_rows(df):
    upper_lines = df["line"].str.isupper()
    
    #sentences = df["line"].str.split(" ").str.len() >= min_number_words
    
    return df[upper_lines]

def create_uppercase_unique_csv(df,script_name):
    '''
    Creates a csv file that is used for inspection of unique
    lines that are all uppercase.  These lines are manually labeled
    to be character names or dialogue.  The resulting table will be
    used to delete rows that are neither character names nor dialogue.
    '''
    
    upper_rows = uppercase_rows(df)
    unique_upper_rows = pd.DataFrame(upper_rows.line.unique())

    unique_upper_rows["words"] = unique_upper_rows[0].str.split(" ").str.len()
    unique_upper_rows["is_character_name"] = 0
    unique_upper_rows["is_dialogue"] = 0
    sorted_unique_upper_rows = unique_upper_rows.sort_values(by=["words"])
    sorted_unique_upper_rows.to_csv("./data/uppercase forms/" + script_name + "_uppercase_unique_form.csv",encoding='utf-8')
    
def remove_non_dialogue_upper_rows(df,upper_rows):
    '''
    Removes lines that are in all caps, and that are not dialogue or a character's name.
    '''
    unique_character_names = upper_rows[upper_rows["is_character_name"]]["line"]
    unique_dialogues = upper_rows[upper_rows["is_dialogue"]]["line"]
    
    all_character_name_lines = df[df["line"].isin(unique_character_names)]
    all_dialogue_lines = df[df["line"].isin(unique_dialogues)]
    
    print(df["line"].str.isupper().sum(),"total uppercase lines")
    print(all_character_name_lines.shape[0],"uppercase character name lines")
    print(all_dialogue_lines.shape[0],"uppercase dialogue lines")
    
    unique_lines_to_remove = upper_rows[~(upper_rows["is_character_name"]|upper_rows["is_dialogue"])]["line"]
    removed_lines = df["line"].isin(unique_lines_to_remove)
    print(removed_lines.sum(),"uppercase lines removed")
    
    return df[~removed_lines], df[removed_lines]

# %% [markdown]
# ## Merge Lines

# %%
def is_character_name(string,character_names):
    return string in character_names["line"].tolist()
    

def merge_lines(df,character_names):
    '''
    Starts at a character name and merges all lines until the next character's name.
    The result should be the best guess at columns "character" and "line".
    This will merge in some screenplay text that is not dialogue, so the result will 
    have to be manually cleaned as the final step.
    '''
    merged_df = pd.DataFrame(columns=["character","line"])
    
    for i in range(0,df.shape[0]):
        
        row = df.iloc[i]
        
        if is_character_name(row["line"],character_names):
            character = row["line"]
            line = ""
            
            j = i + 1
            while(j < len(df) and (not is_character_name(df.iloc[j]["line"],character_names))):
                line += df.iloc[j]["line"] + " "
                j += 1
            
            new_row = {"character": character,"line": line}
            
            merged_df = merged_df.append(new_row,ignore_index=True)
    
    return merged_df

# %% [markdown]
# ## Avengers Endgame

# %%
avengers_endgame = pd.read_csv("./data/script txts/avengers-endgame-script-slug.txt",sep="\n",header=None,names=["line"])

avengers_endgame, garbage_rows = remove_garbage_rows(avengers_endgame)
avengers_endgame = format_lines(avengers_endgame)


create_uppercase_unique_csv(avengers_endgame,"avengers_endgame")
filled_out_upper_rows = pd.read_csv("./data/uppercase results/avengers_endgame_uppercase_unique.csv",
                                    names=["","line","words","is_character_name","is_dialogue"],
                                    dtype={"line":str, "words":int, "is_character_name":bool, "is_dialogue":bool},
                                    index_col=0)

avengers_endgame, upper_removed_rows = remove_non_dialogue_upper_rows(avengers_endgame, filled_out_upper_rows)
removed_rows = pd.concat([garbage_rows,pd.concat([upper_removed_rows],keys=[""])],keys=["garbage","uppercase"])


unique_character_names = pd.DataFrame(filled_out_upper_rows[filled_out_upper_rows["is_character_name"]]["line"])

avengers_endgame = merge_lines(avengers_endgame, unique_character_names)

avengers_endgame.reindex(copy=False)

avengers_endgame.to_csv("./data/uncleaned/avengers_endgame_uncleaned.csv", index=False)

avengers_endgame = pd.read_csv("./data/cleaned/avengers_endgame.csv")

avengers_endgame
# Out:
# 95 INT. rows removed
# 75 EXT. rows removed
# 149 whitespace rows removed
# 290 page number rows removed
# 11 TIME CUT rows removed
# 2 INTERCUT rows removed
# 8 TITILE rows removed
# 1 MARVEL FLIP rows removed
# 1 CUT TO rows removed
# 1 SLAM TO rows removed
# 4 DISSOLVE TO rows removed
# 1 THE END rows removed
# 1 BEST ADAPTED SCREENPLAY rows removed
# 2 FADE TO BLACK rows removed
# 2 CUE MUSIC rows removed
# -----------------------------------------
# 643 total rows removed
#
# 1772 total uppercase lines
# 1238 uppercase character name lines
# 21 uppercase dialogue lines
# 513 uppercase lines removed
#                 character  \
# 0            CLINT BARTON
# 1            CLINT BARTON
# 2             LILA BARTON
# 3            CLINT BARTON
# 4            LAURA BARTON
# 5             LILA BARTON
# 6            CLINT BARTON
# 7            CLINT BARTON
# 8            LAURA BARTON
# 9            CLINT BARTON
# 10           CLINT BARTON
# 11           CLINT BARTON
# 12           CLINT BARTON
# 13           CLINT BARTON
# 14                   TONY
# 15                 NEBULA
# 16                   TONY
# 17                   TONY
# 18                   TONY
# 19                   TONY
# 20                   TONY
# 21                   TONY
# 22                   TONY
# 23                   TONY
# 24                   TONY
# 25                  STEVE
# 26                   TONY
# 27                  STEVE
# 28                   TONY
# 29           PEPPER POTTS
# 30                   TONY
# 31                 RHODEY
# 32                NATASHA
# 33                NATASHA
# 34          CAROL DANVERS
# 35                 RHODEY
# 36          CAROL DANVERS
# 37                   TONY
# 38                  STEVE
# 39                   TONY
# 40                 ROCKET
# 41                 ROCKET
# 42                   TONY
# 43                  STEVE
# 44                   TONY
# 45                  STEVE
# 46                   TONY
# 47                  STEVE
# 48                   TONY
# 49                   TONY
# 50                  STEVE
# 51                   TONY
# 52                 RHODEY
# 53                   TONY
# 54                 RHODEY
# 55          CAROL DANVERS
# 56                  STEVE
# 57          CAROL DANVERS
# 58                NATASHA
# 59          CAROL DANVERS
# 60          CAROL DANVERS
# 61                  STEVE
# 62                 RHODEY
# 63          CAROL DANVERS
# 64                 NEBULA
# 65                 NEBULA
# 66                 NEBULA
# 67                 RHODEY
# 68                  STEVE
# 69                 ROCKET
# 70                 ROCKET
# 71                NATASHA
# 72                 NEBULA
# 73                  STEVE
# 74           BRUCE BANNER
# 75           BRUCE BANNER
# 76                 RHODEY
# 77                 ROCKET
# 78                 RHODEY
# 79          CAROL DANVERS
# 80           BRUCE BANNER
# 81                  STEVE
# 82                NATASHA
# 83           BRUCE BANNER
# 84          CAROL DANVERS
# 85                 RHODEY
# 86          CAROL DANVERS
# 87                   THOR
# 88                  STEVE
# 89          CAROL DANVERS
# 90                 ROCKET
# 91                 ROCKET
# 92                 NEBULA
# 93          CAROL DANVERS
# 94                NATASHA
# 95                  STEVE
# 96          CAROL DANVERS
# 97                 NEBULA
# 98                  STEVE
# 99          CAROL DANVERS
# 100                THANOS
# 101          BRUCE BANNER
# 102                THANOS
# 103               NATASHA
# 104                THANOS
# 105          BRUCE BANNER
# 106                THANOS
# 107                ROCKET
# 108                RHODEY
# 109                NEBULA
# 110                THANOS
# 111                ROCKET
# 112                  THOR
# 113          GRIEVING MAN
# 114                 JIMMY
# 115          GRIEVING MAN
# 116                 STEVE
# 117          GRIEVING MAN
# 118             OLDER MAN
# 119          GRIEVING MAN
# 120                 STEVE
# 121                 STEVE
# 122            SCOTT LANG
# 123            SCOTT LANG
# 124            SCOTT LANG
# 125            SCOTT LANG
# 126           CASSIE LANG
# 127            SCOTT LANG
# 128           CASSIE LANG
# 129            SCOTT LANG
# 130                ROCKET
# 131               NATASHA
# 132                NEBULA
# 133                ROCKET
# 134         CAROL DANVERS
# 135                ROCKET
# 136               NATASHA
# 137                 OKOYE
# 138               NATASHA
# 139                 OKOYE
# 140                RHODEY
# 141               NATASHA
# 142         CAROL DANVERS
# 143                ROCKET
# 144         CAROL DANVERS
# 145               NATASHA
# 146               NATASHA
# 147                RHODEY
# 148               NATASHA
# 149                RHODEY
# 150               NATASHA
# 151                RHODEY
# 152                RHODEY
# 153                RHODEY
# 154               NATASHA
# 155                 STEVE
# 156               NATASHA
# 157                 STEVE
# 158               NATASHA
# 159                 STEVE
# 160               NATASHA
# 161                 STEVE
# 162               NATASHA
# 163                 STEVE
# 164               NATASHA
# 165                 STEVE
# 166               NATASHA
# 167                 STEVE
# 168               NATASHA
# 169                 STEVE
# 170               NATASHA
# 171                 STEVE
# 172               NATASHA
# 173               NATASHA
# 174                 STEVE
# 175               NATASHA
# 176            SCOTT LANG
# 177                 STEVE
# 178               NATASHA
# 179                 STEVE
# 180            SCOTT LANG
# 181            SCOTT LANG
# 182               NATASHA
# 183            SCOTT LANG
# 184               NATASHA
# 185            SCOTT LANG
# 186                 STEVE
# 187            SCOTT LANG
# 188            SCOTT LANG
# 189                 STEVE
# 190            SCOTT LANG
# 191               NATASHA
# 192            SCOTT LANG
# 193                  TONY
# 194          MORGAN STARK
# 195                  TONY
# 196                  TONY
# 197          MORGAN STARK
# 198                  TONY
# 199                  TONY
# 200               NATASHA
# 201                  TONY
# 202            SCOTT LANG
# 203                 STEVE
# 204                  TONY
# 205            SCOTT LANG
# 206                  TONY
# 207            SCOTT LANG
# 208                  TONY
# 209            SCOTT LANG
# 210                 STEVE
# 211               NATASHA
# 212                  TONY
# 213                 STEVE
# 214                  TONY
# 215            SCOTT LANG
# 216                  TONY
# 217            SCOTT LANG
# 218                  TONY
# 219               NATASHA
# 220                  TONY
# 221            SCOTT LANG
# 222                  TONY
# 223            SCOTT LANG
# 224                  TONY
# 225            SCOTT LANG
# 226                  TONY
# 227          MORGAN STARK
# 228                  TONY
# 229                 STEVE
# 230                  TONY
# 231               NATASHA
# 232                 STEVE
# 233            SCOTT LANG
# 234                 STEVE
# 235            SCOTT LANG
# 236            SCOTT LANG
# 237            SMART HULK
# 238            SCOTT LANG
# 239            SMART HULK
# 240            SCOTT LANG
# 241            SMART HULK
# 242                 STEVE
# 243            SMART HULK
# 244               NATASHA
# 245            SMART HULK
# 246            SMART HULK
# 247            SCOTT LANG
# 248            SMART HULK
# 249            SMART HULK
# 250                   KID
# 251            SMART HULK
# 252            SMART HULK
# 253                 STEVE
# 254            SMART HULK
# 255               NATASHA
# 256            SMART HULK
# 257                  TONY
# 258                FRIDAY
# 259                  TONY
# 260                FRIDAY
# 261                  TONY
# 262                FRIDAY
# 263                  TONY
# 264          MORGAN STARK
# 265                  TONY
# 266          MORGAN STARK
# 267                  TONY
# 268          MORGAN STARK
# 269                  TONY
# 270          MORGAN STARK
# 271                  TONY
# 272                  TONY
# 273          MORGAN STARK
# 274                  TONY
# 275          MORGAN STARK
# 276                  TONY
# 277          MORGAN STARK
# 278                  TONY
# 279                  TONY
# 280          PEPPER POTTS
# 281                  TONY
# 282          PEPPER POTTS
# 283                  TONY
# 284          PEPPER POTTS
# 285                  TONY
# 286          PEPPER POTTS
# 287                  TONY
# 288          PEPPER POTTS
# 289                  TONY
# 290          PEPPER POTTS
# 291                  TONY
# 292          PEPPER POTTS
# 293                  TONY
# 294          PEPPER POTTS
# 295                  TONY
# 296          PEPPER POTTS
# 297                  TONY
# 298          PEPPER POTTS
# 299            SCOTT LANG
# 300            SMART HULK
# 301            SCOTT LANG
# 302            SMART HULK
# 303            SCOTT LANG
# 304                 STEVE
# 305            SMART HULK
# 306            SCOTT LANG
# 307               NATASHA
# 308            SMART HULK
# 309               NATASHA
# 310            SMART HULK
# 311            SMART HULK
# 312            SCOTT LANG
# 313                 STEVE
# 314            SCOTT LANG
# 315            SMART HULK
# 316            SCOTT LANG
# 317               NATASHA
# 318            SMART HULK
# 319                 STEVE
# 320            SCOTT LANG
# 321               NATASHA
# 322            SMART HULK
# 323               NATASHA
# 324                 STEVE
# 325            SMART HULK
# 326                 STEVE
# 327            SMART HULK
# 328            SCOTT LANG
# 329                  TONY
# 330                 STEVE
# 331                  TONY
# 332                 STEVE
# 333                  TONY
# 334                  TONY
# 335                 STEVE
# 336                  TONY
# 337                 STEVE
# 338                  TONY
# 339                 STEVE
# 340                  TONY
# 341                 STEVE
# 342                  TONY
# 343                 STEVE
# 344                ROCKET
# 345            SCOTT LANG
# 346                NEBULA
# 347            SCOTT LANG
# 348                RHODEY
# 349                ROCKET
# 350            SMART HULK
# 351                ROCKET
# 352            SMART HULK
# 353                ROCKET
# 354            SMART HULK
# 355              VALKYRIE
# 356            SMART HULK
# 357              VALKYRIE
# 358            SMART HULK
# 359                ROCKET
# 360              VALKYRIE
# 361            SMART HULK
# 362              VALKYRIE
# 363                ROCKET
# 364              VALKYRIE
# 365            SMART HULK
# 366              VALKYRIE
# 367                ROCKET
# 368            SMART HULK
# 369                  THOR
# 370                  THOR
# 371            SMART HULK
# 372                  THOR
# 373                ROCKET
# 374                  THOR
# 375                  KORG
# 376            SMART HULK
# 377                  KORG
# 378                  THOR
# 379                  KORG
# 380                  THOR
# 381            SMART HULK
# 382                  THOR
# 383                ROCKET
# 384                  THOR
# 385            SMART HULK
# 386                  THOR
# 387            SMART HULK
# 388                  THOR
# 389                  KORG
# 390            SMART HULK
# 391            SMART HULK
# 392                  THOR
# 393                  THOR
# 394                  KORG
# 395                  THOR
# 396                ROCKET
# 397            SMART HULK
# 398                  THOR
# 399            SMART HULK
# 400                  THOR
# 401                ROCKET
# 402                  THOR
# 403            SMART HULK
# 404                  THOR
# 405            SMART HULK
# 406                ROCKET
# 407                  THOR
# 408               AKIHIKO
# 409                 RONIN
# 410                 RONIN
# 411               AKIHIKO
# 412               AKIHIKO
# 413                 RONIN
# 414          CLINT BARTON
# 415               NATASHA
# 416          CLINT BARTON
# 417               NATASHA
# 418               NATASHA
# 419          CLINT BARTON
# 420               NATASHA
# 421          CLINT BARTON
# 422               NATASHA
# 423                  TONY
# 424                  TONY
# 425                ROCKET
# 426                  TONY
# 427                ROCKET
# 428                  TONY
# 429                ROCKET
# 430                RHODEY
# 431            SCOTT LANG
# 432            SMART HULK
# 433            SCOTT LANG
# 434            SCOTT LANG
# 435            SCOTT LANG
# 436            SCOTT LANG
# 437          CLINT BARTON
# 438          CLINT BARTON
# 439            SMART HULK
# 440                RHODEY
# 441            SMART HULK
# 442            SCOTT LANG
# 443                NEBULA
# 444          CLINT BARTON
# 445            SMART HULK
# 446                RHODEY
# 447            SMART HULK
# 448                NEBULA
# 449                RHODEY
# 450            SCOTT LANG
# 451          CLINT BARTON
# 452            SMART HULK
# 453          CLINT BARTON
# 454           LILA BARTON
# 455               NATASHA
# 456                  TONY
# 457          CLINT BARTON
# 458                ROCKET
# 459                 STEVE
# 460                 STEVE
# 461                  TONY
# 462            SCOTT LANG
# 463            SMART HULK
# 464                  TONY
# 465          CLINT BARTON
# 466                 STEVE
# 467               NATASHA
# 468                RHODEY
# 469                  THOR
# 470                  THOR
# 471                ROCKET
# 472            SMART HULK
# 473                ROCKET
# 474            SCOTT LANG
# 475                ROCKET
# 476                ROCKET
# 477                NEBULA
# 478               NATASHA
# 479                NEBULA
# 480            SCOTT LANG
# 481               NATASHA
# 482            SMART HULK
# 483                  TONY
# 484            SMART HULK
# 485                  TONY
# 486            SMART HULK
# 487                  TONY
# 488               NATASHA
# 489            SMART HULK
# 490                 STEVE
# 491                 STEVE
# 492                 STEVE
# 493                 STEVE
# 494                 STEVE
# 495                ROCKET
# 496                  TONY
# 497            SMART HULK
# 498                ROCKET
# 499          CLINT BARTON
# 500                ROCKET
# 501               NATASHA
# 502            SMART HULK
# 503                  TONY
# 504                 STEVE
# 505                 STEVE
# 506            SMART HULK
# 507            SMART HULK
# 508           ANCIENT ONE
# 509           ANCIENT ONE
# 510            SMART HULK
# 511           ANCIENT ONE
# 512           ANCIENT ONE
# 513            SMART HULK
# 514           ANCIENT ONE
# 515            SMART HULK
# 516           ANCIENT ONE
# 517            SMART HULK
# 518           ANCIENT ONE
# 519            SMART HULK
# 520         ASTRAL BANNER
# 521           ANCIENT ONE
# 522                MAIDEN
# 523           JANE FOSTER
# 524                MAIDEN
# 525           JANE FOSTER
# 526                  THOR
# 527                ROCKET
# 528                  THOR
# 529                FRIGGA
# 530                ROCKET
# 531                  THOR
# 532                ROCKET
# 533                  THOR
# 534                ROCKET
# 535                ROCKET
# 536                  THOR
# 537                ROCKET
# 538                  THOR
# 539                ROCKET
# 540                  THOR
# 541                ROCKET
# 542                ROCKET
# 543                ROCKET
# 544                RHODEY
# 545          CLINT BARTON
# 546               NATASHA
# 547                RHODEY
# 548               NATASHA
# 549                RHODEY
# 550                NEBULA
# 551               NATASHA
# 552          CLINT BARTON
# 553               NATASHA
# 554                RHODEY
# 555                NEBULA
# 556                RHODEY
# 557                NEBULA
# 558                RHODEY
# 559                GAMORA
# 560            BAD NEBULA
# 561                GAMORA
# 562            BAD NEBULA
# 563                GAMORA
# 564            BAD NEBULA
# 565                GAMORA
# 566            BAD NEBULA
# 567                GAMORA
# 568            BAD NEBULA
# 569                GAMORA
# 570            BAD NEBULA
# 571                THANOS
# 572                GAMORA
# 573                THANOS
# 574            BAD NEBULA
# 575                THANOS
# 576            BAD NEBULA
# 577                GAMORA
# 578                RHODEY
# 579                NEBULA
# 580                GAMORA
# 581            BAD NEBULA
# 582                GAMORA
# 583                THANOS
# 584                THANOS
# 585                  LOKI
# 586                  TONY
# 587                 STEVE
# 588            SCOTT LANG
# 589            A1 NATASHA
# 590              A1 STEVE
# 591                  TONY
# 592                  TONY
# 593                 STEVE
# 594            A1 NATASHA
# 595       A1 CLINT BARTON
# 596          BROCK RUMLOW
# 597            SCOTT LANG
# 598                  TONY
# 599            SCOTT LANG
# 600                  TONY
# 601              A1 STEVE
# 602            LOKI/STEVE
# 603               A1 THOR
# 604               A1 THOR
# 605               A1 TONY
# 606                  TONY
# 607            SCOTT LANG
# 608               A1 HULK
# 609                  TONY
# 610                 STEVE
# 611                  TONY
# 612         AGENT SITWELL
# 613         AGENT SITWELL
# 614                 STEVE
# 615          BROCK RUMLOW
# 616                 STEVE
# 617                 STEVE
# 618         AGENT SITWELL
# 619                 STEVE
# 620          BROCK RUMLOW
# 621         AGENT SITWELL
# 622                 STEVE
# 623                 STEVE
# 624               A1 HULK
# 625                  TONY
# 626            SCOTT LANG
# 627            SCOTT LANG
# 628                  TONY
# 629            SCOTT LANG
# 630      ALEXANDER PIERCE
# 631               A1 THOR
# 632               A1 TONY
# 633      ALEXANDER PIERCE
# 634               A1 THOR
# 635      ALEXANDER PIERCE
# 636               A1 TONY
# 637      ALEXANDER PIERCE
# 638                  TONY
# 639            SCOTT LANG
# 640                  TONY
# 641            SCOTT LANG
# 642                  TONY
# 643            SCOTT LANG
# 644      ALEXANDER PIERCE
# 645      ALEXANDER PIERCE
# 646               A1 THOR
# 647                  TONY
# 648            SCOTT LANG
# 649               A1 THOR
# 650              SECURITY
# 651                 STEVE
# 652              A1 STEVE
# 653                 STEVE
# 654              A1 STEVE
# 655                 STEVE
# 656              A1 STEVE
# 657                 STEVE
# 658              A1 STEVE
# 659                 STEVE
# 660              A1 STEVE
# 661                 STEVE
# 662              A1 STEVE
# 663                 STEVE
# 664           ANCIENT ONE
# 665           ANCIENT ONE
# 666         ASTRAL BANNER
# 667           ANCIENT ONE
# 668         ASTRAL BANNER
# 669           ANCIENT ONE
# 670           ANCIENT ONE
# 671           ANCIENT ONE
# 672           ANCIENT ONE
# 673           ANCIENT ONE
# 674         ASTRAL BANNER
# 675         ASTRAL BANNER
# 676           ANCIENT ONE
# 677         ASTRAL BANNER
# 678           ANCIENT ONE
# 679           ANCIENT ONE
# 680         ASTRAL BANNER
# 681           ANCIENT ONE
# 682         ASTRAL BANNER
# 683           ANCIENT ONE
# 684         ASTRAL BANNER
# 685           ANCIENT ONE
# 686           ANCIENT ONE
# 687         ASTRAL BANNER
# 688           ANCIENT ONE
# 689            SMART HULK
# 690           ANCIENT ONE
# 691                THANOS
# 692             EBONY MAW
# 693                THANOS
# 694             EBONY MAW
# 695                THANOS
# 696             EBONY MAW
# 697                THANOS
# 698             EBONY MAW
# 699                THANOS
# 700            SMART HULK
# 701                  TONY
# 702          CLINT BARTON
# 703                 STEVE
# 704                THANOS
# 705                GAMORA
# 706                THANOS
# 707                THANOS
# 708                GAMORA
# 709                THANOS
# 710                FRIGGA
# 711                  THOR
# 712                FRIGGA
# 713                  THOR
# 714                FRIGGA
# 715                  THOR
# 716                FRIGGA
# 717                  THOR
# 718                FRIGGA
# 719                  THOR
# 720                FRIGGA
# 721                  THOR
# 722                FRIGGA
# 723                  THOR
# 724                FRIGGA
# 725                  THOR
# 726                FRIGGA
# 727                  THOR
# 728                FRIGGA
# 729                  THOR
# 730                FRIGGA
# 731                  THOR
# 732                FRIGGA
# 733                  THOR
# 734                FRIGGA
# 735                  THOR
# 736                ROCKET
# 737                  THOR
# 738                FRIGGA
# 739                  THOR
# 740                FRIGGA
# 741                ROCKET
# 742                  THOR
# 743                FRIGGA
# 744                ROCKET
# 745                  THOR
# 746                ROCKET
# 747                FRIGGA
# 748                  THOR
# 749                  THOR
# 750                FRIGGA
# 751                RHODEY
# 752                NEBULA
# 753                 QUILL
# 754                RHODEY
# 755                NEBULA
# 756                RHODEY
# 757                NEBULA
# 758                RHODEY
# 759                NEBULA
# 760                RHODEY
# 761                RHODEY
# 762                RHODEY
# 763                NEBULA
# 764                RHODEY
# 765                RHODEY
# 766                THANOS
# 767          BRUCE BANNER
# 768                THANOS
# 769               NATASHA
# 770                THANOS
# 771          BRUCE BANNER
# 772                THANOS
# 773                THANOS
# 774                THANOS
# 775                GAMORA
# 776                THANOS
# 777                THANOS
# 778                GAMORA
# 779                THANOS
# 780             EBONY MAW
# 781                THANOS
# 782                RHODEY
# 783                NEBULA
# 784                THANOS
# 785                THANOS
# 786             EBONY MAW
# 787            BAD NEBULA
# 788                THANOS
# 789                NEBULA
# 790                NEBULA
# 791                  TONY
# 792                 STEVE
# 793                  TONY
# 794            SCOTT LANG
# 795                  TONY
# 796            SCOTT LANG
# 797                  TONY
# 798                 STEVE
# 799                 STEVE
# 800            SCOTT LANG
# 801                 STEVE
# 802                  TONY
# 803                 STEVE
# 804                  TONY
# 805                 STEVE
# 806            SCOTT LANG
# 807                  TONY
# 808                 STEVE
# 809            SCOTT LANG
# 810                 STEVE
# 811                  TONY
# 812            SCOTT LANG
# 813                  TONY
# 814                 STEVE
# 815              STAN LEE
# 816                  TONY
# 817                 STEVE
# 818                  TONY
# 819                 STEVE
# 820                  TONY
# 821                 STEVE
# 822   FEMALE SHIELD AGENT
# 823                 STEVE
# 824                  TONY
# 825                  TONY
# 826          HOWARD STARK
# 827          HOWARD STARK
# 828                  TONY
# 829          HOWARD STARK
# 830                  TONY
# 831          HOWARD STARK
# 832                  TONY
# 833          HOWARD STARK
# 834                  TONY
# 835          HOWARD STARK
# 836                  TONY
# 837          HOWARD STARK
# 838              HANK PYM
# 839                 STEVE
# 840              HANK PYM
# 841                 STEVE
# 842              HANK PYM
# 843                 STEVE
# 844              HANK PYM
# 845                 STEVE
# 846              HANK PYM
# 847                  TONY
# 848          HOWARD STARK
# 849                  TONY
# 850          HOWARD STARK
# 851                  TONY
# 852          HOWARD STARK
# 853                  TONY
# 854          HOWARD STARK
# 855                  TONY
# 856          HOWARD STARK
# 857                  M.P.
# 858   FEMALE SHIELD AGENT
# 859                  M.P.
# 860   FEMALE SHIELD AGENT
# 861                  M.P.
# 862   FEMALE SHIELD AGENT
# 863                  M.P.
# 864          PEGGY CARTER
# 865            MALE AGENT
# 866          PEGGY CARTER
# 867            MALE AGENT
# 868          PEGGY CARTER
# 869          PEGGY CARTER
# 870            MALE AGENT
# 871          PEGGY CARTER
# 872                  TONY
# 873          HOWARD STARK
# 874                  TONY
# 875          HOWARD STARK
# 876                  TONY
# 877          HOWARD STARK
# 878                  TONY
# 879          HOWARD STARK
# 880                  TONY
# 881          HOWARD STARK
# 882                  TONY
# 883          HOWARD STARK
# 884                  TONY
# 885          HOWARD STARK
# 886                  TONY
# 887          HOWARD STARK
# 888          HOWARD STARK
# 889          EDWIN JARVIS
# 890          HOWARD STARK
# 891                  TONY
# 892          HOWARD STARK
# 893                  TONY
# 894          HOWARD STARK
# 895          EDWIN JARVIS
# 896          HOWARD STARK
# 897            BAD NEBULA
# 898                NEBULA
# 899            BAD NEBULA
# 900                NEBULA
# 901                NEBULA
# 902            BAD NEBULA
# 903            BAD NEBULA
# 904            BAD NEBULA
# 905          CLINT BARTON
# 906          CLINT BARTON
# 907               NATASHA
# 908          CLINT BARTON
# 909               NATASHA
# 910         HOODED FIGURE
# 911          CLINT BARTON
# 912         HOODED FIGURE
# 913          CLINT BARTON
# 914               NATASHA
# 915             RED SKULL
# 916               NATASHA
# 917             RED SKULL
# 918             RED SKULL
# 919               NATASHA
# 920             RED SKULL
# 921             RED SKULL
# 922          CLINT BARTON
# 923               NATASHA
# 924          CLINT BARTON
# 925               NATASHA
# 926               NATASHA
# 927          CLINT BARTON
# 928               NATASHA
# 929          CLINT BARTON
# 930               NATASHA
# 931          CLINT BARTON
# 932               NATASHA
# 933          CLINT BARTON
# 934               NATASHA
# 935          CLINT BARTON
# 936               NATASHA
# 937          CLINT BARTON
# 938               NATASHA
# 939          CLINT BARTON
# 940          CLINT BARTON
# 941               NATASHA
# 942          CLINT BARTON
# 943               NATASHA
# 944          CLINT BARTON
# 945               NATASHA
# 946          CLINT BARTON
# 947                RHODEY
# 948            SMART HULK
# 949                 STEVE
# 950            SMART HULK
# 951                  TONY
# 952                 STEVE
# 953                  THOR
# 954                  TONY
# 955                  THOR
# 956          CLINT BARTON
# 957                  THOR
# 958          CLINT BARTON
# 959                  THOR
# 960          CLINT BARTON
# 961                  THOR
# 962          CLINT BARTON
# 963            SMART HULK
# 964                 STEVE
# 965                ROCKET
# 966                  THOR
# 967                  TONY
# 968                 STEVE
# 969                  THOR
# 970                ROCKET
# 971            SCOTT LANG
# 972                  THOR
# 973                  TONY
# 974                  THOR
# 975                  TONY
# 976                  THOR
# 977                RHODEY
# 978                  THOR
# 979            SMART HULK
# 980                 STEVE
# 981            SMART HULK
# 982                  TONY
# 983            SMART HULK
# 984                  TONY
# 985            SMART HULK
# 986                  TONY
# 987            SMART HULK
# 988                  THOR
# 989                 STEVE
# 990                  TONY
# 991            SMART HULK
# 992                 STEVE
# 993                  TONY
# 994            SMART HULK
# 995          CLINT BARTON
# 996            SCOTT LANG
# 997                THANOS
# 998            BAD NEBULA
# 999                THANOS
# 1000           BAD NEBULA
# 1001               THANOS
# 1002               THANOS
# 1003           BAD NEBULA
# 1004               THANOS
# 1005               RHODEY
# 1006               RHODEY
# 1007               RHODEY
# 1008               RHODEY
# 1009               RHODEY
# 1010           SCOTT LANG
# 1011               ROCKET
# 1012               RHODEY
# 1013           SCOTT LANG
# 1014         CLINT BARTON
# 1015                 TONY
# 1016                STEVE
# 1017                 TONY
# 1018                STEVE
# 1019                 TONY
# 1020                 TONY
# 1021                 THOR
# 1022                STEVE
# 1023                 TONY
# 1024                STEVE
# 1025                 TONY
# 1026                STEVE
# 1027                 THOR
# 1028                 TONY
# 1029                 THOR
# 1030                 THOR
# 1031               THANOS
# 1032               THANOS
# 1033                 TONY
# 1034               THANOS
# 1035               THANOS
# 1036               THANOS
# 1037                STEVE
# 1038               THANOS
# 1039               THANOS
# 1040               NEBULA
# 1041               GAMORA
# 1042               NEBULA
# 1043               GAMORA
# 1044               NEBULA
# 1045               GAMORA
# 1046           SMART HULK
# 1047               ROCKET
# 1048           SMART HULK
# 1049               RHODEY
# 1050           SCOTT LANG
# 1051         CLINT BARTON
# 1052           BAD NEBULA
# 1053         CLINT BARTON
# 1054               GAMORA
# 1055           BAD NEBULA
# 1056               GAMORA
# 1057               NEBULA
# 1058           BAD NEBULA
# 1059               GAMORA
# 1060               NEBULA
# 1061               GAMORA
# 1062           BAD NEBULA
# 1063               NEBULA
# 1064           BAD NEBULA
# 1065         CLINT BARTON
# 1066               FRIDAY
# 1067               RHODEY
# 1068                 THOR
# 1069               THANOS
# 1070               THANOS
# 1071               THANOS
# 1072               THANOS
# 1073        MUFFLED VOICE
# 1074           SAM WILSON
# 1075          DR. STRANGE
# 1076                 WONG
# 1077           SCOTT LANG
# 1078                STEVE
# 1079                 THOR
# 1080         PETER PARKER
# 1081         PETER PARKER
# 1082                QUILL
# 1083                QUILL
# 1084                QUILL
# 1085               GAMORA
# 1086               NEBULA
# 1087         CLINT BARTON
# 1088                STEVE
# 1089           SMART HULK
# 1090                 TONY
# 1091           SCOTT LANG
# 1092                STEVE
# 1093             VALKYRIE
# 1094                 TONY
# 1095           SCOTT LANG
# 1096                STEVE
# 1097        HOPE VAN DYNE
# 1098                 TONY
# 1099          DR. STRANGE
# 1100                 TONY
# 1101            EBONY MAW
# 1102             T’CHALLA
# 1103           SCOTT LANG
# 1104        HOPE VAN DYNE
# 1105           SCOTT LANG
# 1106                WANDA
# 1107               THANOS
# 1108                WANDA
# 1109         PETER PARKER
# 1110         PETER PARKER
# 1111               THANOS
# 1112        CORVUS GLAIVE
# 1113               THANOS
# 1114         PEPPER POTTS
# 1115         PETER PARKER
# 1116                STEVE
# 1117         PEPPER POTTS
# 1118         PETER PARKER
# 1119               ROCKET
# 1120           SAM WILSON
# 1121                 TONY
# 1122               FRIDAY
# 1123                GROOT
# 1124               ROCKET
# 1125               ROCKET
# 1126                STEVE
# 1127        CAROL DANVERS
# 1128           SCOTT LANG
# 1129         PETER PARKER
# 1130        CAROL DANVERS
# 1131         PETER PARKER
# 1132                WANDA
# 1133                OKOYE
# 1134           SCOTT LANG
# 1135               THANOS
# 1136                 TONY
# 1137                QUILL
# 1138         PETER PARKER
# 1139         PEPPER POTTS
# 1140               FRIDAY
# 1141         PEPPER POTTS
# 1142         PEPPER POTTS
# 1143                 TONY
# 1144                 TONY
# 1145                 TONY
# 1146                 TONY
# 1147                 TONY
# 1148                 TONY
# 1149                 TONY
# 1150                 TONY
# 1151                 TONY
# 1152         CLINT BARTON
# 1153                WANDA
# 1154          HAPPY HOGAN
# 1155         MORGAN STARK
# 1156          HAPPY HOGAN
# 1157         MORGAN STARK
# 1158          HAPPY HOGAN
# 1159         MORGAN STARK
# 1160          HAPPY HOGAN
# 1161             VALKYRIE
# 1162                 THOR
# 1163             VALKYRIE
# 1164                 THOR
# 1165             VALKYRIE
# 1166                 THOR
# 1167             VALKYRIE
# 1168                 THOR
# 1169             VALKYRIE
# 1170                 THOR
# 1171               ROCKET
# 1172                 THOR
# 1173                 THOR
# 1174                QUILL
# 1175                 THOR
# 1176                QUILL
# 1177                 THOR
# 1178                 DRAX
# 1179               NEBULA
# 1180                QUILL
# 1181               ROCKET
# 1182               MANTIS
# 1183                QUILL
# 1184                GROOT
# 1185                 THOR
# 1186                QUILL
# 1187           SMART HULK
# 1188                STEVE
# 1189           SMART HULK
# 1190                STEVE
# 1191           SMART HULK
# 1192           SAM WILSON
# 1193                STEVE
# 1194                STEVE
# 1195         BUCKY BARNES
# 1196         BUCKY BARNES
# 1197                STEVE
# 1198           SAM WILSON
# 1199           SMART HULK
# 1200                STEVE
# 1201           SMART HULK
# 1202           SMART HULK
# 1203           SAM WILSON
# 1204           SMART HULK
# 1205           SAM WILSON
# 1206           SMART HULK
# 1207           SAM WILSON
# 1208           SMART HULK
# 1209         BUCKY BARNES
# 1210           SAM WILSON
# 1211            OLD STEVE
# 1212           SAM WILSON
# 1213            OLD STEVE
# 1214           SAM WILSON
# 1215            OLD STEVE
# 1216           SAM WILSON
# 1217            OLD STEVE
# 1218           SAM WILSON
# 1219            OLD STEVE
# 1220           SAM WILSON
# 1221            OLD STEVE
# 1222            OLD STEVE
# 1223           SAM WILSON
# 1224            OLD STEVE
# 1225           SAM WILSON
# 1226            OLD STEVE
# 1227           SAM WILSON
# 1228            OLD STEVE
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 line
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Okay, you see where you’re going? Let’s work on how to get there.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Okay, good...tip down...bow arm out...three fingers-
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Why three?
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ‘Cause two’s not enough and four’s too much-
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            You guys want mustard or mayo, or both?
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Who puts mayo on a hot dog?
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    We’ll both have mustard, hon!  Okay.  Draw back, deep breath...
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Good job, Hawkeye.  Go get your arrow.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Enough murder practice!  Soup’s on!
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      One sec, babe.  Be right there! We’re gonna kill some hot dogs. We’re hungry.
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Lila?  Babe, did you see Lila-
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Guys?  Guys, come on...
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Laura?
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            LAURA!
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Good sport.  Have fun?
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       It was fun.
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              This thing on?  Hey, Ms. Potts. Pep.  If you find this recording, don’t post it on social media. It’s going to be a real tearjerker.
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    I don’t know if you’re ever going to see these.  I don’t even know if you’re still...God, I hope so. Today’s day twenty-one, no...twenty- two.
# ...
# 1203                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Where is he?
# 1204                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 I don’t know.  He blew past our time stamp.  He should be here.
# 1205                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Get him back!
# 1206                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     I’m trying.
# 1207                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Get him the hell back-
# 1208                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     I’M TRYING!
# 1209                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Sam.
# 1210                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Hey, Cap.
# 1211                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Hi, Sam.
# 1212                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Something go wrong...or something go right?
# 1213                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             I thought, after everything that’s happened...maybe I should try out some of that life Tony always told me to get.
# 1214                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     How was it?
# 1215                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               It was beautiful.
# 1216                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     I’m happy for you.  Really.
# 1217                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Thanks.
# 1218                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Only thing bumming me out is now I live in a world without Captain America.
# 1219                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    That’s kind of why I’m here.
# 1220                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Where did you even get this?
# 1221                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       I had a little time to travel. Try it on.
# 1222                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               How does it feel?
# 1223                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Like it’s someone else’s.
# 1224                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       It isn’t.
# 1225                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Thank you.  I’ll try my best.
# 1226                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          That’s why it’s yours.
# 1227                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    You gonna tell me about her?
# 1228                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Nope.  I don’t think I will.
