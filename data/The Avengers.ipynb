# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Script to CSV Process
#
# 1. Load script `.txt` file.  Use [PDF Extractor](https://pdfextractor.com/) to convert any `.pdf`s to `.txt`s.
# 2. Remove garbage rows
# 3. Inspect rows removed
# 4. Format lines
# 5. Create `uppercase_unique_form.csv`
# 6. Manually fill out `uppercase_unique_form.csv` columns `is_character_name` and `is_dialogue` in Excel or other `.csv` editor.
# 7. Load `uppercase_unique.csv` and filter out rows
# 8. Inspect rows removed
# 9. Merge lines into best guesses for columns "character" and "line"
# 10. Manually clean the `line` column by removing text that is not dialogue.  There will be a lot, so nearly every cell will have to be cleaned!
#
#
# See the Avengers script at the end of this notebook for an example of this process.

# %% [markdown]
# ## Remove Garbage Rows

# %%
def remove_regex_rows(df,string):
    rows_to_remove = df["line"].str.contains(string,case=True,regex=True)
    print("Removed",rows_to_remove.sum(),"rows that match regex \"" + string + "\"")
    
    return df[~rows_to_remove], df[rows_to_remove]

def remove_whitespace_rows(df):
    whitespace_rows = df["line"].str.isspace()
    print(whitespace_rows.sum(),"whitespace rows removed")
    return df[~whitespace_rows], df[whitespace_rows]

def remove_movie_text_rows(df):
    
    regex_strings = ["INTERCUT:",
                    "CUT TO",
                    "^THE END",
                    "^INT\.",
                    "^EXT\.",
                    "\(CONTINUED\)",
                    "CONTINUED: \(.\)",
                    "[0-9]+\.",
                    "\(.*radio\)",
                    "\(.*earpiece\)",
                    "\(.*headset\)",
                    "\(.*phone\)",
                    "\(.*cell\)",
                    "\(to .*\)",
                    "\(in .*\)",
                    "\(MORE\)",
                    "\(angry\)",
                    "TIME CUT:",
                    "TITLE:",
                    "MARVEL FLIP",
                    "SLAM TO",
                    "DISSOLVE TO",
                    "BEST ADAPTED SCREENPLAY",
                    "FADE TO BLACK",
                    "CUE MUSIC"]
    
    removed_rows = pd.DataFrame()
    
    for regex_string in regex_strings:
        df, new_rows_to_remove = remove_regex_rows(df,regex_string)
        
        removed_rows = pd.concat([removed_rows, new_rows_to_remove])
    
    return df, removed_rows


def remove_page_number_rows(df):
    page_rows = df["line"].str.isnumeric()
    print(page_rows.sum(),"page number rows removed")
    
    return df[~page_rows], df[page_rows]

def remove_garbage_rows(df):
    df, whitespace_rows = remove_whitespace_rows(df)
    df, page_number_rows = remove_page_number_rows(df)
    df, movie_text_rows = remove_movie_text_rows(df)
    
    garbage_rows = pd.concat([whitespace_rows, page_number_rows, movie_text_rows], 
                            keys = ["whitespace","page_numbers","movie_text"])
    
    print("-----------------------------------------")
    print(garbage_rows.shape[0],"total rows removed\n")
    
    return df, garbage_rows

# %% [markdown]
# ## Format Character Lines

# %%
def remove_regex(df,string):
    print("Removed",df["line"].str.count(string).sum(),"occurences of regex \"" + string + "\"")
    df["line"] = df["line"].str.replace(string,"",case=True,regex=True)

def remove_leading_trailing_whitespace(df):
    df["line"] = df["line"].str.replace("[ \t]+$","")
    df["line"] = df["line"].str.replace("^[ \t]+","")

def format_lines(df):
    remove_leading_trailing_whitespace(df)
    
    regex_strings = ["\(O\.S\)",
                    "\(V\.O\)",
                    "\(CONT’D\)",
                    "\(O\.S\.\)",
                    "\(ON SCREEN\)",
                    "\(OVER COM\)",
                    "\(ON COM\)",
                    "\(INTO COM\)",
                    "\(OVER SPEAKER\)",
                    "\(INTO PHONE\)",
                    "\(OVER PHONE\)",
                    "\(HOLO\)"]
    
    for regex_string in regex_strings:
        remove_regex(df, regex_string)
    
    print("")
    
    remove_leading_trailing_whitespace(df)

# %% [markdown]
# ## Remove Non Dialogue Uppercase Rows

# %%
def uppercase_rows(df):
    upper_lines = df["line"].str.isupper()
    
    return df[upper_lines]

def create_uppercase_unique_csv(df,script_name):
    '''
    Creates a csv file that is used for inspection of unique
    lines that are all uppercase.  These lines are manually labeled
    to be character names or dialogue.  The resulting table will be
    used to delete rows that are neither character names nor dialogue.
    '''
    
    upper_rows = uppercase_rows(df)
    unique_upper_rows = pd.DataFrame(upper_rows.line.unique())

    unique_upper_rows["words"] = unique_upper_rows[0].str.split(" ").str.len()
    unique_upper_rows["is_character_name"] = 0
    unique_upper_rows["is_dialogue"] = 0
    sorted_unique_upper_rows = unique_upper_rows.sort_values(by=["words"])
    sorted_unique_upper_rows.to_csv("./uppercase forms/" + script_name + "_uppercase_unique_form.csv",encoding='utf-8')
    
def remove_non_dialogue_upper_rows(df,upper_rows):
    '''
    Removes lines that are in all caps, and that are not dialogue or a character's name.
    '''
    unique_character_names = upper_rows[upper_rows["is_character_name"]]["line"]
    unique_dialogues = upper_rows[upper_rows["is_dialogue"]]["line"]
    
    all_character_name_lines = df[df["line"].isin(unique_character_names)]
    all_dialogue_lines = df[df["line"].isin(unique_dialogues)]
    
    print(df["line"].str.isupper().sum(),"total uppercase lines")
    print(all_character_name_lines.shape[0],"uppercase character name lines")
    print(all_dialogue_lines.shape[0],"uppercase dialogue lines")
    
    unique_lines_to_remove = upper_rows[~(upper_rows["is_character_name"]|upper_rows["is_dialogue"])]["line"]
    removed_lines = df["line"].isin(unique_lines_to_remove)
    print(removed_lines.sum(),"uppercase lines removed")
    
    return df[~removed_lines], df[removed_lines]

# %% [markdown]
# ## Merge Lines

# %%
def is_character_name(string,character_names):
    return string in character_names["line"].tolist()
    

def merge_lines(df,character_names):
    '''
    Starts at a character name and merges all lines until the next character's name.
    The result should be the best guess at columns "character" and "line".
    This will merge in some screenplay text that is not dialogue, so the result will 
    have to be manually cleaned as the final step.
    '''
    merged_df = pd.DataFrame(columns=["character","line"])
    
    for i in range(0,df.shape[0]):
        
        row = df.iloc[i]
        
        if is_character_name(row["line"],character_names):
            character = row["line"]
            line = ""
            
            j = i + 1
            while(j < len(df) and (not is_character_name(df.iloc[j]["line"],character_names))):
                line += df.iloc[j]["line"] + " "
                j += 1
            
            new_row = {"character": character,"line": line}
            
            merged_df = merged_df.append(new_row,ignore_index=True)
    
    return merged_df

# %% [markdown]
# ## The Avengers

# %%
avengers = pd.read_csv("./script txts/avengers-script-slug.txt",sep="\n",header=None,names=["line"])

avengers, garbage_rows = remove_garbage_rows(avengers)
format_lines(avengers)

create_uppercase_unique_csv(avengers,"avengers")
filled_out_upper_rows = pd.read_csv("./uppercase results/avengers_uppercase_unique.csv",
                                    names=["","line","words","is_character_name","is_dialogue"],
                                    dtype={"line":str, "words":int, "is_character_name":bool, "is_dialogue":bool},
                                    index_col=0)

avengers, upper_removed_rows = remove_non_dialogue_upper_rows(avengers, filled_out_upper_rows)
removed_rows = pd.concat([garbage_rows,pd.concat([upper_removed_rows],keys=[""])],keys=["garbage","uppercase"])

unique_character_names = pd.DataFrame(filled_out_upper_rows[filled_out_upper_rows["is_character_name"]]["line"])

avengers = merge_lines(avengers, unique_character_names)
avengers.reindex(copy=False)

avengers.to_csv("./uncleaned/avengers_uncleaned.csv", index=False)

avengers = pd.read_csv("./cleaned/avengers.csv")

avengers
# Out:
# 132 whitespace rows removed
# 440 page number rows removed
# Removed 6 rows that match regex "INTERCUT:"
# Removed 1 rows that match regex "CUT TO"
# Removed 1 rows that match regex "^THE END"
# Removed 122 rows that match regex "^INT\."
# Removed 98 rows that match regex "^EXT\."
# Removed 98 rows that match regex "\(CONTINUED\)"
# Removed 98 rows that match regex "CONTINUED: \(.\)"
# Removed 130 rows that match regex "[0-9]+\."
# Removed 28 rows that match regex "\(.*radio\)"
# Removed 26 rows that match regex "\(.*earpiece\)"
# Removed 9 rows that match regex "\(.*headset\)"
# Removed 1 rows that match regex "\(.*phone\)"
# Removed 12 rows that match regex "\(.*cell\)"
# Removed 40 rows that match regex "\(to .*\)"
# Removed 14 rows that match regex "\(in .*\)"
# Removed 3 rows that match regex "\(MORE\)"
# Removed 3 rows that match regex "\(angry\)"
# Removed 0 rows that match regex "TIME CUT:"
# Removed 0 rows that match regex "TITLE:"
# Removed 0 rows that match regex "MARVEL FLIP"
# Removed 0 rows that match regex "SLAM TO"
# Removed 0 rows that match regex "DISSOLVE TO"
# Removed 0 rows that match regex "BEST ADAPTED SCREENPLAY"
# Removed 0 rows that match regex "FADE TO BLACK"
# Removed 0 rows that match regex "CUE MUSIC"
# -----------------------------------------
# 1262 total rows removed
#
# Removed 8 occurences of regex "\(O\.S\)"
# Removed 39 occurences of regex "\(V\.O\)"
# Removed 19 occurences of regex "\(CONT’D\)"
# Removed 0 occurences of regex "\(O\.S\.\)"
# Removed 0 occurences of regex "\(ON SCREEN\)"
# Removed 0 occurences of regex "\(OVER COM\)"
# Removed 0 occurences of regex "\(ON COM\)"
# Removed 0 occurences of regex "\(INTO COM\)"
# Removed 0 occurences of regex "\(OVER SPEAKER\)"
# Removed 0 occurences of regex "\(INTO PHONE\)"
# Removed 0 occurences of regex "\(OVER PHONE\)"
# Removed 0 occurences of regex "\(HOLO\)"
#
# 1120 total uppercase lines
# 1031 uppercase character name lines
# 16 uppercase dialogue lines
# 73 uppercase lines removed
#                        character  \
# 0                      THE OTHER
# 1                      THE OTHER
# 2                      THE OTHER
# 3                 INTERCOM VOICE
# 4                 INTERCOM VOICE
# 5                 INTERCOM VOICE
# 6                           FURY
# 7                  AGENT COULSON
# 8                  AGENT COULSON
# 9                  AGENT COULSON
# 10                          FURY
# 11                 AGENT COULSON
# 12                    MARIA HILL
# 13                          FURY
# 14                 AGENT COULSON
# 15                          FURY
# 16                 AGENT COULSON
# 17                          FURY
# 18                    MARIA HILL
# 19                          FURY
# 20                    MARIA HILL
# 21                          FURY
# 22                    MARIA HILL
# 23                          FURY
# 24                    MARIA HILL
# 25                          FURY
# 26                        SELVIG
# 27                          FURY
# 28                        SELVIG
# 29                          FURY
# 30                        SELVIG
# 31                          FURY
# 32                        SELVIG
# 33                          FURY
# 34                        SELVIG
# 35                          FURY
# 36                        SELVIG
# 37                          FURY
# 38                          FURY
# 39                        BARTON
# 40                          FURY
# 41                NASA SCIENTIST
# 42                        BARTON
# 43                          FURY
# 44                        BARTON
# 45                        SELVIG
# 46                          FURY
# 47                          LOKI
# 48                          LOKI
# 49                          FURY
# 50                          LOKI
# 51                        SELVIG
# 52                          FURY
# 53                          LOKI
# 54                          FURY
# 55                          LOKI
# 56                          FURY
# 57                          LOKI
# 58                          FURY
# 59                        BARTON
# 60                          FURY
# 61                        SELVIG
# 62                          LOKI
# 63                        BARTON
# 64                    MARIA HILL
# 65                        BARTON
# 66                          FURY
# 67                          FURY
# 68                          FURY
# 69                          FURY
# 70                 AGENT COULSON
# 71                 AGENT COULSON
# 72                 AGENT COULSON
# 73                 AGENT COULSON
# 74                 AGENT COULSON
# 75                          FURY
# 76                    MARIA HILL
# 77                          FURY
# 78                          FURY
# 79                    MARIA HILL
# 80                          FURY
# 81                          FURY
# 82                          FURY
# 83                          FURY
# 84                 AGENT COULSON
# 85                GEORGI LUCHKOV
# 86                       NATASHA
# 87                GEORGI LUCHKOV
# 88                GEORGI LUCHKOV
# 89                       NATASHA
# 90                GEORGI LUCHKOV
# 91                       NATASHA
# 92                GEORGI LUCHKOV
# 93                 WEASELLY THUG
# 94                GEORGI LUCHKOV
# 95                 AGENT COULSON
# 96                       NATASHA
# 97                 AGENT COULSON
# 98                       NATASHA
# 99                GEORGI LUCHKOV
# 100                      NATASHA
# 101                AGENT COULSON
# 102                      NATASHA
# 103                      NATASHA
# 104                AGENT COULSON
# 105                      NATASHA
# 106                AGENT COULSON
# 107                      NATASHA
# 108                AGENT COULSON
# 109                      NATASHA
# 110               CALCUTTA WOMAN
# 111                   YOUNG GIRL
# 112                       BANNER
# 113                   YOUNG GIRL
# 114                       BANNER
# 115                   YOUNG GIRL
# 116                       BANNER
# 117                      NATASHA
# 118                      NATASHA
# 119                       BANNER
# 120                      NATASHA
# 121                       BANNER
# 122                      NATASHA
# 123                       BANNER
# 124                      NATASHA
# 125                       BANNER
# 126                      NATASHA
# 127                       BANNER
# 128                      NATASHA
# 129                       BANNER
# 130                      NATASHA
# 131                       BANNER
# 132                      NATASHA
# 133                       BANNER
# 134                      NATASHA
# 135                       BANNER
# 136                      NATASHA
# 137                       BANNER
# 138                      NATASHA
# 139                       BANNER
# 140                      NATASHA
# 141                       BANNER
# 142                      NATASHA
# 143                       BANNER
# 144                      NATASHA
# 145                       BANNER
# 146                      NATASHA
# 147                       BANNER
# 148                      NATASHA
# 149                       BANNER
# 150                      NATASHA
# 151                       BANNER
# 152                   COUNCILMAN
# 153                         FURY
# 154                   COUNCILMAN
# 155                         FURY
# 156                 COUNCILWOMAN
# 157                         FURY
# 158                   COUNCILMAN
# 159                         FURY
# 160                   COUNCILMAN
# 161                         FURY
# 162                   COUNCILMAN
# 163                         FURY
# 164                 COUNCILWOMAN
# 165                   COUNCILMAN
# 166                         FURY
# 167              CAPTAIN AMERICA
# 168                 PEGGY CARTER
# 169                    SCIENTIST
# 170                         FURY
# 171                        STEVE
# 172                         FURY
# 173                        STEVE
# 174                         FURY
# 175                        STEVE
# 176                         FURY
# 177                        STEVE
# 178                         FURY
# 179                        STEVE
# 180                         FURY
# 181                        STEVE
# 182                         FURY
# 183                        STEVE
# 184                         FURY
# 185                        STEVE
# 186                     IRON MAN
# 187                       PEPPER
# 188                         TONY
# 189                       PEPPER
# 190                         TONY
# 191                       PEPPER
# 192                         TONY
# 193                         TONY
# 194                       PEPPER
# 195                       PEPPER
# 196                         TONY
# 197                       PEPPER
# 198                       JARVIS
# 199                         TONY
# 200                       JARVIS
# 201                         TONY
# 202                       PEPPER
# 203                         TONY
# 204                       PEPPER
# 205                         TONY
# 206                       PEPPER
# 207                         TONY
# 208                       PEPPER
# 209                         TONY
# 210                       PEPPER
# 211                         TONY
# 212                       PEPPER
# 213                         TONY
# 214                       PEPPER
# 215                         TONY
# 216                       PEPPER
# 217                         TONY
# 218                       PEPPER
# 219                         TONY
# 220                       JARVIS
# 221                         TONY
# 222                AGENT COULSON
# 223                         TONY
# 224                AGENT COULSON
# 225                         TONY
# 226                       PEPPER
# 227                         TONY
# 228                AGENT COULSON
# 229                         TONY
# 230                       PEPPER
# 231                         TONY
# 232                AGENT COULSON
# 233                         TONY
# 234                       PEPPER
# 235                         TONY
# 236                AGENT COULSON
# 237                       PEPPER
# 238                         TONY
# 239                       PEPPER
# 240                         TONY
# 241                       PEPPER
# 242                AGENT COULSON
# 243                         TONY
# 244                       PEPPER
# 245                         TONY
# 246                       PEPPER
# 247                         TONY
# 248                       PEPPER
# 249                         TONY
# 250                       PEPPER
# 251                         TONY
# 252                       PEPPER
# 253                         TONY
# 254                       PEPPER
# 255                         TONY
# 256                       PEPPER
# 257                AGENT COULSON
# 258                       PEPPER
# 259                AGENT COULSON
# 260                       PEPPER
# 261               FACELESS PILOT
# 262                        STEVE
# 263                AGENT COULSON
# 264                        STEVE
# 265                AGENT COULSON
# 266                AGENT COULSON
# 267                        STEVE
# 268                AGENT COULSON
# 269                        STEVE
# 270                AGENT COULSON
# 271                    THE OTHER
# 272                         LOKI
# 273                    THE OTHER
# 274                         LOKI
# 275                    THE OTHER
# 276                         LOKI
# 277                    THE OTHER
# 278                         LOKI
# 279                    THE OTHER
# 280                AGENT COULSON
# 281                        STEVE
# 282                      NATASHA
# 283                AGENT COULSON
# 284                      NATASHA
# 285                        STEVE
# 286                      NATASHA
# 287                        STEVE
# 288                       BANNER
# 289                        STEVE
# 290                       BANNER
# 291                        STEVE
# 292                       BANNER
# 293                        STEVE
# 294                      NATASHA
# 295         HELICARRIER INTERCOM
# 296                        STEVE
# 297                       BANNER
# 298        CARRIER BRIDGE TECH 1
# 299   FEMALE CARRIER BRIDGE TECH
# 300                   MARIA HILL
# 301                         FURY
# 302                   MARIA HILL
# 303                   MALE AGENT
# 304                         FURY
# 305                       BANNER
# 306                         FURY
# 307                       BANNER
# 308                AGENT COULSON
# 309                      NATASHA
# 310                       BANNER
# 311                         FURY
# 312                       BANNER
# 313                         FURY
# 314                      NATASHA
# 315                       BANNER
# 316                      NATASHA
# 317                       BANNER
# 318                         FURY
# 319                   MARIA HILL
# 320                   MARIA HILL
# 321                         FURY
# 322                       SELVIG
# 323                       BARTON
# 324                       SELVIG
# 325                       BARTON
# 326                       SELVIG
# 327                         LOKI
# 328                       BARTON
# 329                       SELVIG
# 330                       BARTON
# 331                         LOKI
# 332                       BARTON
# 333                         LOKI
# 334                       BARTON
# 335                         LOKI
# 336                       BARTON
# 337                         LOKI
# 338                       BARTON
# 339                         LOKI
# 340                       BARTON
# 341                         LOKI
# 342                       BARTON
# 343                         LOKI
# 344                       BARTON
# 345                AGENT COULSON
# 346                        STEVE
# 347                AGENT COULSON
# 348         AGENT JASPER SITWELL
# 349                AGENT COULSON
# 350         AGENT JASPER SITWELL
# 351                         FURY
# 352                         LOKI
# 353               GERMAN OLD MAN
# 354                         LOKI
# 355               GERMAN OLD MAN
# 356                         LOKI
# 357              CAPTAIN AMERICA
# 358                         LOKI
# 359              CAPTAIN AMERICA
# 360                      NATASHA
# 361                         LOKI
# 362              CAPTAIN AMERICA
# 363                      NATASHA
# 364                         TONY
# 365                     IRON MAN
# 366              CAPTAIN AMERICA
# 367                     IRON MAN
# 368                         FURY
# 369                      NATASHA
# 370                         FURY
# 371                        STEVE
# 372                         TONY
# 373                        STEVE
# 374                         TONY
# 375                        STEVE
# 376                         TONY
# 377                        STEVE
# 378                         TONY
# 379                      NATASHA
# 380                        STEVE
# 381                         LOKI
# 382              CAPTAIN AMERICA
# 383                     IRON MAN
# 384                      NATASHA
# 385              CAPTAIN AMERICA
# 386                      NATASHA
# 387              CAPTAIN AMERICA
# 388                     IRON MAN
# 389                      NATASHA
# 390              CAPTAIN AMERICA
# 391                      NATASHA
# 392              CAPTAIN AMERICA
# 393                         THOR
# 394                         LOKI
# 395                         THOR
# 396                         LOKI
# 397                         THOR
# 398                         LOKI
# 399                         THOR
# 400                         LOKI
# 401                         THOR
# 402                         LOKI
# 403                         THOR
# 404                         LOKI
# 405                         THOR
# 406                         LOKI
# 407                         THOR
# 408                         LOKI
# 409                         THOR
# 410                         LOKI
# 411                         THOR
# 412                         LOKI
# 413                         THOR
# 414                         TONY
# 415                         THOR
# 416                         TONY
# 417                         THOR
# 418                         TONY
# 419                     IRON MAN
# 420                         TONY
# 421                       JARVIS
# 422                         TONY
# 423              CAPTAIN AMERICA
# 424              CAPTAIN AMERICA
# 425                         THOR
# 426              CAPTAIN AMERICA
# 427                     IRON MAN
# 428                         THOR
# 429              CAPTAIN AMERICA
# 430                         FURY
# 431                         LOKI
# 432                         FURY
# 433                         LOKI
# 434                         FURY
# 435                         LOKI
# 436                         FURY
# 437                       BANNER
# 438                        STEVE
# 439                         THOR
# 440                        STEVE
# 441                       BANNER
# 442                         THOR
# 443                       BANNER
# 444                         THOR
# 445                      NATASHA
# 446                        STEVE
# 447                       BANNER
# 448                         THOR
# 449                      NATASHA
# 450                         THOR
# 451                       BANNER
# 452                         TONY
# 453                         TONY
# 454                   MARIA HILL
# 455                         TONY
# 456                   MARIA HILL
# 457                         TONY
# 458                        STEVE
# 459                       BANNER
# 460                         TONY
# 461                       BANNER
# 462                         TONY
# 463                        STEVE
# 464                         TONY
# 465                       BANNER
# 466                         FURY
# 467                        STEVE
# 468                         FURY
# 469                         THOR
# 470                        STEVE
# 471                        STEVE
# 472                         TONY
# 473                       BANNER
# 474                       BANNER
# 475                         TONY
# 476                       BANNER
# 477                         TONY
# 478                       BANNER
# 479                         TONY
# 480                       BANNER
# 481                        STEVE
# 482                         TONY
# 483                        STEVE
# 484                         TONY
# 485                        STEVE
# 486                         TONY
# 487                        STEVE
# 488                       BANNER
# 489                         TONY
# 490                        STEVE
# 491                         TONY
# 492                        STEVE
# 493                         TONY
# 494                       BANNER
# 495                        STEVE
# 496                       BANNER
# 497                        STEVE
# 498                       BANNER
# 499                        STEVE
# 500                       BANNER
# 501                         TONY
# 502                       BANNER
# 503                         TONY
# 504                        STEVE
# 505                         TONY
# 506                        STEVE
# 507                         TONY
# 508                        STEVE
# 509                         TONY
# 510                        STEVE
# 511                         TONY
# 512                       BANNER
# 513                        STEVE
# 514                         TONY
# 515                       BANNER
# 516                         TONY
# 517                       BANNER
# 518                         TONY
# 519                       BANNER
# 520                         TONY
# 521                       BANNER
# 522                         TONY
# 523                       BANNER
# 524                         TONY
# 525                       BANNER
# 526                         TONY
# 527                       BANNER
# 528                         TONY
# 529                AGENT COULSON
# 530                AGENT COULSON
# 531                         THOR
# 532                AGENT COULSON
# 533                         THOR
# 534                AGENT COULSON
# 535                         THOR
# 536                AGENT COULSON
# 537                         THOR
# 538                         FURY
# 539                         THOR
# 540                         FURY
# 541                         THOR
# 542                         FURY
# 543                         THOR
# 544                         FURY
# 545                         LOKI
# 546                      NATASHA
# 547                         LOKI
# 548                      NATASHA
# 549                         LOKI
# 550                      NATASHA
# 551                         LOKI
# 552                      NATASHA
# 553                         LOKI
# 554                      NATASHA
# 555                         LOKI
# 556                      NATASHA
# 557                         LOKI
# 558                      NATASHA
# 559                         LOKI
# 560                      NATASHA
# 561                         LOKI
# 562                         LOKI
# 563                         LOKI
# 564                         LOKI
# 565                         LOKI
# 566                      NATASHA
# 567                         LOKI
# 568                      NATASHA
# 569                         LOKI
# 570                      NATASHA
# 571                         FURY
# 572                         TONY
# 573                         FURY
# 574                       BANNER
# 575                         TONY
# 576                        STEVE
# 577                         FURY
# 578                         TONY
# 579                        STEVE
# 580                       BANNER
# 581                      NATASHA
# 582                       BANNER
# 583                      NATASHA
# 584                       BANNER
# 585                      NATASHA
# 586                       BANNER
# 587                       BANNER
# 588                         FURY
# 589                         THOR
# 590                         FURY
# 591                         THOR
# 592                         FURY
# 593                        STEVE
# 594                         THOR
# 595                        STEVE
# 596                         FURY
# 597                         TONY
# 598                         FURY
# 599                        STEVE
# 600                         TONY
# 601                        STEVE
# 602                         THOR
# 603                         FURY
# 604                         THOR
# 605                         FURY
# 606                      NATASHA
# 607                         TONY
# 608                       BANNER
# 609                      NATASHA
# 610                         FURY
# 611                         TONY
# 612                        STEVE
# 613                         TONY
# 614                        STEVE
# 615                         TONY
# 616                       BANNER
# 617               INTERCOM VOICE
# 618                        PILOT
# 619                         THOR
# 620                       BANNER
# 621                         FURY
# 622                         TONY
# 623                        STEVE
# 624                         TONY
# 625                        STEVE
# 626                         TONY
# 627                        STEVE
# 628                         TONY
# 629                        STEVE
# 630                         TONY
# 631                        STEVE
# 632                         THOR
# 633                       BANNER
# 634                         FURY
# 635                       BANNER
# 636                         FURY
# 637                       BANNER
# 638                        STEVE
# 639                         FURY
# 640                       BANNER
# 641                         THOR
# 642                         TONY
# 643                        STEVE
# 644                        NOVAR
# 645                        STEVE
# 646                         TONY
# 647                        STEVE
# 648                         TONY
# 649                        STEVE
# 650                       BANNER
# 651                        STEVE
# 652                         TONY
# 653               INTERCOM VOICE
# 654                         FURY
# 655                   MARIA HILL
# 656   FEMALE CARRIER BRIDGE TECH
# 657                   MARIA HILL
# 658            OFF SCREEN WORKER
# 659        CARRIER BRIDGE TECH 1
# 660                   MARIA HILL
# 661                         FURY
# 662                         TONY
# 663                         FURY
# 664                         FURY
# 665                      NATASHA
# 666                      NATASHA
# 667                       BARTON
# 668                         TONY
# 669                      NATASHA
# 670              MAINTENANCE GUY
# 671                      NATASHA
# 672                       BANNER
# 673                      NATASHA
# 674                         FURY
# 675                 SHIELD AGENT
# 676                         FURY
# 677                 SHIELD AGENT
# 678                         FURY
# 679                        STEVE
# 680                     IRON MAN
# 681                         TONY
# 682                     IRON MAN
# 683                         TONY
# 684                        STEVE
# 685                         TONY
# 686                         THOR
# 687                        STEVE
# 688                        STEVE
# 689                     IRON MAN
# 690                         TONY
# 691                        STEVE
# 692                         TONY
# 693                        STEVE
# 694                         TONY
# 695                         TONY
# 696                         FURY
# 697                   MARIA HILL
# 698               INTERCOM VOICE
# 699               INTERCOM VOICE
# 700                   MARIA HILL
# 701                         FURY
# 702                   MARIA HILL
# 703                   MARIA HILL
# 704           YOUNG SHIELD PILOT
# 705           YOUNG SHIELD PILOT
# 706                         FURY
# 707               INTERCOM VOICE
# 708                SHIELD WORKER
# 709                         FURY
# 710                      NATASHA
# 711                         FURY
# 712                         TONY
# 713                         LOKI
# 714                         LOKI
# 715                AGENT COULSON
# 716                         THOR
# 717                       BARTON
# 718                AGENT COULSON
# 719                         LOKI
# 720                AGENT COULSON
# 721                         LOKI
# 722                AGENT COULSON
# 723                         LOKI
# 724                AGENT COULSON
# 725               INTERCOM VOICE
# 726                         TONY
# 727                        STEVE
# 728                         TONY
# 729                         TONY
# 730                AGENT COULSON
# 731                         FURY
# 732                AGENT COULSON
# 733                         FURY
# 734                AGENT COULSON
# 735                         FURY
# 736                SHIELD WORKER
# 737                         FURY
# 738                         FURY
# 739                         FURY
# 740               SECURITY GUARD
# 741                       BANNER
# 742               SECURITY GUARD
# 743                       BANNER
# 744               SECURITY GUARD
# 745                       BANNER
# 746               SECURITY GUARD
# 747                       BANNER
# 748               SECURITY GUARD
# 749                       BANNER
# 750               SECURITY GUARD
# 751                       BANNER
# 752               SECURITY GUARD
# 753               SECURITY GUARD
# 754                       BANNER
# 755               SECURITY GUARD
# 756                       BANNER
# 757               SECURITY GUARD
# 758                       BANNER
# 759               SECURITY GUARD
# 760                       BANNER
# 761               SECURITY GUARD
# 762                       BANNER
# 763               SECURITY GUARD
# 764                      NATASHA
# 765                       BARTON
# 766                      NATASHA
# 767                       BARTON
# 768                      NATASHA
# 769                       BARTON
# 770                      NATASHA
# 771                       BARTON
# 772                      NATASHA
# 773                       BARTON
# 774                      NATASHA
# 775                       BARTON
# 776                      NATASHA
# 777                       BARTON
# 778                      NATASHA
# 779                       BARTON
# 780                      NATASHA
# 781                       BARTON
# 782                      NATASHA
# 783                       BARTON
# 784                      NATASHA
# 785                        STEVE
# 786                         TONY
# 787                        STEVE
# 788                         TONY
# 789                        STEVE
# 790                         TONY
# 791                        STEVE
# 792                         TONY
# 793                        STEVE
# 794                         TONY
# 795                        STEVE
# 796                         TONY
# 797                        STEVE
# 798                         TONY
# 799                        STEVE
# 800                         TONY
# 801                        STEVE
# 802                         TONY
# 803                        STEVE
# 804                         TONY
# 805              CAPTAIN AMERICA
# 806                      NATASHA
# 807              CAPTAIN AMERICA
# 808                       BARTON
# 809              CAPTAIN AMERICA
# 810                       BARTON
# 811              CAPTAIN AMERICA
# 812              SHIELD ENGINEER
# 813              CAPTAIN AMERICA
# 814                   MARIA HILL
# 815                         FURY
# 816                   MARIA HILL
# 817                         FURY
# 818               INTERCOM VOICE
# 819                         FURY
# 820                   MARIA HILL
# 821                       JARVIS
# 822                     IRON MAN
# 823                       SELVIG
# 824                     IRON MAN
# 825                       JARVIS
# 826                     IRON MAN
# 827                       JARVIS
# 828                         TONY
# 829                         LOKI
# 830                         TONY
# 831                         LOKI
# 832                         TONY
# 833                         LOKI
# 834                         TONY
# 835                         LOKI
# 836                         TONY
# 837                         LOKI
# 838                         TONY
# 839                         LOKI
# 840                         TONY
# 841                         LOKI
# 842                         TONY
# 843                         LOKI
# 844                         TONY
# 845                         LOKI
# 846                         TONY
# 847                         LOKI
# 848                         TONY
# 849                         TONY
# 850                     IRON MAN
# 851                         TONY
# 852                         THOR
# 853                         LOKI
# 854                         THOR
# 855                      NATASHA
# 856                         TONY
# 857                       JARVIS
# 858                         TONY
# 859                       BARTON
# 860                      NATASHA
# 861              CAPTAIN AMERICA
# 862              CAPTAIN AMERICA
# 863                         TONY
# 864                         TONY
# 865              CAPTAIN AMERICA
# 866                         TONY
# 867                         THOR
# 868                         LOKI
# 869                         THOR
# 870                         LOKI
# 871                       BARTON
# 872              CAPTAIN AMERICA
# 873                      NATASHA
# 874              CAPTAIN AMERICA
# 875                       BARTON
# 876                      NATASHA
# 877                       BARTON
# 878                    YOUNG COP
# 879              POLICE SERGEANT
# 880              POLICE SERGEANT
# 881                    YOUNG COP
# 882              CAPTAIN AMERICA
# 883              POLICE SERGEANT
# 884              POLICE SERGEANT
# 885                         TONY
# 886              CAPTAIN AMERICA
# 887                         THOR
# 888                         TONY
# 889                      NATASHA
# 890              CAPTAIN AMERICA
# 891                         THOR
# 892                       BARTON
# 893              CAPTAIN AMERICA
# 894                       BANNER
# 895                      NATASHA
# 896                       BANNER
# 897                      NATASHA
# 898              CAPTAIN AMERICA
# 899                         TONY
# 900              CAPTAIN AMERICA
# 901                         TONY
# 902                      NATASHA
# 903              CAPTAIN AMERICA
# 904                       BANNER
# 905                     IRON MAN
# 906                         LOKI
# 907                      NATASHA
# 908                     IRON MAN
# 909              CAPTAIN AMERICA
# 910                       BARTON
# 911                     IRON MAN
# 912              CAPTAIN AMERICA
# 913              CAPTAIN AMERICA
# 914                   MARIA HILL
# 915                       BARTON
# 916                         TONY
# 917                       BARTON
# 918                         TONY
# 919                         TONY
# 920                         TONY
# 921                       BARTON
# 922                         TONY
# 923                      NATASHA
# 924              CAPTAIN AMERICA
# 925                      NATASHA
# 926              CAPTAIN AMERICA
# 927                      NATASHA
# 928              CAPTAIN AMERICA
# 929                      NATASHA
# 930                      NATASHA
# 931                       BARTON
# 932              CAPTAIN AMERICA
# 933              CAPTAIN AMERICA
# 934                 COUNCILWOMAN
# 935                         FURY
# 936                   COUNCILMAN
# 937                         FURY
# 938                         FURY
# 939                   COUNCILMAN
# 940                         FURY
# 941                      NATASHA
# 942                       BARTON
# 943                      NATASHA
# 944                       BARTON
# 945                         LOKI
# 946                         HULK
# 947                       SELVIG
# 948                      NATASHA
# 949                       SELVIG
# 950                      NATASHA
# 951                       SELVIG
# 952                      NATASHA
# 953                       SELVIG
# 954                       JARVIS
# 955                         TONY
# 956                       JARVIS
# 957                 COUNCILWOMAN
# 958                    JET PILOT
# 959                   MARIA HILL
# 960                         FURY
# 961                     IRON MAN
# 962                         FURY
# 963                         TONY
# 964                       JARVIS
# 965                    JET PILOT
# 966                         THOR
# 967                        STEVE
# 968                       SELVIG
# 969                      NATASHA
# 970                        STEVE
# 971                         TONY
# 972                        STEVE
# 973                         TONY
# 974                         TONY
# 975                        STEVE
# 976                         TONY
# 977                       JARVIS
# 978                         TONY
# 979                     REPORTER
# 980                     REPORTER
# 981                       JARVIS
# 982                      NATASHA
# 983                        STEVE
# 984                        STEVE
# 985                         THOR
# 986                         TONY
# 987                        STEVE
# 988                         TONY
# 989                         THOR
# 990                         TONY
# 991                         LOKI
# 992                MALE REPORTER
# 993                MALE REPORTER
# 994                 MALE CITIZEN
# 995               FEMALE CITIZEN
# 996                      HUSBAND
# 997                         WIFE
# 998                     STAN LEE
# 999                  THE SENATOR
# 1000                    REPORTER
# 1001                    WAITRESS
# 1002                    WAITRESS
# 1003                COUNCILMAN 2
# 1004                        FURY
# 1005                COUNCILWOMAN
# 1006                        FURY
# 1007                  COUNCILMAN
# 1008                        FURY
# 1009                  COUNCILMAN
# 1010                  COUNCILMAN
# 1011                        FURY
# 1012                COUNCILWOMAN
# 1013                COUNCILWOMAN
# 1014                        FURY
# 1015                        FURY
# 1016                  COUNCILMAN
# 1017                        FURY
# 1018                  MARIA HILL
# 1019                  MARIA HILL
# 1020                        FURY
# 1021                  MARIA HILL
# 1022                        FURY
# 1023                  MARIA HILL
# 1024                        FURY
# 1025                   THE OTHER
# 1026                   THE OTHER
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        line
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           The Tesseract has awakened. It is on a little world, a human world. They would wield its power.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 But our ally knows its workings as they never will. He is ready to lead. And our force...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...our Chitauri, will follow. The world will be his...the universe, yours. And the humans, what can they do but burn?
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                All personnel, evacuation order has been confirmed. Proceed to your designated vehicles...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...for all campus evacuation.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   This is not a drill. Emergency personnel proceed to your designated vehicles for all campus evacuation.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            How bad is it?
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   That’s the problem, sir. We don’t know.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Doctor Selvig read an...
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...energy surge from the Tesseract four hours ago.
# ...
# 1007                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  That’s not your call.
# 1008                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           I didn’t make it. I just didn’t argue with the god that did.
# 1009                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              So you let him take it...
# 1010                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     and the war criminal Loki, who should be answering for his crime.
# 1011                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Oh I think he will be.
# 1012                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    I don’t think you understand what you’ve started...
# 1013                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...letting The Avengers loose on this world. They’re dangerous.
# 1014                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        They surely are, and the whole world knows it.
# 1015                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Every world knows it!
# 1016                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Was that the point in all this? A statement.
# 1017                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             A promise.
# 1018                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Sir, how does it work now...?
# 1019                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...They’ve gone their separate ways, some pretty extremely far. We get into a situation like this again, what happens then?
# 1020                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     They’ll come back!
# 1021                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Really sure about that?
# 1022                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  I am.
# 1023                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Why?
# 1024                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Because we’ll need them to.
# 1025                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            The humans, they are not the cowering wretches we were promised. They stand. They are unruly and therefore cannot be ruled.
# 1026                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  To challenge them, is to court Death.
