# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Importing csv's

# %%
avengers_endgame = pd.read_csv("./cleaned/avengers_endgame.csv")
avengers = pd.read_csv("./cleaned/avengers.csv")
ragnorak = pd.read_csv("./cleaned/ragnorak.csv")
iron_man = pd.read_csv("./cleaned/iron_man.csv")
guardians2 = pd.read_csv("./cleaned/guardians_2.csv")
infinity_war = pd.read_csv("./cleaned/infinity_war.csv")
age_of_ultron = pd.read_csv("./cleaned/age_of_ultron.csv")
iron_man_2 = pd.read_csv("./cleaned/iron_man_2.csv")
iron_man_3 = pd.read_csv("./cleaned/iron_man_3.csv")
captain_america = pd.read_csv("./cleaned/captain_america.csv")
winter_soldier = pd.read_csv("./cleaned/winter_soldier.csv")
civil_war = pd.read_csv("./cleaned/civil_war.csv")
spider_man_homecoming = pd.read_csv("./cleaned/spider_man_homecoming.csv")
captain_marvel = pd.read_csv("./cleaned/captain_marvel.csv")
thor_dark_world = pd.read_csv("./cleaned/thor_dark_world.csv")
ant_man = pd.read_csv("./cleaned/ant_man.csv")
thor = pd.read_csv("./cleaned/thor.csv")
black_panther = pd.read_csv("./cleaned/black_panther.csv")

# %% [markdown]
# ## Adding a Movie Column

# %%
avengers_endgame["movie"] = "Avengers: Endgame"
avengers["movie"] = "The Avengers"
ragnorak["movie"] = "Thor: Ragnarok"
iron_man["movie"] = "Iron Man"
guardians2["movie"] = "Guardians of the Galaxy Vol. 2"
infinity_war["movie"] = "Avengers: Infinity War"
age_of_ultron["movie"] = "Avengers: Age of Ultron"
iron_man_2["movie"] = "Iron Man 2"
iron_man_3["movie"] = "Iron Man 3"
captain_america["movie"] = "Captain America: The First Avenger"
winter_soldier["movie"] = "Captain America: The Winter Soldier"
civil_war["movie"] = "Captain America: Civil War"
spider_man_homecoming["movie"] = "Spider-Man: Homecoming"
captain_marvel["movie"] = "Captain Marvel"
thor_dark_world["movie"] = "Thor: The Dark World"
ant_man["movie"] = "Ant-Man"
thor["movie"] = "Thor"
black_panther["movie"] = "Black Panther"

# %% [markdown]
# ## Adding Author Indicators

# %% [markdown]
# Indicator variables for if an author contributed to the screenplay that the line is from.  These names were taken from the Wikipedia articles for these movies.  The names used are listed in the right column in the "Screenplay By"  or "Written By" row.

# %%
avengers_endgame["Christopher Markus"] = True
avengers_endgame["Stephen McFeely"] = True

avengers["Joss Whedon"] = True

ragnorak["Eric Pearson"] = True
ragnorak["Craig Kyle"] = True
ragnorak["Christopher Yost"] = True

iron_man["Mark Fergus"] = True
iron_man["Hawk Ostby"] = True
iron_man["Art Marcum"] = True
iron_man["Matt Holloway"] = True

guardians2["James Gunn"] = True

infinity_war["Christopher Markus"] = True
infinity_war["Stephen McFeely"] = True

age_of_ultron["Joss Whedon"] = True

iron_man_2["Justin Theroux"] = True

iron_man_3["Shane Black"] = True
iron_man_3["Drew Pearce"] = True

captain_america["Christopher Markus"] = True
captain_america["Stephen McFeely"] = True

winter_soldier["Christopher Markus"] = True
winter_soldier["Stephen McFeely"] = True

civil_war["Christopher Markus"] = True
civil_war["Stephen McFeely"] = True

spider_man_homecoming["Jonathan Goldstein"] = True
spider_man_homecoming["John Francis Daley"] = True
spider_man_homecoming["Jon Watts"] = True
spider_man_homecoming["Christopher Ford"] = True
spider_man_homecoming["Chris McKenna"] = True
spider_man_homecoming["Erik Sommers"] = True

captain_marvel["Anna Boden"] = True
captain_marvel["Ryan Fleck"] = True
captain_marvel["Geneva Robertson-Dworet"] = True

thor_dark_world["Christopher Yost"] = True
thor_dark_world["Christopher Markus"] = True
thor_dark_world["Stephen McFeely"] = True

ant_man["Edgar Wright"] = True
ant_man["Joe Cornish"] = True
ant_man["Adam McKay"] = True
ant_man["Paul Rudd"] = True

thor["Ashley Edward Miller"] = True
thor["Zack Stentz"] = True
thor["Don Payne"] = True

black_panther["Ryan Coogler"] = True
black_panther["Joe Robert Cole"] = True

# %% [markdown]
# ## Adding a Year Column

# %%
avengers_endgame["year"] = 2019
avengers["year"] = 2012
ragnorak["year"] = 2017
iron_man["year"] = 2008
guardians2["year"] = 2017
infinity_war["year"] = 2018
age_of_ultron["year"] = 2015
iron_man_2["year"] = 2010
iron_man_3["year"] = 2013
captain_america["year"] = 2011
winter_soldier["year"] = 2014
civil_war["year"] = 2016
spider_man_homecoming["year"] = 2017
captain_marvel["year"] = 2019
thor_dark_world["year"] = 2013
ant_man["year"] = 2015
thor["year"] = 2011
black_panther["year"] = 2018

# %% [markdown]
# ## Specifying Duplicate Names

# %% [markdown]
# Some characters happen to have the same name as characters in a different movie, though they are not the same person.  This cell specifies the difference so that their lines aren't aggregated.  This won't really matter since these characters have so few lines anyway.

# %%
avengers_endgame['character'] = avengers_endgame['character'].replace(["JIMMY"],'AVENGERS JIMMY')
avengers_endgame['character'] = avengers_endgame['character'].replace(["KID"],'AVENGERS KID')
iron_man['character'] = iron_man['character'].replace(["JIMMY"],'IRON MAN JIMMY')
iron_man['character'] = iron_man['character'].replace(["MAN"],'PHIL COULSON')
iron_man['character'] = iron_man['character'].replace(["KID"],'IRON MAN KID')
spider_man_homecoming['character'] = spider_man_homecoming['character'].replace(["GARY"],'STAN LEE')

# %% [markdown]
# ## Creating a Combined DataFrame

# %%
combined = pd.concat([avengers_endgame, avengers, ragnorak, iron_man, guardians2, infinity_war, age_of_ultron, iron_man_2, 
                      iron_man_3, captain_america, winter_soldier, civil_war, spider_man_homecoming, captain_marvel, 
                      thor_dark_world, ant_man, thor, black_panther])

combined.fillna(False, inplace=True)

# %% [markdown]
# ## Removing Character Name Aliases

# %% [markdown]
# Some characters go by different names in different movies.  Also, some characters start out as `MYSTERIOUS MAN` and be revealed to be `EGO`.  This cell fixes that by assigning the same lines to the same name.  Some of these choices are subjective.  For example, I've decided that `HULK` is a different character than `BRUCE BANNER`, and that all reporter characters are named `REPORTER`.
#
# When adding a new movie to this dataset, **be careful** to see that the extra characters (`MAN`, `WOMAN`, `KID` etc.) are being assigned to who they actually are.  For example, in Iron Man, `MAN` is `AGENT COULSON`, but `MAN` could be somebody else in a different movie.

# %%
# Iron Man People
combined['character'].replace(['IRON MAN','TONY',"VOICE"],'TONY STARK', inplace=True)
combined['character'].replace(['PEPPER'],'PEPPER POTTS', inplace=True)
combined['character'].replace(["WOMAN’S VOICE"],'CHRISTINE', inplace=True)
combined['character'].replace(["GABRIEL"],'GENERAL GABRIEL', inplace=True)
combined['character'].replace(["HOGAN", "HAPPY"],'HAPPY HOGAN', inplace=True)
combined['character'].replace(["F.R.I.D.A.Y."],'FRIDAY', inplace=True)
combined['character'].replace(["OBADIAH"],'OBADIAH STANE', inplace=True)
combined['character'].replace(["RHODEY", "COLONEL JAMES RHODES"],'JAMES RHODES', inplace=True)
combined['character'].replace(["HOWARD"],'HOWARD STARK', inplace=True)
combined['character'].replace(["IVAN"],'IVAN VANKO', inplace=True)
combined['character'].replace(["JUSTIN", "TV JUSTIN"],'JUSTIN HAMMER', inplace=True)
combined['character'].replace(["STERN"],'SENATOR STERN', inplace=True)
combined['character'].replace(["CHRISTINE"],'CHRISTINE EVERHART', inplace=True)
combined['character'].replace(["MR MUSK"],'ELON MUSK', inplace=True)
combined['character'].replace(["ALRICH KILLIAN"],'ALDRICH KILLIAN', inplace=True)
combined['character'].replace(["CAMERAMAN"],'GARY', inplace=True)
combined['character'].replace(["SAVIN"],'ERIC SAVIN', inplace=True)
combined['character'].replace(["TAGGERT"],'JACK TAGGART', inplace=True)

# SHIELD People
combined['character'].replace(['BARTON'],'CLINT BARTON', inplace=True)
combined['character'].replace(['COULSON', 'AGENT COULSON', 'COULON'],'PHIL COULSON', inplace=True)
combined['character'].replace(['AGENT JASPER SITWELL', 'AGENT SITWELL', 'SITWELL'],'JAPSER SITWELL', inplace=True)
combined['character'].replace(["FURY"],'NICK FURY', inplace=True)
combined['character'].replace(["NATASHA", "NATALIE", "AGENT ROMANOFF", "NOTARY", "NATALIE/AGENT ROMANOFF"],'NATASHA ROMANOFF', inplace=True)

# Guardians of the Galaxy People
combined['character'].replace(['QUILL'],'PETER QUILL', inplace=True)
combined['character'].replace(['MONSTROUS RAVAGER'],'TASERFACE', inplace=True)
combined['character'].replace(['MYSTERIOUS MAN'],'EGO', inplace=True)
combined['character'].replace(["ADOLESCENT GROOT"],'GROOT', inplace=True)
combined['character'].replace(["MEREDITH"],'MEREDITH QUILL', inplace=True)
combined['character'].replace(["MEMORY GAMORA"],"GAMORA", inplace=True)
combined['character'].replace(["MEMORY NEBULA"],"NEBULA", inplace=True)

# Thor People
combined['character'].replace(['SCRAPPER #142'],'VALKYRIE', inplace=True)
combined['character'].replace(['LOKIE', 'LOKIS'],'LOKI', inplace=True)
combined['character'].replace(['SELVIG', "DR. ERIK SELVIG"],'ERIK SELVIG', inplace=True)
combined['character'].replace(['DARCY'],'DARCY LEWIS', inplace=True)
combined['character'].replace(['JANE'],'JANE FOSTER', inplace=True)
combined['character'].replace(["COLLECTOR'S ASSISTANT"],'CARINA', inplace=True)
combined['character'].replace(["ISABEL"],'ISABELA', inplace=True)
combined['character'].replace(["PETE"],'TOWNIE PETE', inplace=True)

# Captain America People
combined['character'].replace(['STEVE','CAPTAIN AMERICA', 'OLD STEVE', "STEVE ROGER"],'STEVE ROGERS', inplace=True)
combined['character'].replace(["HOODED FIGURE", "STONEKEEPER", "JOHAN SCHMIDT", "JOHANN SCHMIDT", "JOHAN SCHMIDT/RED SKULL"],'RED SKULL', inplace=True)
combined['character'].replace(['JAMES BARNES', "WINTER SOLDIER"],'BUCKY BARNES', inplace=True)
combined['character'].replace(['LIST'],'DR. LIST', inplace=True)
combined['character'].replace(['STRUCKER'],'BARON WOLFGANG VON STRUCKER', inplace=True)
combined['character'].replace(['MRS SPENCER'],'MRS. SPENCER', inplace=True)

#Spider Man People
combined['character'].replace(['AARON'],'AARON DAVIS', inplace=True)
combined['character'].replace(['ABE'],'ABRAHAM BROWN', inplace=True)
combined['character'].replace(['BETTY'],'BETTY BRANT', inplace=True)
combined['character'].replace(['BRICE'],'JACKSON BRICE', inplace=True)
combined['character'].replace(['CHARLES'],'CHARLES MURPHY', inplace=True)
combined['character'].replace(['CINDY'],'CINDY MOON', inplace=True)
combined['character'].replace(['DORIS'],'DORIS TOOMES', inplace=True)
combined['character'].replace(['LIZ'],'LIZ TOOMES', inplace=True)
combined['character'].replace(['TOOMES', "VULTURE"],'ADRIAN TOOMES', inplace=True)
combined['character'].replace(['FLASH'],'FLASH THOMPSON', inplace=True)
combined['character'].replace(['GARGAN'],'MAC GARGAN', inplace=True)
combined['character'].replace(['JASON'],'JASON IONELLO', inplace=True)
combined['character'].replace(['MASON'],'PHINEAS MASON', inplace=True)
combined['character'].replace(['MAY'],'MAY PARKER', inplace=True)
combined['character'].replace(['MICHELLE'],'MICHELLE "MJ" JONES', inplace=True)
combined['character'].replace(['NED'],'NED LEEDS', inplace=True)
combined['character'].replace(['PETER', 'PETER PETER'],'PETER PARKER', inplace=True)
combined['character'].replace(['SALLY'],'SALLY AVRIL', inplace=True)
combined['character'].replace(['SCHULTZ'],'HERMAN SCHULTZ', inplace=True)
combined['character'].replace(['TINY'],'BRIAN "TINY" MCKEEVER', inplace=True)
combined['character'].replace(['SUIT LADY'],'KAREN', inplace=True)

# Captain Marvel People
combined['character'].replace(["CAROL", "'VERS", "VERS", "CVERS"],"CAROL DANVERS", inplace=True)
combined['character'].replace(["LAWSON"],"WENDY LAWSON", inplace=True)
combined['character'].replace(["MARIA"],"MARIA RAMBEAU", inplace=True)
combined['character'].replace(["MONICA"],"MONICA RAMBEAU", inplace=True)
combined['character'].replace(["GENERAL TALOS"],"TALOS", inplace=True)

# Ant Man People
combined['character'].replace(["CARSON"],"MITCHELL CARSON", inplace=True)
combined['character'].replace(["PAXTON"],'JAMES "JIM" PAXTON', inplace=True)
combined['character'].replace(["SCOTT", "SCOT LANG"],'SCOTT LANG', inplace=True)
combined['character'].replace(["DR. HANK PYM"],'HANK PYM', inplace=True)

# Black Panther People
combined['character'].replace(["T’CHALLA", "KING T'CHALLA", "T' CHALLA"],"T'CHALLA", inplace=True)
combined['character'].replace(["KING T'CHAKA", "T' CHAKA"],"T'CHAKA", inplace=True)
combined['character'].replace(["NA.KIA"],"NAKIA", inplace=True)
combined['character'].replace(["GIOT"],"GRIOT", inplace=True)
combined['character'].replace(["JAMES"],"YOUNG ZURI", inplace=True)
combined['character'].replace(["KILLMONGER"],"N'JADAKA (KILLMONGER)", inplace=True)
combined['character'].replace(["KLAUE"],"ULYSSES KLAUE", inplace=True)
combined['character'].replace(["ROSS"],"EVERETT ROSS", inplace=True)
combined['character'].replace(["M' BAKU"],"M'BAKU", inplace=True)
combined['character'].replace(["N' JOBU"],"N'JOBU", inplace=True)
combined['character'].replace(["W' KABI"],"W'KABI", inplace=True)
combined['character'].replace(["OKOYE'S PROJECTION"],"OKOYE", inplace=True)
combined['character'].replace(["SHURI'S PROJECTION"],"SHURI", inplace=True)

# Other People
combined['character'].replace(['BANNER','SMART HULK', 'ASTRAL BANNER'],'BRUCE BANNER', inplace=True)
combined['character'].replace(['STRANGE', "DOCTOR STRANGE", "DR. STRANGE", "STEVEN STRANGE"],'STEPHEN STRANGE', inplace=True)
combined['character'].replace(["SCHOOL BUS DRIVER, STAN LEE", "LARRY", "FEDEX DRIVER STAN LEE", 
                                    "THIRSTY GAMBLER"],'STAN LEE', inplace=True)
combined['character'].replace(["WANDA"],"WANDA MAXIMOFF", inplace=True)
combined['character'].replace(["BARTON'S DAUGHTER"],"LILA BARTON", inplace=True)

# %%
unique_names = pd.DataFrame(combined["character"].value_counts())

unique_names.rename(columns={"character": "line count"}, inplace=True)
unique_names.reset_index(inplace=True)
unique_names.rename(columns={"index": "character"}, inplace=True)

unique_names["words"] = unique_names["character"].str.split(" ").str.len()
unique_names.sort_values(by=["words", "character"], inplace=True)

unique_names
# Out:
#                                            character  line count  words
# 231                                              ABU           5      1
# 315                                          ACCUSER           3      1
# 277                                          ADMIRAL           4      1
# 227                                            AGENT           5      1
# 338                                          AKIHIKO           3      1
# 366                                            ALETA           2      1
# 196                                           ALGRIM           7      1
# 621                                            ANNIE           1      1
# 589                                     ANNOUNCEMENT           1      1
# 245                                        ANNOUNCER           5      1
# 250                                         ATT-LASS           5      1
# 465                                          ATTACHE           1      1
# 603                                        ATTENDANT           1      1
# 106                                           AYESHA          23      1
# 427                                              AYO           2      1
# 601                                          BAILIFF           1      1
# 548                                        BARKEEPER           1      1
# 390                                        BARTENDER           2      1
# 357                                            BIKER           2      1
# 429                                   BITCHING-BETTY           2      1
# 596                                              BOR           1      1
# 423                                             BOTH           2      1
# 646                                              BOY           1      1
# 552                                            BRAHL           1      1
# 157                                           BRANDT          10      1
# 186                                        BRON-CHAR           8      1
# 355                                            BUCKY           2      1
# 642                                           CADETS           1      1
# 415                                           CARINA           2      1
# 289                                      CHAMBERMAID           3      1
# 442                                       CHARLIE-27           2      1
# 645                                      CHEERLEADER           1      1
# 219                                        COLLECTOR           5      1
# 207                                         COMPUTER           6      1
# 312                                           CONNIE           3      1
# 426                                          CONTROL           2      1
# 489                                         CORPORAL           1      1
# 144                                       COUNCILMAN          12      1
# 191                                     COUNCILWOMAN           7      1
# 495                                           CRAMER           1      1
# 537                                             CREW           1      1
# 235                                            CROWD           5      1
# 420                                        CUSTODIAN           2      1
# 152                                             DALE          11      1
# 86                                              DAVE          34      1
# 290                                        DETECTIVE           3      1
# 133                                         DIRECTOR          15      1
# 183                                           DOCTOR           8      1
# 27                                              DRAX         117      1
# 594                                           DRIVER           1      1
# 629                                           DURAND           1      1
# 33                                               EGO         103      1
# 273                                              EIR           4      1
# 130                                            EITRI          16      1
# 360                                            EMCEE           2      1
# 319                                             ERIN           3      1
# 630                                         FAMILIES           1      1
# 62                                           FANDRAL          63      1
# 171                                           FATHER           9      1
# 246                                            FRANK           5      1
# 80                                            FRIDAY          41      1
# 479                                           FRIEND           1      1
# 48                                            FRIGGA          76      1
# 269                                             GALE           4      1
# 16                                            GAMORA         197      1
# 117                                             GARY          20      1
# 195                                          GENERAL           7      1
# 263                                             GIRL           4      1
# 584                                        GOLDSTEIN           1      1
# 73                                       GRANDMASTER          48      1
# 154                                            GRIOT          10      1
# 98                                             GROOT          26      1
# 201                                            GUARD           6      1
# 377                                           GUARDS           2      1
# 592                                         HALF-NUT           1      1
# 409                                          HEATHER           2      1
# 57                                          HEIMDALL          68      1
# 67                                              HELA          57      1
# 134                                            HOGUN          15      1
# 76                                              HULK          45      1
# 466                                          HUSBAND           1      1
# 341                                           HUTTER           3      1
# 372                                              IAN           2      1
# 203                                          ISABELA           6      1
# 240                                             JACK           5      1
# 389                                              JAN           2      1
# 23                                            JARVIS         142      1
# 602                                      JASON/BETTY           1      1
# 574                                            JOTUN           1      1
# 51                                             KAREN          74      1
# 557                                           KHALID           1      1
# 158                                           KORATH          10      1
# 84                                              KORG          36      1
# 114                                          KRAGLIN          21      1
# 322                                             KREE           3      1
# 561                                            KURSE           1      1
# 90                                              KURT          29      1
# 116                                           LAUFEY          20      1
# 401                                        LIBRARIAN           2      1
# 443                                          LIMBANI           2      1
# 373                                            LINDA           2      1
# 579                                          LIZ/NED           1      1
# 8                                               LOKI         377      1
# 550                                       LOKI/STEVE           1      1
# 38                                              LUIS          86      1
# 91                                            M'BAKU          29      1
# 253                                             M.P.           4      1
# 314                                           MADDIE           3      1
# 384                                           MAIDEN           2      1
# 545                                        MAINFRAME           1      1
# 96                                          MALEKITH          26      1
# 127                                              MAN          17      1
# 541                                            MAN#1           1      1
# 518                                            MAN#2           1      1
# 551                                            MANDY           1      1
# 54                                            MANTIS          71      1
# 400                                         MARJORIE           2      1
# 194                                          MARSHAL           7      1
# 350                                         MARTINEX           2      1
# 556                                        MERCENARY           1      1
# 145                                        MINN-ERVA          12      1
# 226                                        MODERATOR           5      1
# 346                                           MOTHER           3      1
# 111                                           N'JOBU          22      1
# 49                                             NAKIA          75      1
# 139                                         NARRATOR          13      1
# 351                                            NAVID           2      1
# 37                                            NEBULA          88      1
# 482                                            NOVAR           1      1
# 276                                            NURSE           4      1
# 424                                             OBLO           2      1
# 20                                              ODIN         159      1
# 178                                          OFFICER           8      1
# 53                                             OKOYE          73      1
# 562                                          ORDERLY           1      1
# 344                                               PA           3      1
# 481                                          PATIENT           1      1
# 326                                           PEACHY           3      1
# 644                                           PEOPLE           1      1
# 363                                           PERSON           2      1
# 225                                            PILOT           5      1
# 211                                           POLICE           6      1
# 299                                            PRATT           3      1
# 586                                           PRIEST           1      1
# 469                                       PROPRIETOR           1      1
# 167                                          QUINJET           9      1
# 505                                          RAMIREZ           1      1
# 105                                          RAMONDA          23      1
# 286                                            RANDY           4      1
# 109                                             RAZA          23      1
# 310                                           RENATA           3      1
# 208                                         REPORTER           6      1
# 266                                            RETCH           4      1
# 100                                          RICHARD          24      1
# 14                                            ROCKET         246      1
# 265                                           ROEDER           4      1
# 161                                            RONAN          10      1
# 325                                            RONIN           3      1
# 432                                          SCANNER           2      1
# 267                                        SCHNEIDER           4      1
# 483                                        SCIENTIST           1      1
# 517                                         SCRAPPER           1      1
# 353                                          SCUDDER           2      1
# 251                                         SECURITY           5      1
# 288                                           SHAMAN           4      1
# 30                                             SHURI         113      1
# 633                                      SHURI/NAKIA           1      1
# 61                                               SIF          63      1
# 407                                           SKRULL           2      1
# 118                                           SKURGE          19      1
# 617                                         SOH-LARR           1      1
# 458                                          SOLDIER           1      1
# 367                                         SOLDIERS           2      1
# 222                                              SON           5      1
# 317                                            SOREN           3      1
# 160                                           STAKAR          10      1
# 318                                          STUDENT           3      1
# 428                                         STUDENTS           2      1
# 142                                           SURTUR          13      1
# 126                                          T'CHAKA          17      1
# 15                                          T'CHALLA         199      1
# 56                                             TALOS          70      1
# 110                                        TASERFACE          23      1
# 378                                             TECH           2      1
# 200                                           TECHIE           7      1
# 280                                       TECHNICIAN           4      1
# 26                                            THANOS         128      1
# 2                                               THOR         959      1
# 522                                      THOR/SELVIG           1      1
# 220                                              TOM           5      1
# 162                                            TOPAZ          10      1
# 580                                          TOURIST           1      1
# 364                                           TOWNIE           2      1
# 223                                            TULLK           5      1
# 480                                           TYCOON           1      1
# 44                                            ULTRON          81      1
# 35                                          VALKYRIE          97      1
# 380                                          VANESSA           2      1
# 45                                            VISION          81      1
# 591                                        VOICEMAIL           1      1
# 46                                          VOLSTAGG          80      1
# 101                                           W'KABI          24      1
# 388                                         WAITRESS           2      1
# 381                                           WARDEN           2      1
# 597                                             WIFE           1      1
# 189                                            WOMAN           8      1
# 149                                             WONG          11      1
# 404                                           WORKER           2      1
# 66                                            YINSEN          59      1
# 39                                          YON-ROGG          85      1
# 43                                             YONDU          82      1
# 620                                           ZRINKA           1      1
# 92                                              ZURI          28      1
# 198                                        4F DOCTOR           7      2
# 519                                     911 OPERATOR           1      2
# 359                                          A1 HULK           2      2
# 411                                       A1 NATASHA           2      2
# 174                                         A1 STEVE           8      2
# 206                                          A1 THOR           6      2
# 343                                          A1 TONY           3      2
# 107                                      AARON DAVIS          23      2
# 165                                    ABRAHAM BROWN          10      2
# 150                                       ACTOR LOKI          11      2
# 334                                       ACTOR ODIN           3      2
# 520                                        ACTOR SIF           1      2
# 143                                       ACTOR THOR          12      2
# 173                                 ADMISSIONS NURSE           8      2
# 29                                     ADRIAN TOOMES         113      2
# 302                                       AGENT CALE           3      2
# 614                                   AGENT DELANCEY           1      2
# 323                                    AGENT GARRETT           3      2
# 507                                    AGENT JACKSON           1      2
# 58                                   ALDRICH KILLIAN          67      2
# 63                                  ALEXANDER PIERCE          62      2
# 305                                      ALPHA GUARD           3      2
# 99                                       ANCIENT ONE          25      2
# 392                                      ANTON VANKO           2      2
# 283                                   APPLE EMPLOYEE           4      2
# 444                                   ARMY HECKLER#1           2      2
# 553                                   ARMY HECKLER#2           1      2
# 476                                   ARMY HECKLER#3           1      2
# 536                                   ARMY HECKLER#4           1      2
# 529                               ASGARDIAN CITIZENS           1      2
# 576                              ASGARDIAN EINHERJAR           1      2
# 585                                    ASGARDIAN MAN           1      2
# 547                                  ASGARDIAN NURSE           1      2
# 608                                     ASGARDIAN PA           1      2
# 477                                  ASGARDIAN WOMAN           1      2
# 496                                   AVENGERS JIMMY           1      2
# 472                                     AVENGERS KID           1      2
# 108                                       BAD NEBULA          23      2
# 567                                BALLET INSTRUCTOR           1      2
# 421                                       BBC ANCHOR           2      2
# 172                                      BETTY BRANT           9      2
# 531                                       BILL MAHER           1      2
# 493                                     BORDER TRIBE           1      2
# 243                                    BRANDT’S AIDE           5      2
# 71                                      BROCK RUMLOW          51      2
# 6                                       BRUCE BANNER         399      2
# 28                                      BUCKY BARNES         114      2
# 578                                       CAB DRIVER           1      2
# 487                                   CALCUTTA WOMAN           1      2
# 410                                       CAR JACKER           2      2
# 13                                     CAROL DANVERS         250      2
# 94                                       CASSIE LANG          26      2
# 514                                       CHAD DAVIS           1      2
# 146                                   CHARLES MURPHY          11      2
# 252                                       CHARLIE XO           4      2
# 87                                CHRISTINE EVERHART          33      2
# 459                                        CIA AGENT           1      2
# 210                                       CINDY MOON           6      2
# 17                                      CLINT BARTON         197      2
# 258                                     COACH WILSON           4      2
# 321                             COMMERCIAL ANNOUNCER           3      2
# 337                                COMMITTEE GENERAL           3      2
# 379                                   COMPUTER VOICE           2      2
# 272                                    CORVUS GLAIVE           4      2
# 540                                     COUNCILMAN 2           1      2
# 566                                COUNCILMAN HAWLEY           1      2
# 166                              COUNCILMAN ROCKWELL           9      2
# 268                                 COUNCILMAN SINGH           4      2
# 434                                   COUNCILMAN YEN           2      2
# 436                              COUNCILWOMAN HAWLEY           2      2
# 391                                     COUSIN CARLO           2      2
# 635                                    CULL OBSIDIAN           1      2
# 31                                       DARCY LEWIS         111      2
# 68                                      DARREN CROSS          56      2
# 607                                      DAY SLEEPER           1      2
# 412                                   DECATHLON TEAM           2      2
# 448                                       DELI CLERK           2      2
# 335                                     DESK OFFICER           3      2
# 484                                        DOCTOR #1           1      2
# 431                                       DODC AGENT           2      2
# 474                                     DODC CENTRAL           1      2
# 473                                      DODC DRIVER           1      2
# 394                                DODGERS ANNOUNCER           2      2
# 622                                     DOME CONTROL           1      2
# 138                                     DORIS TOOMES          13      2
# 169                                         DR. LIST           9      2
# 509                                 DRILL INSTRUCTOR           1      2
# 238                                     DRUNK TOWNIE           5      2
# 417                                     EAGER TOWNIE           2      2
# 95                                         EBONY MAW          26      2
# 408                                     EDWIN JARVIS           2      2
# 242                                  EINHERJAR GUARD           5      2
# 425                             EINHERJAR LIEUTENANT           2      2
# 418                                    ELDERLY WOMAN           2      2
# 494                            ELECTRONIC VOICE-OVER           1      2
# 478                                        ELK RIDGE           1      2
# 294                                        ELON MUSK           3      2
# 460                                   ENLISTMENT GUY           1      2
# 113                                       ERIC SAVIN          21      2
# 25                                       ERIK SELVIG         129      2
# 50                                      EVERETT ROSS          74      2
# 521                                   EXPO ANNOUNCER           1      2
# 526                                   FACELESS PILOT           1      2
# 648                                 FACILITY MANAGER           1      2
# 525                                   FEMALE CITIZEN           1      2
# 398                                     FEMALE NURSE           2      2
# 97                                    FLASH THOMPSON          26      2
# 262                                 FORTRESS SOLDIER           4      2
# 475                                FRENCH AMBASSADOR           1      2
# 247                                    FRENCH PIRATE           5      2
# 405                                 FRIGHTENED PILOT           2      2
# 136                                       FURY'S CAR          14      2
# 180                                       GABE JONES           8      2
# 492                                  GAMORA'S MOTHER           1      2
# 168                                  GENERAL GABRIEL           9      2
# 399                                   GEORGES BATROC           2      2
# 190                                   GEORGI LUCHKOV           7      2
# 209                                 GERMAN INNKEEPER           6      2
# 260                                    GILMORE HODGE           4      2
# 506                              GOVERNMENT EMPLOYEE           1      2
# 498                                    GRANDPA QUILL           1      2
# 259                                     GRIEVING MAN           4      2
# 539                                     GSG-9 DRIVER           1      2
# 307                                    GSG-9 SOLDIER           3      2
# 438                                         GUARD #1           2      2
# 192                                         GUARD #2           7      2
# 21                                          HANK PYM         154      2
# 19                                       HAPPY HOGAN         169      2
# 439                                    HAPPY'S NURSE           2      2
# 70                                     HARLEY KEENER          53      2
# 264                                    HEAD ENGINEER           4      2
# 316                                     HEINZ KRUGER           3      2
# 590                             HELICARRIER INTERCOM           1      2
# 79                                       HELMUT ZEMO          41      2
# 89                                    HERMAN SCHULTZ          30      2
# 396                                   HIDEOUS RABBIT           2      2
# 354                                  HISTORY TEACHER           2      2
# 278                                        HO YINSEN           4      2
# 59                                      HOWARD STARK          65      2
# 356                                   HYDRA DISPATCH           2      2
# 533                                     HYDRA GUARDS           1      2
# 402                                 HYDRA LIEUTENANT           2      2
# 564                                    HYDRA SOLDIER           1      2
# 588                                HYDRA TECHNICIANS           1      2
# 104                                      IAN BOOTHBY          23      2
# 155                                   INTERCOM VOICE          10      2
# 233                                      IRON LEGION           5      2
# 83                                        IVAN VANKO          37      2
# 437                                  JABARI WARRIORS           2      2
# 605                                     JACK ROLLINS           1      2
# 224                                     JACK TAGGART           5      2
# 119                                    JACKSON BRICE          19      2
# 568                                  JACQUES DERNIER           1      2
# 10                                      JAMES RHODES         332      2
# 12                                       JANE FOSTER         269      2
# 148                                   JAPSER SITWELL          11      2
# 600                                   JAQUES DERNIER           1      2
# 244                                    JASON IONELLO           5      2
# 112                                   JASPER SITWELL          22      2
# 358                                        JET PILOT           2      2
# 175                                       JIM MORITA           8      2
# 515                                      JOAN RIVERS           1      2
# 471                                   JOSEPH DANVERS           1      2
# 634                                     JOTUN SENTRY           1      2
# 599                                      JOTUN VOICE           1      2
# 40                                     JUSTIN HAMMER          84      2
# 349                                KLAUE'S MERCENARY           2      2
# 122                                     LAURA BARTON          18      2
# 320                                    LEAD SCRAPPER           3      2
# 228                                      LILA BARTON           5      2
# 604                                       LITTLE BOY           1      2
# 47                                        LIZ TOOMES          78      2
# 332                                        LOUD JERK           3      2
# 485                                       MAC GARGAN           1      2
# 254                                         MADAME B           4      2
# 129                                      MAGGIE LANG          16      2
# 627                                  MAINTENANCE GUY           1      2
# 115                                      MAJOR ALLEN          21      2
# 284                                       MALE AGENT           4      2
# 544                                     MALE CITIZEN           1      2
# 271                                       MALE NURSE           4      2
# 352                                    MALE REPORTER           2      2
# 527                                       MALE VOICE           1      2
# 528                                MANDARIN LOOK-OUT           1      2
# 41                                        MARIA HILL          84      2
# 75                                     MARIA RAMBEAU          45      2
# 213                                      MARIA STARK           6      2
# 72                                        MAY PARKER          49      2
# 60                                       MAYA HANSEN          65      2
# 281                                 MEDICAL EXAMINER           4      2
# 416                                     MERCENARY #1           2      2
# 571                                     MERCENARY #2           1      2
# 217                                   MEREDITH QUILL           6      2
# 313                                  MILITANT LEADER           3      2
# 328                                    MILITARY AIDE           3      2
# 333                                      MIT TEACHER           3      2
# 170                                  MITCHELL CARSON           9      2
# 93                                    MONICA RAMBEAU          27      2
# 140                                     MORGAN STARK          13      2
# 555                                     MR. COBBWELL           1      2
# 159                                       MR. DELMAR          10      2
# 623                                      MR. HAPGOOD           1      2
# 128                                   MR. HARRINGTON          16      2
# 204                                       MRS. DAVIS           6      2
# 212                                     MRS. SPENCER           6      2
# 202                                       MS. WARREN           6      2
# 508                                    MUFFLED VOICE           1      2
# 185                                  MUSEUM DIRECTOR           8      2
# 55                             N'JADAKA (KILLMONGER)          70      2
# 524                                   NASA SCIENTIST           1      2
# 4                                   NATASHA ROMANOFF         519      2
# 22                                         NED LEEDS         150      2
# 218                                      NEWS ANCHOR           6      2
# 375                                      NEWS READER           2      2
# 179                                    NEWS REPORTER           8      2
# 7                                          NICK FURY         399      2
# 618                                   NIGERIAN WOMAN           1      2
# 52                                     OBADIAH STANE          73      2
# 387                                       OFFICER #2           2      2
# 470                               OFFICER FITZGIBBON           1      2
# 532                                          OLD MAN           1      2
# 486                                        OLDER MAN           1      2
# 292                                      PARK RANGER           3      2
# 422                                      PARTY GUEST           2      2
# 34                                      PEGGY CARTER          98      2
# 5                                       PEPPER POTTS         459      2
# 371                               PEPPER'S ASSISTANT           2      2
# 3                                       PETER PARKER         700      2
# 11                                       PETER QUILL         312      2
# 24                                      PHIL COULSON         132      2
# 82                                     PHINEAS MASON          38      2
# 102                                  PIETRO MAXIMOFF          24      2
# 188                                   POLICE OFFICER           8      2
# 595                                     POLICE RADIO           1      2
# 261                                  POLICE SERGEANT           4      2
# 151                                  PRESIDENT ELLIS          11      2
# 249                                 PRINCIPAL MORITA           5      2
# 184                                 PROXIMA MIDNIGHT           8      2
# 232                                    PVT. LORRAINE           5      2
# 468                                    QUINJET PILOT           1      2
# 612                                     RANDOM WOMAN           1      2
# 65                                         RED SKULL          60      2
# 440                                      REPORTER #2           2      2
# 499                                      REPORTER #3           1      2
# 500                                       RESIDENT 1           1      2
# 637                                       RESIDENT 2           1      2
# 309                                         ROBBER 1           3      2
# 616                                         ROBBER 2           1      2
# 450                                         ROBBER 3           1      2
# 570                                         ROBBER 4           1      2
# 324                                      SALLY AVRIL           3      2
# 18                                        SAM WILSON         180      2
# 433                                     SCIENTIST #1           2      2
# 9                                         SCOTT LANG         357      2
# 534                               SCURRILOUS RAVAGER           1      2
# 457                                     SECOND GUARD           1      2
# 88                                    SECRETARY ROSS          31      2
# 293                              SECURITY CHECKPOINT           3      2
# 640                                   SECURITY CHIEF           1      2
# 125                                   SECURITY GUARD          17      2
# 393                                 SECURITY OFFICER           2      2
# 153                                   SENATOR BRANDT          11      2
# 85                                     SENATOR STERN          34      2
# 257                                   SERGEANT DUFFY           4      2
# 78                                     SHARON CARTER          41      2
# 137                                     SHIELD AGENT          14      2
# 141                                  SHIELD COMPUTER          13      2
# 490                                  SHIELD ENGINEER           1      2
# 205                                SHIELD LIEUTENANT           6      2
# 572                                     SHIELD PILOT           1      2
# 214                                      SHIELD TECH           6      2
# 403                                    SHIELD WORKER           2      2
# 187                                 SKRULL SCIENTIST           8      2
# 445                                      SKRULL TECH           2      2
# 560                                SMITHSONIAN GUARD           1      2
# 181                                   SOOTHING VOICE           8      2
# 467                                  SOVEREIGN PILOT           1      2
# 610                                  SPANISH TEACHER           1      2
# 581                                       SSR DOCTOR           1      2
# 135                                         STAN LEE          14      2
# 535                                STARK'S ASSISTANT           1      2
# 361                                 STARK’S ENGINEER           2      2
# 42                                   STEPHEN STRANGE          83      2
# 1                                       STEVE ROGERS        1024      2
# 221                                   STRAWBERRY MAN           5      2
# 311                                    STREET VENDOR           3      2
# 304                                     STRIKE AGENT           3      2
# 121                             SUPREME INTELLIGENCE          18      2
# 452                                     TALL RAVAGER           1      2
# 501                                      TAXI DRIVER           1      2
# 631                                        TENT KIDS           1      2
# 502                                     TEXT MESSAGE           1      2
# 414                                      THAI WAITER           2      2
# 176                                    THE COLLECTOR           8      2
# 131                                     THE MANDARIN          16      2
# 164                                        THE OTHER          10      2
# 649                                      THE SENATOR           1      2
# 546                                  THOMAS RICHARDS           1      2
# 0                                         TONY STARK        1976      2
# 308                                       TOUR GUIDE           3      2
# 193                                     TOWER KEEPER           7      2
# 339                                      TOWNIE PETE           3      2
# 124                                  TREVOR SLATTERY          17      2
# 69                                     ULYSSES KLAUE          55      2
# 376                                       UN STAFFER           2      2
# 456                                         USO GIRL           1      2
# 216                                       USO SINGER           6      2
# 147                                    VASILY KARPOV          11      2
# 455                                    VERS' BROTHER           1      2
# 215                                   VICE PRESIDENT           6      2
# 182                                          VIPER 1           8      2
# 199                                          VIPER 2           7      2
# 609                                   WAKANDAN CHILD           1      2
# 463                                WAKANDAN CHILDREN           1      2
# 32                                    WANDA MAXIMOFF         108      2
# 582                                    WEASELLY THUG           1      2
# 103                                     WENDY LAWSON          23      2
# 300                                        YOUNG BOY           3      2
# 446                                        YOUNG COP           2      2
# 365                                     YOUNG DOCTOR           2      2
# 285                                     YOUNG GAMORA           4      2
# 291                                       YOUNG GIRL           3      2
# 279                                 YOUNG KILLMONGER           4      2
# 163                                    YOUNG T'CHAKA          10      2
# 241                                       YOUNG ZURI           5      2
# 369                                      ZEMO'S WIFE           2      2
# 641                                  A1 CLINT BARTON           1      3
# 229                                  ANNE MARIE HOAG           5      3
# 624                              ANTIQUE STORE OWNER           1      3
# 611                           BORDER TRIBE COMMANDER           1      3
# 419                               BORDER TRIBE ELDER           2      3
# 342                            BRIAN "TINY" MCKEEVER           3      3
# 513                             CARGO TRUCK MILITANT           1      3
# 237                             CHARLIE WEAPONS TECH           5      3
# 64                             COL. CHESTER PHILLIPS          60      3
# 430                                   COLLEGE GIRL 1           2      3
# 382                                   COLLEGE GIRL 2           2      3
# 256                                      COM TECH #1           4      3
# 297                                      COM TECH #2           3      3
# 625                                   COP ON SPEAKER           1      3
# 270                            DELIVERY TRUCK DRIVER           4      3
# 330                                    DORA MILAJE 1           3      3
# 81                               DR. ABRAHAM ERSKINE          41      3
# 77                                    DR. ARNIM ZOLA          44      3
# 123                                    DR. HELEN CHO          18      3
# 239                                DRUNK TOWNIE JAKE           5      3
# 510                                  DUBAI BEAUTY #1           1      3
# 156                                    DUM DUM DUGAN          10      3
# 638                           ELDERS, WARRIORS, DORA           1      3
# 348                                      FBI AGENT 1           3      3
# 549                                      FBI AGENT 2           1      3
# 282                              FEMALE SHIELD AGENT           4      3
# 331                               FEMALE WAR VETERAN           3      3
# 197                                 FRENCH PIRATE #1           7      3
# 542                                 FRENCH PIRATE #2           1      3
# 558                                   FURY AND MARIA           1      3
# 345                                  GEF THE RAVAGER           3      3
# 362                                   GERMAN OLD MAN           2      3
# 615                           GOVERNMENT OFFICIAL #1           1      3
# 370                           GOVERNMENT OFFICIAL #2           2      3
# 451                            HAMMER SECURITY GUARD           1      3
# 36                                     HOPE VAN DYNE          93      3
# 619                           HOSPITAL NEWS REPORTER           1      3
# 275                                   IRON MAN JIMMY           4      3
# 488                                     IRON MAN KID           1      3
# 74                                JAMES "JIM" PAXTON          46      3
# 177                       JAMES MONTGOMERY FALSWORTH           8      3
# 503                                     MAN IN CROWD           1      3
# 413                                        MAN ON PA           2      3
# 491                                  MAN ON SPEAKERS           1      3
# 374                             MERCHANT TRIBE ELDER           2      3
# 120                              MICHELLE "MJ" JONES          19      3
# 230                               MINING TRIBE ELDER           5      3
# 406                                   NEWS ANCHOR #1           2      3
# 651                                   NEWS ANCHOR #2           1      3
# 516                                   NEWS ANCHOR #3           1      3
# 296                                   NEWS ANCHOR #4           3      3
# 632                                   NEWS ANCHOR #5           1      3
# 530                                 NEWS REPORTER #1           1      3
# 593                                 NEWS REPORTER #2           1      3
# 538                                 NEWS REPORTER #3           1      3
# 449                                 NEWS REPORTER #4           1      3
# 386                             NIGERIAN MILITANT #2           2      3
# 255                                   OAKLAND KID #1           4      3
# 336                                   OAKLAND KID #2           3      3
# 295                                   OAKLAND KID #3           3      3
# 598                                OFF SCREEN WORKER           1      3
# 575                            OLD FOOTAGE RECORDING           1      3
# 639                                  PET STORE CLERK           1      3
# 329                                POLICE OFFICER #1           3      3
# 347                                POLICE OFFICER #2           3      3
# 573                                     POOL BBQ DAD           1      3
# 462                           PUSHY TABLOID REPORTER           1      3
# 523                                PYM TECH EMPLOYEE           1      3
# 447                                     REPORTER # 1           2      3
# 287                                RIVER TRIBE ELDER           4      3
# 234                               ROSE HILLS SHERIFF           5      3
# 248                               SEARCH TEAM LEADER           5      3
# 565                                  SHIELD AGENT #1           1      3
# 340                                  SHIELD AGENT #2           3      3
# 512                                  SHIELD AGENT #3           1      3
# 647                            SOMEONE IN BACKGROUND           1      3
# 383                              SOUTH AFRICAN TOUGH           2      3
# 327                         SPECIALIST CAMERON KLEIN           3      3
# 554                                  STRIKE AGENT #1           1      3
# 583                                  STRIKE AGENT #2           1      3
# 613                                  STRIKE AGENT #3           1      3
# 274                         THE SMITHSONIAN NARRATOR           4      3
# 626                                    THOR / BANNER           1      3
# 298                              TV REPORTER’S VOICE           3      3
# 587                                 VIDEO VOICE OVER           1      3
# 504                              VOICE FROM EARPIECE           1      3
# 643                                 VOLSTAGG / HOGUN           1      3
# 650                                    WEIRD OLD MAN           1      3
# 497                                   WOMAN IN CROWD           1      3
# 397                                      WOMAN ON PA           2      3
# 435                                   WOMAN ON TRAIN           2      3
# 563                                   WORLD HUB TECH           1      3
# 306                                  YOUNG BLACK KID           3      3
# 385                               YOUNG SHIELD PILOT           2      3
# 303                                   YOUNG T' CHAKA           3      3
# 236                                 YOUNG TONY STARK           5      3
# 511                          25TH FLOOR STRIKE AGENT           1      4
# 132                      BARON WOLFGANG VON STRUCKER          16      4
# 368                            CARRIER BRIDGE TECH 1           2      4
# 441                       FEMALE CARRIER BRIDGE TECH           2      4
# 301                         ICE CREAM STORE CUSTOMER           3      4
# 454                              KID IN THE BACKSEAT           1      4
# 453                             KIDS IN USO AUDIENCE           1      4
# 569                                     MAN ON PA #1           1      4
# 628                                     MAN ON PA #2           1      4
# 577                                 MAN ON THE RADIO           1      4
# 559                              PYM TECH GATE GUARD           1      4
# 395                          PYM TECH SECURITY GUARD           2      4
# 461                      STONEHENGE TV NEWS REPORTER           1      4
# 464                         JOSEF / SUPER SOLDIER #1           1      5
# 606                 ROSE HILL CHRISTMAS TREE SHOPPER           1      5
# 636                PRETTY MUCH EVERYONE IN THE CROWD           1      6
# 543  VERS, BRON-CHAR, KORATH, MINN-ERVA AND ATT-LASS           1      6

# %%
unique_names[unique_names["character"].str.contains("SHIELD", regex=True)]
# Out:
#                character  line count  words
# 137         SHIELD AGENT          14      2
# 141      SHIELD COMPUTER          13      2
# 490      SHIELD ENGINEER           1      2
# 205    SHIELD LIEUTENANT           6      2
# 572         SHIELD PILOT           1      2
# 214          SHIELD TECH           6      2
# 403        SHIELD WORKER           2      2
# 282  FEMALE SHIELD AGENT           4      3
# 565      SHIELD AGENT #1           1      3
# 340      SHIELD AGENT #2           3      3
# 512      SHIELD AGENT #3           1      3
# 385   YOUNG SHIELD PILOT           2      3

# %% [markdown]
# ## Adding a Words Column

# %% [markdown]
# Be aware, elipses and dashes aren't guaranteed to be counted as their own word.  For example, `down...bow` from the opening scene of Avengers Endgame might be counted as 1 word.  The same thing can happen with This shouldn't happen.  This might need to be corrected when constructing models.

# %%
combined["words"] = combined["line"].str.split(" ").str.len()

# %% [markdown]
# ## Exporting mcu.csv

# %%
column_order = ["character", "line", "movie", "year", "words", 
                'Adam McKay', 'Anna Boden', 'Art Marcum', 'Ashley Edward Miller', 'Chris McKenna', 'Christopher Ford',
                'Christopher Markus', 'Christopher Yost', 'Craig Kyle', 'Don Payne', 'Drew Pearce', 'Edgar Wright',
                'Eric Pearson', 'Erik Sommers', 'Geneva Robertson-Dworet', 'Hawk Ostby', 'James Gunn', 'Joe Cornish',
                'Joe Robert Cole', 'John Francis Daley', 'Jon Watts', 'Jonathan Goldstein', 'Joss Whedon', 
                'Justin Theroux', 'Mark Fergus', 'Matt Holloway', 'Paul Rudd', 'Ryan Coogler', 'Ryan Fleck', 'Shane Black',
                'Stephen McFeely', 'Zack Stentz']

combined = combined[column_order]
#combined.astype('int32', copy=False)

combined.to_csv("./mcu.csv")

combined.head()
# Out:
#       character  \
# 0  CLINT BARTON
# 1  CLINT BARTON
# 2   LILA BARTON
# 3  CLINT BARTON
# 4  LAURA BARTON
#
#                                                                 line  \
# 0  Okay, you see where you’re going? Let’s work on how to get there.
# 1              Okay, good...tip down...bow arm out...three fingers-
# 2                                                         Why three?
# 3                       ‘Cause two’s not enough and four’s too much-
# 4                            You guys want mustard or mayo, or both?
#
#                movie  year  words  Adam McKay  Anna Boden  Art Marcum  \
# 0  Avengers: Endgame  2019     13       False       False       False
# 1  Avengers: Endgame  2019      7       False       False       False
# 2  Avengers: Endgame  2019      2       False       False       False
# 3  Avengers: Endgame  2019      8       False       False       False
# 4  Avengers: Endgame  2019      8       False       False       False
#
#    Ashley Edward Miller  Chris McKenna  ...  Joss Whedon  Justin Theroux  \
# 0                 False          False  ...        False           False
# 1                 False          False  ...        False           False
# 2                 False          False  ...        False           False
# 3                 False          False  ...        False           False
# 4                 False          False  ...        False           False
#
#    Mark Fergus  Matt Holloway  Paul Rudd  Ryan Coogler  Ryan Fleck  \
# 0        False          False      False         False       False
# 1        False          False      False         False       False
# 2        False          False      False         False       False
# 3        False          False      False         False       False
# 4        False          False      False         False       False
#
#    Shane Black  Stephen McFeely  Zack Stentz
# 0        False             True        False
# 1        False             True        False
# 2        False             True        False
# 3        False             True        False
# 4        False             True        False
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Movie Metadata Table

# %%
movies = pd.DataFrame()

movies = movies.append(pd.Series({"movie": "Avengers: Endgame", "year": 2019, "is transcript": False, "lines": avengers_endgame.shape[0], "url": "https://www.scriptslug.com/assets/uploads/scripts/avengers-endgame-2019.pdf"}), ignore_index=True)
movies = movies.append(pd.Series({"movie": "The Avengers", "year": 2012, "is transcript": False, "lines": avengers.shape[0], "url": "https://www.scriptslug.com/assets/uploads/scripts/the-avengers-2012.pdf"}), ignore_index=True)
movies = movies.append(pd.Series({"movie": "Thor: Ragnorak", "year": 2017, "is transcript": False, "lines": ragnorak.shape[0], "url" : "https://www.scriptslug.com/assets/uploads/scripts/thor-ragnorak-2017.pdf"}), ignore_index=True)
movies = movies.append(pd.Series({"movie": "Iron Man", "year": 2008, "is transcript": False, "lines": iron_man.shape[0], "url": "https://www.scriptslug.com/assets/uploads/scripts/iron-man-2008.pdf"}), ignore_index=True)
movies = movies.append(pd.Series({"movie": "Guardians of the Galaxy Vol. 2", "year": 2017, "is transcript": False, "lines": guardians2.shape[0], "url" : "https://www.scriptslug.com/assets/uploads/scripts/guardians-of-the-galaxy-vol-2-2017.pdf"}), ignore_index=True)
movies = movies.append(pd.Series({"movie": "Avengers: Infinity War", "year": 2018, "is transcript": True, "lines": infinity_war.shape[0], "url" : "https://transcripts.fandom.com/wiki/Avengers:_Infinity_War"}), ignore_index=True)
movies = movies.append(pd.Series({"movie": "Avengers: Age of Ultron", "year": 2015, "is transcript": True, "lines": age_of_ultron.shape[0], "url" : "https://transcripts.fandom.com/wiki/Avengers:_Age_of_Ultron"}), ignore_index=True)
movies = movies.append(pd.Series({"movie": "Iron Man 2", "year": 2010, "is transcript": True, "lines": iron_man_2.shape[0], "url" : "https://transcripts.fandom.com/wiki/Iron_Man_2"}), ignore_index=True)
movies = movies.append(pd.Series({"movie": "Iron Man 3", "year": 2013, "is transcript": True, "lines": iron_man_3.shape[0], "url" : "https://transcripts.fandom.com/wiki/Iron_Man_3"}), ignore_index=True)
movies = movies.append(pd.Series({"movie": "Captain America: The First Avenger", "year": 2011, "is transcript": True, "lines": captain_america.shape[0], "url" : "https://transcripts.fandom.com/wiki/Captain_America:_The_First_Avenger"}), ignore_index=True)
movies = movies.append(pd.Series({"movie": "Captain America: The Winter Soldier", "year": 2014, "is transcript": True, "lines": winter_soldier.shape[0], "url" : "https://transcripts.fandom.com/wiki/Captain_America:_The_Winter_Soldier"}), ignore_index=True)
movies = movies.append(pd.Series({"movie": "Captain America: Civil War", "year": 2016, "is transcript": True, "lines": civil_war.shape[0], "url" : "https://transcripts.fandom.com/wiki/Captain_America:_Civil_War"}), ignore_index=True)
movies = movies.append(pd.Series({"movie": "Spider-Man: Homecoming", "year": 2017, "is transcript": True, "lines": spider_man_homecoming.shape[0], "url" : "https://transcripts.fandom.com/wiki/Spider-Man:_Homecoming"}), ignore_index=True)
movies = movies.append(pd.Series({"movie": "Captain Marvel", "year": 2019, "is transcript": True, "lines": captain_marvel.shape[0], "url" : "https://transcripts.fandom.com/wiki/Captain_Marvel_(2019)"}), ignore_index=True)
movies = movies.append(pd.Series({"movie": "Thor: The Dark World", "year": 2013, "is transcript": True, "lines": thor_dark_world.shape[0], "url" : "https://transcripts.fandom.com/wiki/Thor:_The_Dark_World"}), ignore_index=True)
movies = movies.append(pd.Series({"movie": "Ant-Man", "year": 2015, "is transcript": True, "lines": ant_man.shape[0], "url" : "https://transcripts.fandom.com/wiki/Ant-Man"}), ignore_index=True)
movies = movies.append(pd.Series({"movie": "Thor", "year": 2011, "is transcript": False, "lines": thor.shape[0], "url" : "https://www.scriptslug.com/assets/uploads/scripts/thor-2011.pdf"}), ignore_index=True)
movies = movies.append(pd.Series({"movie": "Black Panther", "year": 2018, "is transcript": False, "lines": black_panther.shape[0], "url" : "https://www.scriptslug.com/assets/uploads/scripts/black-panther-2018.pdf"}), ignore_index=True)

movies.set_index('movie', inplace=True)
movies["is transcript"] = movies['is transcript'].astype('boolean', copy=False)
movies["lines"] = movies['lines'].astype('int64', copy=False)
movies["year"] = movies['year'].astype('int64', copy=False)

movies.sort_values(by="year", inplace=True)

movies.to_csv("./movies.csv")

movies
# Out:
#                                      is transcript  lines  \
# movie
# Iron Man                                     False    834
# Iron Man 2                                    True   1010
# Thor                                         False   1007
# Captain America: The First Avenger            True    688
# The Avengers                                 False   1027
# Iron Man 3                                    True   1043
# Thor: The Dark World                          True    734
# Captain America: The Winter Soldier           True    841
# Ant-Man                                       True    867
# Avengers: Age of Ultron                       True    980
# Captain America: Civil War                    True    987
# Thor: Ragnorak                               False    961
# Guardians of the Galaxy Vol. 2               False    993
# Spider-Man: Homecoming                        True   1558
# Black Panther                                False    834
# Avengers: Infinity War                        True    990
# Captain Marvel                                True    775
# Avengers: Endgame                            False   1229
#
#                                                                                                                           url  \
# movie
# Iron Man                                                  https://www.scriptslug.com/assets/uploads/scripts/iron-man-2008.pdf
# Iron Man 2                                                                     https://transcripts.fandom.com/wiki/Iron_Man_2
# Thor                                                          https://www.scriptslug.com/assets/uploads/scripts/thor-2011.pdf
# Captain America: The First Avenger                     https://transcripts.fandom.com/wiki/Captain_America:_The_First_Avenger
# The Avengers                                          https://www.scriptslug.com/assets/uploads/scripts/the-avengers-2012.pdf
# Iron Man 3                                                                     https://transcripts.fandom.com/wiki/Iron_Man_3
# Thor: The Dark World                                                 https://transcripts.fandom.com/wiki/Thor:_The_Dark_World
# Captain America: The Winter Soldier                   https://transcripts.fandom.com/wiki/Captain_America:_The_Winter_Soldier
# Ant-Man                                                                           https://transcripts.fandom.com/wiki/Ant-Man
# Avengers: Age of Ultron                                           https://transcripts.fandom.com/wiki/Avengers:_Age_of_Ultron
# Captain America: Civil War                                     https://transcripts.fandom.com/wiki/Captain_America:_Civil_War
# Thor: Ragnorak                                       https://www.scriptslug.com/assets/uploads/scripts/thor-ragnorak-2017.pdf
# Guardians of the Galaxy Vol. 2       https://www.scriptslug.com/assets/uploads/scripts/guardians-of-the-galaxy-vol-2-2017.pdf
# Spider-Man: Homecoming                                             https://transcripts.fandom.com/wiki/Spider-Man:_Homecoming
# Black Panther                                        https://www.scriptslug.com/assets/uploads/scripts/black-panther-2018.pdf
# Avengers: Infinity War                                             https://transcripts.fandom.com/wiki/Avengers:_Infinity_War
# Captain Marvel                                                      https://transcripts.fandom.com/wiki/Captain_Marvel_(2019)
# Avengers: Endgame                                 https://www.scriptslug.com/assets/uploads/scripts/avengers-endgame-2019.pdf
#
#                                      year
# movie
# Iron Man                             2008
# Iron Man 2                           2010
# Thor                                 2011
# Captain America: The First Avenger   2011
# The Avengers                         2012
# Iron Man 3                           2013
# Thor: The Dark World                 2013
# Captain America: The Winter Soldier  2014
# Ant-Man                              2015
# Avengers: Age of Ultron              2015
# Captain America: Civil War           2016
# Thor: Ragnorak                       2017
# Guardians of the Galaxy Vol. 2       2017
# Spider-Man: Homecoming               2017
# Black Panther                        2018
# Avengers: Infinity War               2018
# Captain Marvel                       2019
# Avengers: Endgame                    2019
