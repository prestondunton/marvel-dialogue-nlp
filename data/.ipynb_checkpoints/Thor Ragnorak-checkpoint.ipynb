# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Script to CSV Process
#
# 1. Load script `.txt` file.  Use [PDF Extractor](https://pdfextractor.com/) to convert any `.pdf`s to `.txt`s.
# 2. Remove garbage rows
# 3. Inspect rows removed
# 4. Format lines
# 5. Create `uppercase_unique_form.csv`
# 6. Manually fill out `uppercase_unique_form.csv` columns `is_character_name` and `is_dialogue` in Excel or other `.csv` editor.
# 7. Load `uppercase_unique.csv` and filter out rows
# 8. Inspect rows removed
# 9. Merge lines into best guesses for columns "character" and "line"
# 10. Manually clean the "line" column by removing text that is not dialogue.  There will be a lot, so nearly every cell will have to be cleaned!
#
#
# See the Thor Ragnorak script at the end of this notebook for an example of this process.

# %% [markdown]
# ## Remove Garbage Rows

# %%
def remove_regex_rows(df,string):
    rows_to_remove = df["line"].str.contains(string,case=True,regex=True)
    print("Removed",rows_to_remove.sum(),"rows that match regex \"" + string + "\"")
    
    return df[~rows_to_remove], df[rows_to_remove]

def remove_whitespace_rows(df):
    whitespace_rows = df["line"].str.isspace()
    print(whitespace_rows.sum(),"whitespace rows removed")
    return df[~whitespace_rows], df[whitespace_rows]

def remove_movie_text_rows(df):
    
    regex_strings = ["INTERCUT:",
                    "CUT TO",
                    "^THE END",
                    "^INT\.",
                    "^EXT\.",
                    "\(CONTINUED\)",
                    "CONTINUED: \(.\)",
                    "^[0-9]+\.$",
                    "\(.*radio\)",
                    "\(.*earpiece\)",
                    "\(.*headset\)",
                    "\(.*phone\)",
                    "\(.*cell\)",
                    "\(to .*\)",
                    "\(in .*\)",
                    "\(MORE\)",
                    "\(angry\)",
                    "TIME CUT:",
                    "TITLE:",
                    "MARVEL FLIP",
                    "SLAM TO",
                    "DISSOLVE TO",
                    "BEST ADAPTED SCREENPLAY",
                    "FADE TO BLACK",
                    "CUE MUSIC",
                    "BLUE DRAFT 05/20/16",
                    "OMITTED",
                    "MAIN TITLE",
                    "[ABC][0-9]+",
                    "\(.*:\)",
                    "\(beat\)"]
    
    removed_rows = pd.DataFrame()
    
    for regex_string in regex_strings:
        df, new_rows_to_remove = remove_regex_rows(df,regex_string)
        
        removed_rows = pd.concat([removed_rows, new_rows_to_remove])
    
    return df, removed_rows


def remove_page_number_rows(df):
    page_rows = df["line"].str.isnumeric()
    print(page_rows.sum(),"page number rows removed")
    
    return df[~page_rows], df[page_rows]

def remove_garbage_rows(df):
    df, whitespace_rows = remove_whitespace_rows(df)
    df, page_number_rows = remove_page_number_rows(df)
    df, movie_text_rows = remove_movie_text_rows(df)
    
    garbage_rows = pd.concat([whitespace_rows, page_number_rows, movie_text_rows], 
                            keys = ["whitespace","page_numbers","movie_text"])
    
    print("-----------------------------------------")
    print(garbage_rows.shape[0],"total rows removed\n")
    
    return df, garbage_rows

# %% [markdown]
# ## Format Character Lines

# %%
def remove_regex(df,string):
    print("Removed",df["line"].str.count(string).sum(),"occurences of regex \"" + string + "\"")
    df["line"] = df["line"].str.replace(string,"",case=True,regex=True)

def remove_leading_trailing_whitespace(df):
    df["line"] = df["line"].str.replace("[ \t]+$","")
    df["line"] = df["line"].str.replace("^[ \t]+","")

def format_lines(df):
    remove_leading_trailing_whitespace(df)
    
    regex_strings = ["\(O\.S\)",
                    "\(V\.O\)",
                     "\(V\.O\.\)",
                    "\(CONT’D\)",
                     "\(CONT'D\)",
                    "\(O\.S\.\)",
                    "\(ON SCREEN\)",
                    "\(OVER COM\)",
                    "\(ON COM\)",
                    "\(INTO COM\)",
                    "\(OVER SPEAKER\)",
                    "\(INTO PHONE\)",
                    "\(OVER PHONE\)",
                    "\(HOLO\)",
                    "\(ADR\)"]
    
    for regex_string in regex_strings:
        remove_regex(df, regex_string)
    
    print("")
    
    remove_leading_trailing_whitespace(df)

# %% [markdown]
# ## Remove Non Dialogue Uppercase Rows

# %%
def uppercase_rows(df):
    upper_lines = df["line"].str.isupper()
    
    return df[upper_lines]

def create_uppercase_unique_csv(df,script_name):
    '''
    Creates a csv file that is used for inspection of unique
    lines that are all uppercase.  These lines are manually labeled
    to be character names or dialogue.  The resulting table will be
    used to delete rows that are neither character names nor dialogue.
    '''
    
    upper_rows = uppercase_rows(df)
    unique_upper_rows = pd.DataFrame(upper_rows.line.unique())

    unique_upper_rows["words"] = unique_upper_rows[0].str.split(" ").str.len()
    unique_upper_rows["is_character_name"] = 0
    unique_upper_rows["is_dialogue"] = 0
    sorted_unique_upper_rows = unique_upper_rows.sort_values(by=["words"])
    sorted_unique_upper_rows.to_csv("./uppercase forms/" + script_name + "_uppercase_unique_form.csv",encoding='utf-8')
    
def remove_non_dialogue_upper_rows(df,upper_rows):
    '''
    Removes lines that are in all caps, and that are not dialogue or a character's name.
    '''
    unique_character_names = upper_rows[upper_rows["is_character_name"]]["line"]
    unique_dialogues = upper_rows[upper_rows["is_dialogue"]]["line"]
    
    all_character_name_lines = df[df["line"].isin(unique_character_names)]
    all_dialogue_lines = df[df["line"].isin(unique_dialogues)]
    
    print(df["line"].str.isupper().sum(),"total uppercase lines")
    print(all_character_name_lines.shape[0],"uppercase character name lines")
    print(all_dialogue_lines.shape[0],"uppercase dialogue lines")
    
    unique_lines_to_remove = upper_rows[~(upper_rows["is_character_name"]|upper_rows["is_dialogue"])]["line"]
    removed_lines = df["line"].isin(unique_lines_to_remove)
    print(removed_lines.sum(),"uppercase lines removed")
    
    return df[~removed_lines], df[removed_lines]

# %% [markdown]
# ## Merge Lines

# %%
def is_character_name(string,character_names):
    return string in character_names["line"].tolist()
    

def merge_lines(df,character_names):
    '''
    Starts at a character name and merges all lines until the next character's name.
    The result should be the best guess at columns "character" and "line".
    This will merge in some screenplay text that is not dialogue, so the result will 
    have to be manually cleaned as the final step.
    '''
    merged_df = pd.DataFrame(columns=["character","line"])
    
    for i in range(0,df.shape[0]):
        
        row = df.iloc[i]
        
        if is_character_name(row["line"],character_names):
            character = row["line"]
            line = ""
            
            j = i + 1
            while(j < len(df) and (not is_character_name(df.iloc[j]["line"],character_names))):
                line += df.iloc[j]["line"] + " "
                j += 1
            
            new_row = {"character": character,"line": line}
            
            merged_df = merged_df.append(new_row,ignore_index=True)
    
    return merged_df

# %% [markdown]
# ## Thor Ragnorak

# %%
ragnorak = pd.read_csv("./script txts/thor-ragnorak-script-slug.txt",sep="\n",header=None,names=["line"])

ragnorak, garbage_rows = remove_garbage_rows(ragnorak)
format_lines(ragnorak)

create_uppercase_unique_csv(ragnorak,"ragnorak")
filled_out_upper_rows = pd.read_csv("./uppercase results/ragnorak_uppercase_unique.csv",
                                    names=["","line","words","is_character_name","is_dialogue"],
                                    dtype={"line":str, "words":int, "is_character_name":bool, "is_dialogue":bool},
                                    index_col=0)

ragnorak, upper_removed_rows = remove_non_dialogue_upper_rows(ragnorak, filled_out_upper_rows)
removed_rows = pd.concat([garbage_rows,pd.concat([upper_removed_rows],keys=[""])],keys=["garbage","uppercase"])

unique_character_names = pd.DataFrame(filled_out_upper_rows[filled_out_upper_rows["is_character_name"]]["line"])

ragnorak = merge_lines(ragnorak, unique_character_names)
ragnorak.reindex(copy=False)

ragnorak.to_csv("./uncleaned/ragnorak_uncleaned.csv", index=False)

ragnorak = pd.read_csv("./cleaned/ragnorak.csv")

ragnorak
# Out:
# 129 whitespace rows removed
# 258 page number rows removed
# Removed 0 rows that match regex "INTERCUT:"
# Removed 2 rows that match regex "CUT TO"
# Removed 1 rows that match regex "^THE END"
# Removed 65 rows that match regex "^INT\."
# Removed 66 rows that match regex "^EXT\."
# Removed 0 rows that match regex "\(CONTINUED\)"
# Removed 0 rows that match regex "CONTINUED: \(.\)"
# Removed 127 rows that match regex "^[0-9]+\.$"
# Removed 0 rows that match regex "\(.*radio\)"
# Removed 0 rows that match regex "\(.*earpiece\)"
# Removed 0 rows that match regex "\(.*headset\)"
# Removed 0 rows that match regex "\(.*phone\)"
# Removed 0 rows that match regex "\(.*cell\)"
# Removed 15 rows that match regex "\(to .*\)"
# Removed 0 rows that match regex "\(in .*\)"
# Removed 12 rows that match regex "\(MORE\)"
# Removed 0 rows that match regex "\(angry\)"
# Removed 2 rows that match regex "TIME CUT:"
# Removed 0 rows that match regex "TITLE:"
# Removed 0 rows that match regex "MARVEL FLIP"
# Removed 0 rows that match regex "SLAM TO"
# Removed 0 rows that match regex "DISSOLVE TO"
# Removed 0 rows that match regex "BEST ADAPTED SCREENPLAY"
# Removed 0 rows that match regex "FADE TO BLACK"
# Removed 0 rows that match regex "CUE MUSIC"
# Removed 127 rows that match regex "BLUE DRAFT 05/20/16"
# Removed 49 rows that match regex "OMITTED"
# Removed 1 rows that match regex "MAIN TITLE"
# Removed 66 rows that match regex "[ABC][0-9]+"
# Removed 23 rows that match regex "\(.*:\)"
# Removed 10 rows that match regex "\(beat\)"
# -----------------------------------------
# 953 total rows removed
#
# Removed 0 occurences of regex "\(O\.S\)"
# Removed 0 occurences of regex "\(V\.O\)"
# Removed 24 occurences of regex "\(V\.O\.\)"
# Removed 129 occurences of regex "\(CONT’D\)"
# Removed 12 occurences of regex "\(CONT'D\)"
# Removed 13 occurences of regex "\(O\.S\.\)"
# Removed 0 occurences of regex "\(ON SCREEN\)"
# Removed 0 occurences of regex "\(OVER COM\)"
# Removed 0 occurences of regex "\(ON COM\)"
# Removed 0 occurences of regex "\(INTO COM\)"
# Removed 0 occurences of regex "\(OVER SPEAKER\)"
# Removed 0 occurences of regex "\(INTO PHONE\)"
# Removed 0 occurences of regex "\(OVER PHONE\)"
# Removed 0 occurences of regex "\(HOLO\)"
# Removed 1 occurences of regex "\(ADR\)"
#
# 1057 total uppercase lines
# 972 uppercase character name lines
# 7 uppercase dialogue lines
# 78 uppercase lines removed
#               character  \
# 0                  THOR
# 1                  THOR
# 2                SURTUR
# 3                  THOR
# 4                SURTUR
# 5                  THOR
# 6                SURTUR
# 7                  THOR
# 8                  THOR
# 9                  THOR
# 10               SURTUR
# 11                 THOR
# 12                 THOR
# 13               SURTUR
# 14                 THOR
# 15               SURTUR
# 16                 THOR
# 17               SURTUR
# 18                 THOR
# 19               SURTUR
# 20                 THOR
# 21               SURTUR
# 22                 THOR
# 23               SURTUR
# 24                 THOR
# 25                 THOR
# 26               SURTUR
# 27                 THOR
# 28                 THOR
# 29                 THOR
# 30               SKURGE
# 31               SKURGE
# 32                 THOR
# 33                 THOR
# 34                 THOR
# 35                 THOR
# 36      ASGARDIAN WOMAN
# 37               SKURGE
# 38               SKURGE
# 39                 THOR
# 40               SKURGE
# 41                 THOR
# 42               SKURGE
# 43                 THOR
# 44               SKURGE
# 45                 THOR
# 46               SKURGE
# 47                 THOR
# 48           ACTOR LOKI
# 49           ACTOR THOR
# 50           ACTOR LOKI
# 51           ACTOR THOR
# 52            ACTOR SIF
# 53           ACTOR LOKI
# 54           ACTOR THOR
# 55           ACTOR LOKI
# 56           ACTOR THOR
# 57           ACTOR LOKI
# 58           ACTOR THOR
# 59           ACTOR LOKI
# 60           ACTOR THOR
# 61           ACTOR LOKI
# 62           ACTOR THOR
# 63                 ODIN
# 64           ACTOR THOR
# 65           ACTOR LOKI
# 66           ACTOR THOR
# 67           ACTOR LOKI
# 68           ACTOR THOR
# 69           ACTOR LOKI
# 70           ACTOR THOR
# 71           ACTOR LOKI
# 72           ACTOR THOR
# 73           ACTOR ODIN
# 74           ACTOR ODIN
# 75           ACTOR ODIN
# 76                 ODIN
# 77                 THOR
# 78                 ODIN
# 79                 THOR
# 80                 ODIN
# 81                 THOR
# 82                 THOR
# 83                 ODIN
# 84                 THOR
# 85                 ODIN
# 86                 THOR
# 87                 ODIN
# 88                 THOR
# 89                 ODIN
# 90                 THOR
# 91                 ODIN
# 92                 THOR
# 93                 ODIN
# 94                 THOR
# 95                 ODIN
# 96                 THOR
# 97                 THOR
# 98                 ODIN
# 99                 THOR
# 100                LOKI
# 101              SKURGE
# 102                LOKI
# 103                THOR
# 104                LOKI
# 105                THOR
# 106                LOKI
# 107                LOKI
# 108                LOKI
# 109                THOR
# 110                LOKI
# 111                THOR
# 112                LOKI
# 113                THOR
# 114                LOKI
# 115      COLLEGE GIRL 2
# 116      COLLEGE GIRL 1
# 117                THOR
# 118      COLLEGE GIRL 1
# 119      COLLEGE GIRL 2
# 120                THOR
# 121                THOR
# 122                LOKI
# 123                THOR
# 124             STRANGE
# 125             STRANGE
# 126             STRANGE
# 127                THOR
# 128             STRANGE
# 129                THOR
# 130             STRANGE
# 131             STRANGE
# 132                THOR
# 133             STRANGE
# 134                THOR
# 135             STRANGE
# 136                THOR
# 137             STRANGE
# 138                THOR
# 139             STRANGE
# 140                THOR
# 141         DR. STRANGE
# 142                THOR
# 143         DR. STRANGE
# 144                THOR
# 145             STRANGE
# 146                THOR
# 147         DR. STRANGE
# 148             STRANGE
# 149             STRANGE
# 150             STRANGE
# 151                THOR
# 152             STRANGE
# 153                THOR
# 154                THOR
# 155         DR. STRANGE
# 156                THOR
# 157             STRANGE
# 158                THOR
# 159                THOR
# 160                THOR
# 161         DR. STRANGE
# 162                LOKI
# 163         DR. STRANGE
# 164                THOR
# 165             STRANGE
# 166                LOKI
# 167                THOR
# 168                LOKI
# 169         DR. STRANGE
# 170                THOR
# 171                ODIN
# 172                THOR
# 173                ODIN
# 174                THOR
# 175                ODIN
# 176                THOR
# 177                ODIN
# 178                ODIN
# 179                THOR
# 180                ODIN
# 181                THOR
# 182                ODIN
# 183                THOR
# 184                ODIN
# 185                THOR
# 186                ODIN
# 187                THOR
# 188                ODIN
# 189                ODIN
# 190                ODIN
# 191                ODIN
# 192                LOKI
# 193                THOR
# 194                HELA
# 195                THOR
# 196                HELA
# 197                LOKI
# 198                HELA
# 199                HELA
# 200                LOKI
# 201                HELA
# 202                THOR
# 203                THOR
# 204                HELA
# 205                LOKI
# 206                THOR
# 207                THOR
# 208            VOLSTAGG
# 209                HELA
# 210              SKURGE
# 211                HELA
# 212       LEAD SCRAPPER
# 213                THOR
# 214       LEAD SCRAPPER
# 215       SCRAPPER #142
# 216       SCRAPPER #142
# 217       SCRAPPER #142
# 218            SCRAPPER
# 219       SCRAPPER #142
# 220       LEAD SCRAPPER
# 221                THOR
# 222       SCRAPPER #142
# 223                THOR
# 224                THOR
# 225       SCRAPPER #142
# 226                HELA
# 227                HELA
# 228               HOGUN
# 229                HELA
# 230               HOGUN
# 231                HELA
# 232                HELA
# 233                HELA
# 234                HELA
# 235               HOGUN
# 236                HELA
# 237      SOOTHING VOICE
# 238      SOOTHING VOICE
# 239      SOOTHING VOICE
# 240      SOOTHING VOICE
# 241                THOR
# 242      SOOTHING VOICE
# 243      SOOTHING VOICE
# 244      SOOTHING VOICE
# 245      SOOTHING VOICE
# 246         GRANDMASTER
# 247       SCRAPPER #142
# 248         GRANDMASTER
# 249               TOPAZ
# 250         GRANDMASTER
# 251               TOPAZ
# 252         GRANDMASTER
# 253               TOPAZ
# 254         GRANDMASTER
# 255       SCRAPPER #142
# 256                THOR
# 257         GRANDMASTER
# 258         GRANDMASTER
# 259                THOR
# 260         GRANDMASTER
# 261       SCRAPPER #142
# 262               TOPAZ
# 263         GRANDMASTER
# 264                THOR
# 265       SCRAPPER #142
# 266         GRANDMASTER
# 267                THOR
# 268         GRANDMASTER
# 269               TOPAZ
# 270         GRANDMASTER
# 271         GRANDMASTER
# 272                THOR
# 273         GRANDMASTER
# 274        COUSIN CARLO
# 275         GRANDMASTER
# 276        COUSIN CARLO
# 277         GRANDMASTER
# 278                THOR
# 279         GRANDMASTER
# 280                THOR
# 281         GRANDMASTER
# 282               TOPAZ
# 283         GRANDMASTER
# 284         GRANDMASTER
# 285                THOR
# 286         GRANDMASTER
# 287                LOKI
# 288                THOR
# 289                LOKI
# 290                THOR
# 291                LOKI
# 292                THOR
# 293                LOKI
# 294                THOR
# 295                LOKI
# 296                THOR
# 297                LOKI
# 298                THOR
# 299                LOKI
# 300                THOR
# 301                LOKI
# 302                THOR
# 303         GRANDMASTER
# 304         GRANDMASTER
# 305         GRANDMASTER
# 306                THOR
# 307                LOKI
# 308                THOR
# 309                LOKI
# 310         GRANDMASTER
# 311                THOR
# 312         GRANDMASTER
# 313                THOR
# 314         GRANDMASTER
# 315                THOR
# 316         GRANDMASTER
# 317                THOR
# 318                KORG
# 319                THOR
# 320                KORG
# 321                THOR
# 322                KORG
# 323                THOR
# 324                KORG
# 325                THOR
# 326                KORG
# 327                THOR
# 328                KORG
# 329                THOR
# 330                KORG
# 331                THOR
# 332                KORG
# 333                HELA
# 334                HELA
# 335                HELA
# 336                HELA
# 337              SKURGE
# 338                HELA
# 339                HELA
# 340                HELA
# 341                HELA
# 342                HELA
# 343                HELA
# 344                HELA
# 345                HELA
# 346                HELA
# 347                THOR
# 348                THOR
# 349                LOKI
# 350                LOKI
# 351                LOKI
# 352                LOKI
# 353                LOKI
# 354                LOKI
# 355                LOKI
# 356                LOKI
# 357                LOKI
# 358                THOR
# 359                LOKI
# 360                KORG
# 361                KORG
# 362                THOR
# 363                KORG
# 364                THOR
# 365                KORG
# 366                THOR
# 367                KORG
# 368                THOR
# 369                KORG
# 370                THOR
# 371                KORG
# 372                THOR
# 373                KORG
# 374                THOR
# 375       SCRAPPER #142
# 376                THOR
# 377                KORG
# 378                THOR
# 379                THOR
# 380                THOR
# 381                THOR
# 382       SCRAPPER #142
# 383              WARDEN
# 384                THOR
# 385       SCRAPPER #142
# 386                THOR
# 387       SCRAPPER #142
# 388              WARDEN
# 389            VALKYRIE
# 390            STAN LEE
# 391                THOR
# 392                THOR
# 393         GRANDMASTER
# 394         GRANDMASTER
# 395         GRANDMASTER
# 396         GRANDMASTER
# 397                THOR
# 398                LOKI
# 399         GRANDMASTER
# 400                THOR
# 401                THOR
# 402                THOR
# 403                HULK
# 404                THOR
# 405                THOR
# 406         GRANDMASTER
# 407         GRANDMASTER
# 408                THOR
# 409                THOR
# 410                LOKI
# 411                THOR
# 412                THOR
# 413                THOR
# 414               CROWD
# 415                KORG
# 416                KORG
# 417                HELA
# 418              SKURGE
# 419                HELA
# 420              SKURGE
# 421                HELA
# 422              SKURGE
# 423                HELA
# 424                HELA
# 425                HELA
# 426                HELA
# 427                HELA
# 428            HEIMDALL
# 429            HEIMDALL
# 430            HEIMDALL
# 431                THOR
# 432                THOR
# 433                HULK
# 434                THOR
# 435                HULK
# 436                THOR
# 437                HULK
# 438                THOR
# 439                HULK
# 440                THOR
# 441                THOR
# 442                HULK
# 443                THOR
# 444                HULK
# 445                THOR
# 446                HULK
# 447                THOR
# 448                HULK
# 449                THOR
# 450                HULK
# 451                THOR
# 452                HULK
# 453                THOR
# 454                HULK
# 455                THOR
# 456                HULK
# 457                THOR
# 458                HULK
# 459                THOR
# 460                HULK
# 461                THOR
# 462                HULK
# 463                THOR
# 464                HULK
# 465                THOR
# 466                HULK
# 467                HULK
# 468                THOR
# 469                THOR
# 470                THOR
# 471            HEIMDALL
# 472                THOR
# 473            HEIMDALL
# 474            HEIMDALL
# 475                THOR
# 476            HEIMDALL
# 477            HEIMDALL
# 478            HEIMDALL
# 479            HEIMDALL
# 480            HEIMDALL
# 481                THOR
# 482            HEIMDALL
# 483                THOR
# 484            HEIMDALL
# 485                HULK
# 486                THOR
# 487                HULK
# 488                THOR
# 489                HULK
# 490                THOR
# 491                HULK
# 492                THOR
# 493                HULK
# 494                THOR
# 495                HULK
# 496                THOR
# 497                HULK
# 498                THOR
# 499                HULK
# 500                THOR
# 501                HULK
# 502                THOR
# 503                HULK
# 504                THOR
# 505                HULK
# 506                THOR
# 507                HULK
# 508                THOR
# 509                HULK
# 510                THOR
# 511                HULK
# 512            VALKYRIE
# 513            VALKYRIE
# 514                THOR
# 515            VALKYRIE
# 516                THOR
# 517                HULK
# 518            VALKYRIE
# 519                THOR
# 520            VALKYRIE
# 521                THOR
# 522                THOR
# 523            VALKYRIE
# 524                THOR
# 525            VALKYRIE
# 526                THOR
# 527                HULK
# 528                THOR
# 529            VALKYRIE
# 530                THOR
# 531            VALKYRIE
# 532                THOR
# 533            VALKYRIE
# 534            VALKYRIE
# 535                THOR
# 536            VALKYRIE
# 537                THOR
# 538            VALKYRIE
# 539                THOR
# 540            VALKYRIE
# 541                THOR
# 542            VALKYRIE
# 543                THOR
# 544            VALKYRIE
# 545                THOR
# 546                THOR
# 547                THOR
# 548                THOR
# 549                THOR
# 550                HULK
# 551                THOR
# 552             QUINJET
# 553                THOR
# 554             QUINJET
# 555                THOR
# 556             QUINJET
# 557                THOR
# 558             QUINJET
# 559                THOR
# 560             QUINJET
# 561                THOR
# 562             QUINJET
# 563                THOR
# 564             QUINJET
# 565                HULK
# 566                THOR
# 567                HULK
# 568                THOR
# 569                HULK
# 570             NATASHA
# 571             NATASHA
# 572             NATASHA
# 573                HULK
# 574                THOR
# 575              BANNER
# 576                THOR
# 577              BANNER
# 578                THOR
# 579              BANNER
# 580                THOR
# 581              BANNER
# 582                THOR
# 583              BANNER
# 584                THOR
# 585              BANNER
# 586                THOR
# 587              BANNER
# 588                THOR
# 589              BANNER
# 590                THOR
# 591              BANNER
# 592                THOR
# 593             QUINJET
# 594              BANNER
# 595             QUINJET
# 596                THOR
# 597              BANNER
# 598              BANNER
# 599                THOR
# 600         GRANDMASTER
# 601         GRANDMASTER
# 602              BANNER
# 603                THOR
# 604              BANNER
# 605                THOR
# 606              BANNER
# 607                THOR
# 608              BANNER
# 609                THOR
# 610         GRANDMASTER
# 611                THOR
# 612              BANNER
# 613                THOR
# 614              BANNER
# 615                THOR
# 616              BANNER
# 617                THOR
# 618         GRANDMASTER
# 619                LOKI
# 620         GRANDMASTER
# 621               TOPAZ
# 622         GRANDMASTER
# 623                LOKI
# 624            VALKYRIE
# 625                LOKI
# 626         GRANDMASTER
# 627                LOKI
# 628            VALKYRIE
# 629                LOKI
# 630                LOKI
# 631            VALKYRIE
# 632                LOKI
# 633            VALKYRIE
# 634                LOKI
# 635                THOR
# 636              BANNER
# 637                THOR
# 638              BANNER
# 639                THOR
# 640              BANNER
# 641                THOR
# 642              BANNER
# 643                THOR
# 644              BANNER
# 645                THOR
# 646              BANNER
# 647                THOR
# 648              BANNER
# 649                THOR
# 650              BANNER
# 651                THOR
# 652              BANNER
# 653              BANNER
# 654                THOR
# 655              BANNER
# 656                THOR
# 657              BANNER
# 658                THOR
# 659              BANNER
# 660                THOR
# 661              BANNER
# 662                THOR
# 663              BANNER
# 664                THOR
# 665              BANNER
# 666                THOR
# 667              BANNER
# 668                THOR
# 669              BANNER
# 670                THOR
# 671              BANNER
# 672                THOR
# 673              BANNER
# 674                THOR
# 675              BANNER
# 676                THOR
# 677              BANNER
# 678                THOR
# 679              BANNER
# 680                THOR
# 681              BANNER
# 682                THOR
# 683                THOR
# 684            VALKYRIE
# 685                THOR
# 686            VALKYRIE
# 687                THOR
# 688            VALKYRIE
# 689                THOR
# 690            VALKYRIE
# 691                THOR
# 692            VALKYRIE
# 693                THOR
# 694              BANNER
# 695            VALKYRIE
# 696                THOR
# 697              BANNER
# 698            VALKYRIE
# 699              BANNER
# 700            VALKYRIE
# 701                THOR
# 702            VALKYRIE
# 703                THOR
# 704            VALKYRIE
# 705                THOR
# 706            VALKYRIE
# 707                THOR
# 708              BANNER
# 709                THOR
# 710            VALKYRIE
# 711               LOKIE
# 712                LOKI
# 713                THOR
# 714                LOKI
# 715              BANNER
# 716                LOKI
# 717                THOR
# 718            VALKYRIE
# 719                THOR
# 720            VALKYRIE
# 721            VALKYRIE
# 722                THOR
# 723            VALKYRIE
# 724              BANNER
# 725                THOR
# 726              BANNER
# 727            VALKYRIE
# 728                THOR
# 729              BANNER
# 730            VALKYRIE
# 731              BANNER
# 732            VALKYRIE
# 733                THOR
# 734              BANNER
# 735                THOR
# 736            VALKYRIE
# 737                LOKI
# 738            VALKYRIE
# 739                LOKI
# 740                THOR
# 741                LOKI
# 742              BANNER
# 743            VALKYRIE
# 744                THOR
# 745            VALKYRIE
# 746                LOKI
# 747                THOR
# 748            VALKYRIE
# 749                THOR
# 750              BANNER
# 751                THOR
# 752            VALKYRIE
# 753                THOR
# 754                KORG
# 755            VALKYRIE
# 756                KORG
# 757            VALKYRIE
# 758                KORG
# 759         GRANDMASTER
# 760               TOPAZ
# 761         GRANDMASTER
# 762               TOPAZ
# 763         GRANDMASTER
# 764               TOPAZ
# 765         GRANDMASTER
# 766                THOR
# 767                LOKI
# 768                THOR
# 769                THOR
# 770                LOKI
# 771                LOKI
# 772                THOR
# 773                LOKI
# 774                THOR
# 775                LOKI
# 776                THOR
# 777                LOKI
# 778                THOR
# 779                LOKI
# 780                THOR
# 781                THOR
# 782                LOKI
# 783                THOR
# 784                LOKI
# 785                THOR
# 786                LOKI
# 787                THOR
# 788                LOKI
# 789                THOR
# 790                LOKI
# 791                THOR
# 792                LOKI
# 793                THOR
# 794                THOR
# 795                THOR
# 796                LOKI
# 797                THOR
# 798                THOR
# 799                LOKI
# 800                LOKI
# 801                THOR
# 802                LOKI
# 803                THOR
# 804                LOKI
# 805                THOR
# 806                THOR
# 807                THOR
# 808                THOR
# 809                THOR
# 810         GRANDMASTER
# 811              BANNER
# 812            VALKYRIE
# 813            VALKYRIE
# 814              BANNER
# 815              BANNER
# 816                THOR
# 817            VALKYRIE
# 818       THOR / BANNER
# 819            VALKYRIE
# 820              BANNER
# 821                THOR
# 822                THOR
# 823                THOR
# 824            VALKYRIE
# 825                THOR
# 826                THOR
# 827              BANNER
# 828                THOR
# 829              BANNER
# 830              BANNER
# 831         GRANDMASTER
# 832              BANNER
# 833            VALKYRIE
# 834                KORG
# 835                LOKI
# 836                KORG
# 837                LOKI
# 838                KORG
# 839            VALKYRIE
# 840              SKURGE
# 841              SKURGE
# 842                HELA
# 843  ASGARDIAN CITIZENS
# 844                HELA
# 845       ASGARDIAN MAN
# 846            VALKYRIE
# 847              BANNER
# 848            VALKYRIE
# 849            VALKYRIE
# 850                THOR
# 851            VALKYRIE
# 852                THOR
# 853              BANNER
# 854                THOR
# 855            HEIMDALL
# 856                THOR
# 857            VALKYRIE
# 858                THOR
# 859            VALKYRIE
# 860            HEIMDALL
# 861                THOR
# 862                HELA
# 863                THOR
# 864                HELA
# 865                THOR
# 866                HELA
# 867                THOR
# 868                HELA
# 869                THOR
# 870                HELA
# 871            HEIMDALL
# 872                HELA
# 873              SKURGE
# 874            HEIMDALL
# 875                HELA
# 876                HELA
# 877                HELA
# 878            VALKYRIE
# 879              BANNER
# 880            VALKYRIE
# 881              BANNER
# 882                HELA
# 883                KORG
# 884                KORG
# 885                LOKI
# 886                HELA
# 887                LOKI
# 888            HEIMDALL
# 889                LOKI
# 890                HELA
# 891                HELA
# 892                HELA
# 893                HELA
# 894                ODIN
# 895                THOR
# 896                ODIN
# 897                ODIN
# 898                THOR
# 899                ODIN
# 900                THOR
# 901                ODIN
# 902                HELA
# 903                THOR
# 904                LOKI
# 905            VALKYRIE
# 906                THOR
# 907                LOKI
# 908                THOR
# 909            VALKYRIE
# 910                THOR
# 911            VALKYRIE
# 912                LOKI
# 913                THOR
# 914                LOKI
# 915                THOR
# 916            VALKYRIE
# 917                LOKI
# 918                THOR
# 919              SKURGE
# 920              SKURGE
# 921                LOKI
# 922                THOR
# 923                THOR
# 924                HELA
# 925                THOR
# 926                HELA
# 927              SURTUR
# 928            VALKYRIE
# 929                THOR
# 930            VALKYRIE
# 931                THOR
# 932                THOR
# 933                THOR
# 934                THOR
# 935                THOR
# 936                HULK
# 937            VALKYRIE
# 938                HULK
# 939              SURTUR
# 940                KORG
# 941                KORG
# 942                THOR
# 943            HEIMDALL
# 944                LOKI
# 945                THOR
# 946                LOKI
# 947                THOR
# 948                THOR
# 949                LOKI
# 950            VALKYRIE
# 951            HEIMDALL
# 952            HEIMDALL
# 953                THOR
# 954                KORG
# 955                KORG
# 956                THOR
# 957                LOKI
# 958                THOR
# 959                LOKI
# 960                THOR
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               line
# 0    Now I know what you’re thinking. Oh no!  Thor’s in a cage.  How did this happen? Well, sometimes you have to get captured just to get a straight answer out of somebody. It’s a long story but basically I'm a bit of a hero. See, I spent some time on earth, fought some robots, saved the planet a couple of times. Then I went searching through the cosmos for some magic, colorful Infinity Stone things... didn’t find any. That’s when I came across a path of death and destruction which led me all the way here into this cage... where I met you.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      How much longer do you think we’ll be here?
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Thor, Son of Odin.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                  Surtur.  Son of a bitch...you’re still alive!  I thought my father killed you, like, half a million years ago.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         I cannot die. Not until I fulfill my destiny and lay waste to your home.
# 5                                                                                                                                                                                                                                                                                                                                                                   You know, it’s funny you should mention that because I’ve been having these terrible dreams of late.  Asgard up in flames, falling to ruins, and you Surtur are at the center of all of them.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Then you have seen Ragnarok, the fall of Asgard. The great prophecy--
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Hang on.  Hang on.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       I’ll be back around shortly.  I really feel like we were connecting there.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Okay, so, Ragnarok. Tell me about that. Walk me through it.
# 10                                                                                                                                                                                                                                                                                                                                                                                 My time has come. When my crown is reunited with the Eternal Flame, I shall be restored to my full might. I will tower over the mountains and bury my sword deep in Asgard’s--
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Oh, hang on.  Give it a second.
# 12                                                                                                                                                                                                                                                                                                                                      I swear I’m not even moving, it’s just doing this on its own.  I’m really sorry. Okay, let me get this straight. You’re going to put your crown into the Eternal Flame, and then you’ll suddenly grow as big as a house--
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     A mountain!
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        The Eternal Flame that Odin keeps locked away on Asgard?
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Odin is not on Asgard. And your absence has left the throne defenseless.
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Okay, so where is it? This crown?
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       This is my Crown, the source of my power.
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Oh, that’s a crown? I thought it was a big eyebrow.
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   It’s a crown.
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Anyway, it sounds like all I have to do to stop Ragnarok is rip that thing off your head.
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                       But Ragnarok has already begun. You cannot stop it.  I am Asgard’s doom, and so are you.  All will suffer, all will burn.
# 22                                                                                                                                                                                                                                                                               That’s intense.  To be honest, seeing you grow really big and set fire to a planet would be quite the spectacle.  But it looks like I’m going to have to go with option B where I bust out of these chains, knock that tiara off your head, and stash it away in Asgard’s vault.
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         You cannot stop Ragnarok. Why fight it?
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Because that’s what heroes do.
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Wait, sorry.  I didn’t time that right.  And, now!
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         You have made a grave mistake, Odinson.
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               I make grave mistakes all the time. Everything seems to work out.
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Heimdall. I know it’s been a while, but I could use a fast exit!
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...Heimdall?
# 30                                                                                                                                                                                                                                                                                                         Heimdall was an idiot.  This job should have made him rich.  Now, the job ain’t easy, but it does have its benefits. The Bi-Frost gives me access to everything the Nine Realms have to offer. I mean it’s all mine for the taking. Behold...my stuff.
# 31                                                                                                                                                                                                                                                                                                                                                                                     I’m particularly fond of these. I pulled ‘em out of a place on Midgard called Texas.  I even named them. Des and Troy.  You see, when you put them together...they destroy.
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Heimdall, come on.
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Stay. I’m running short on--
# ...
# 932                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Surtur destroys Asgard, he destroys Hela so that our people can live.
# 933                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               We need to let him finish... No!
# 934                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Hulk no!  Stop it you moron!!
# 935                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Hulk, just for once in your life, don’t smash!
# 936                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             But...big Monster.
# 937                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Hulk! Let’s go.
# 938                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Friends.
# 939                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           I am Asgard’s doom!!
# 940                                                                                                                                                                                                                                                                                                                                                                                             The damage is not too bad.  As long as the foundations are strong, we can rebuild this place.  It will become a haven for all people and aliens of the universe...
# 941                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Nope, those foundations are gone. Sorry.
# 942                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              What have I done?
# 943                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            You saved us from extinction. Asgard is not a place, it’s a people.
# 944                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  It suits you.
# 945                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Perhaps you’re not so bad after all, brother.
# 946                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Maybe not.
# 947                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Thank you, Loki.
# 948                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             And if you were here, I might even give you a hug.
# 949                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Do we have to hug now?
# 950                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Your throne.
# 951                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            So, King of Asgard.
# 952                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Where to?
# 953                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 I’m not sure.  Any suggestions? Miek, what’s your home planet?
# 954                                                                                                                                                                                                                                                                                                                                                                                                                               Oh, Miek’s dead.  I accidentally stepped on him on the bridge, I’ve just felt so guilty I’ve been carrying him around all day...
# 955                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Miek, you’re alive!  He’s alive everyone!  What was your question?
# 956                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Earth it is.
# 957                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Do you really think it’s a good idea to go back to Earth?
# 958                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Sure!  They love me there.
# 959                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Let me rephrase: Do you really think it’s a good idea to bring me back to Earth?
# 960                                                                                                                                                                                                                                                                                                                                                                                                                                                              Probably not.  But don’t worry, brother...I’ve got a feeling that everything’s going to work out.
