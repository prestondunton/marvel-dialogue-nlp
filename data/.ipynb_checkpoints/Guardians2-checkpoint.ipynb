# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Script to CSV Process
#
# 1. Load script `.txt` file.  Use [PDF Extractor](https://pdfextractor.com/) to convert any `.pdf`s to `.txt`s.
# 2. Remove garbage rows
# 3. Inspect rows removed
# 4. Format lines
# 5. Create `uppercase_unique_form.csv`
# 6. Manually fill out `uppercase_unique_form.csv` columns `is_character_name` and `is_dialogue` in Excel or other `.csv` editor.
# 7. Load `uppercase_unique.csv` and filter out rows
# 8. Inspect rows removed
# 9. Merge lines into best guesses for columns "character" and "line"
# 10. Manually clean the "line" column by removing text that is not dialogue.  There will be a lot, so nearly every cell will have to be cleaned!
#
#
# See the Guardians of the Galaxy script at the end of this notebook for an example of this process.

# %% [markdown]
# ## Remove Garbage Rows

# %%
def remove_regex_rows(df,string):
    rows_to_remove = df["line"].str.contains(string,case=True,regex=True)
    print("Removed",rows_to_remove.sum(),"rows that match regex \"" + string + "\"")
    
    return df[~rows_to_remove], df[rows_to_remove]

def remove_whitespace_rows(df):
    whitespace_rows = df["line"].str.isspace()
    print(whitespace_rows.sum(),"whitespace rows removed")
    return df[~whitespace_rows], df[whitespace_rows]

def remove_movie_text_rows(df):
    
    regex_strings = ["INTERCUT",
                    "CUT TO",
                    "^THE END",
                    "^INT\.",
                    "^EXT\.",
                    "CONTINUED",
                    "^[0-9]+\.$",
                    "\(.*radio\)",
                    "\(.*earpiece\)",
                    "\(.*headset\)",
                    "\(.*phone\)",
                    "\(.*cell\)",
                    "\(to .*\)",
                    "\(in .*\)",
                    "\(MORE\)",
                    "\(angry\)",
                    "TIME CUT:",
                    "TITLE:",
                    "SLAM TO",
                    "DISSOLVE TO",
                    "FADE",
                    "BEST ADAPTED SCREENPLAY",
                    "MARVEL",
                    "© Marvel",
                    "FADE TO BLACK",
                    "CUE MUSIC",
                    "BLUE DRAFT 05/20/16",
                    "SALMON #2",
                    "../../..",
                    "OMITTED",
                    "MAIN TITLE",
                    "[A-J][0-9]+",
                    "[0-9]+[A-J]",
                    "\*",
                    "\(.*:\)",
                    "^\(beat\)$",
                    "\(re:.*\)"]
    
    removed_rows = pd.DataFrame()
    
    for regex_string in regex_strings:
        df, new_rows_to_remove = remove_regex_rows(df,regex_string)
        
        removed_rows = pd.concat([removed_rows, new_rows_to_remove])
    
    return df, removed_rows


def remove_page_number_rows(df):
    page_rows = df["line"].str.isnumeric()
    print(page_rows.sum(),"page number rows removed")
    
    return df[~page_rows], df[page_rows]

def remove_garbage_rows(df):
    df, whitespace_rows = remove_whitespace_rows(df)
    df, page_number_rows = remove_page_number_rows(df)
    df, movie_text_rows = remove_movie_text_rows(df)
    
    garbage_rows = pd.concat([whitespace_rows, page_number_rows, movie_text_rows], 
                            keys = ["whitespace","page_numbers","movie_text"])
    
    print("-----------------------------------------")
    print(garbage_rows.shape[0],"total rows removed\n")
    
    return df, garbage_rows

# %% [markdown]
# ## Format Character Lines

# %%
def remove_regex(df,string):
    print("Removed",df["line"].str.count(string).sum(),"occurences of regex \"" + string + "\"")
    df["line"] = df["line"].str.replace(string,"",case=True,regex=True)

def remove_leading_trailing_whitespace(df):
    df["line"] = df["line"].str.replace("[ \t]+$","")
    df["line"] = df["line"].str.replace("^[ \t]+","")

def format_lines(df):
    remove_leading_trailing_whitespace(df)
    
    regex_strings = ["\(O\.S\)",
                    "\(V\.O\)",
                     "\(V\.O\.\)",
                    "\(CONT.D\)",
                    "\(cont.d\)",
                    "\(O\.S\.\)",
                    "\(ON.*\)",
                    "\(OVER.*\)",
                    "\(INTO.*\)",
                    "\(HOLO\)",
                    "\(ADR\)",
                    "\(then\)",
                    " \(RHODEY’S VOICE\)",
                    " \(PRE-LAP\)"]
    
    for regex_string in regex_strings:
        remove_regex(df, regex_string)
    
    print("")
    
    remove_leading_trailing_whitespace(df)

# %% [markdown]
# ## Remove Non Dialogue Uppercase Rows

# %%
def uppercase_rows(df):
    upper_lines = df["line"].str.isupper()
    
    return df[upper_lines]

def create_uppercase_unique_csv(df,script_name):
    '''
    Creates a csv file that is used for inspection of unique
    lines that are all uppercase.  These lines are manually labeled
    to be character names or dialogue.  The resulting table will be
    used to delete rows that are neither character names nor dialogue.
    '''
    
    upper_rows = uppercase_rows(df)
    unique_upper_rows = pd.DataFrame(upper_rows.line.unique())

    unique_upper_rows["words"] = unique_upper_rows[0].str.split(" ").str.len()
    unique_upper_rows["is_character_name"] = 0
    unique_upper_rows["is_dialogue"] = 0
    sorted_unique_upper_rows = unique_upper_rows.sort_values(by=["words"])
    sorted_unique_upper_rows.to_csv("./uppercase forms/" + script_name + "_uppercase_unique_form.csv",encoding='utf-8')
    
    print("Created " + "./uppercase forms/" + script_name + "_uppercase_unique_form.csv\n")
    
def remove_non_dialogue_upper_rows(df,upper_rows):
    '''
    Removes lines that are in all caps, and that are not dialogue or a character's name.
    '''
    unique_character_names = upper_rows[upper_rows["is_character_name"]]["line"]
    unique_dialogues = upper_rows[upper_rows["is_dialogue"]]["line"]
    
    all_character_name_lines = df[df["line"].isin(unique_character_names)]
    all_dialogue_lines = df[df["line"].isin(unique_dialogues)]
    
    print(df["line"].str.isupper().sum(),"total uppercase lines")
    print(all_character_name_lines.shape[0],"uppercase character name lines")
    print(all_dialogue_lines.shape[0],"uppercase dialogue lines")
    
    unique_lines_to_remove = upper_rows[~(upper_rows["is_character_name"]|upper_rows["is_dialogue"])]["line"]
    removed_lines = df["line"].isin(unique_lines_to_remove)
    print(removed_lines.sum(),"uppercase lines removed")
    
    return df[~removed_lines], df[removed_lines]

# %% [markdown]
# ## Merge Lines

# %%
def is_character_name(string,character_names):
    return string in character_names["line"].tolist()
    

def merge_lines(df,character_names):
    '''
    Starts at a character name and merges all lines until the next character's name.
    The result should be the best guess at columns "character" and "line".
    This will merge in some screenplay text that is not dialogue, so the result will 
    have to be manually cleaned as the final step.
    '''
    merged_df = pd.DataFrame(columns=["character","line"])
    
    for i in range(0,df.shape[0]):
        
        row = df.iloc[i]
        
        if is_character_name(row["line"],character_names):
            character = row["line"]
            line = ""
            
            j = i + 1
            while(j < len(df) and (not is_character_name(df.iloc[j]["line"],character_names))):
                line += df.iloc[j]["line"] + " "
                j += 1
            
            new_row = {"character": character,"line": line}
            
            merged_df = merged_df.append(new_row,ignore_index=True)
    
    return merged_df

# %% [markdown]
# ## Guardians of the Galaxy 2

# %%
guardians = pd.read_csv("./script txts/guardians-of-the-galaxy-vol-2-script-slug.txt",sep="\n",header=None,names=["line"])

guardians, garbage_rows = remove_garbage_rows(guardians)
format_lines(guardians)

create_uppercase_unique_csv(guardians,"guardians2")
filled_out_upper_rows = pd.read_csv("./uppercase results/guardians2_uppercase_unique.csv",
                                    names=["","line","words","is_character_name","is_dialogue"],
                                    dtype={"line":str, "words":int, "is_character_name":bool, "is_dialogue":bool},
                                    index_col=0)

guardians, upper_removed_rows = remove_non_dialogue_upper_rows(guardians, filled_out_upper_rows)
removed_rows = pd.concat([garbage_rows,pd.concat([upper_removed_rows],keys=[""])],keys=["garbage","uppercase"])

unique_character_names = pd.DataFrame(filled_out_upper_rows[filled_out_upper_rows["is_character_name"]]["line"])

guardians = merge_lines(guardians, unique_character_names)
guardians.reindex(copy=False)

guardians.to_csv("./uncleaned/guardians2_uncleaned.csv", index=False)

guardians = pd.read_csv("./cleaned/guardians2.csv")

guardians
# Out:
# 140 whitespace rows removed
# 141 page number rows removed
# Removed 1 rows that match regex "INTERCUT"
# Removed 3 rows that match regex "CUT TO"
# Removed 2 rows that match regex "^THE END"
# Removed 135 rows that match regex "^INT\."
# Removed 69 rows that match regex "^EXT\."
# Removed 0 rows that match regex "CONTINUED"
# Removed 0 rows that match regex "^[0-9]+\.$"
# Removed 0 rows that match regex "\(.*radio\)"
# Removed 0 rows that match regex "\(.*earpiece\)"
# Removed 0 rows that match regex "\(.*headset\)"
# Removed 0 rows that match regex "\(.*phone\)"
# Removed 0 rows that match regex "\(.*cell\)"
# Removed 3 rows that match regex "\(to .*\)"
# Removed 0 rows that match regex "\(in .*\)"
# Removed 7 rows that match regex "\(MORE\)"
# Removed 0 rows that match regex "\(angry\)"
# Removed 0 rows that match regex "TIME CUT:"
# Removed 0 rows that match regex "TITLE:"
# Removed 0 rows that match regex "SLAM TO"
# Removed 0 rows that match regex "DISSOLVE TO"
# Removed 3 rows that match regex "FADE"
# Removed 0 rows that match regex "BEST ADAPTED SCREENPLAY"
# Removed 0 rows that match regex "MARVEL"
# Removed 140 rows that match regex "© Marvel"
# Removed 0 rows that match regex "FADE TO BLACK"
# Removed 0 rows that match regex "CUE MUSIC"
# Removed 0 rows that match regex "BLUE DRAFT 05/20/16"
# Removed 0 rows that match regex "SALMON #2"
# Removed 0 rows that match regex "../../.."
# Removed 0 rows that match regex "OMITTED"
# Removed 0 rows that match regex "MAIN TITLE"
# Removed 4 rows that match regex "[A-J][0-9]+"
# Removed 0 rows that match regex "[0-9]+[A-J]"
# Removed 0 rows that match regex "\*"
# Removed 0 rows that match regex "\(.*:\)"
# Removed 1 rows that match regex "^\(beat\)$"
# Removed 4 rows that match regex "\(re:.*\)"
# -----------------------------------------
# 653 total rows removed
#
# Removed 4 occurences of regex "\(O\.S\)"
# Removed 0 occurences of regex "\(V\.O\)"
# Removed 0 occurences of regex "\(V\.O\.\)"
# Removed 147 occurences of regex "\(CONT.D\)"
# Removed 0 occurences of regex "\(cont.d\)"
# Removed 18 occurences of regex "\(O\.S\.\)"
# Removed 4 occurences of regex "\(ON.*\)"
# Removed 0 occurences of regex "\(OVER.*\)"
# Removed 0 occurences of regex "\(INTO.*\)"
# Removed 0 occurences of regex "\(HOLO\)"
# Removed 0 occurences of regex "\(ADR\)"
# Removed 0 occurences of regex "\(then\)"
# Removed 0 occurences of regex " \(RHODEY’S VOICE\)"
# Removed 1 occurences of regex " \(PRE-LAP\)"
#
# Created ./uppercase forms/guardians2_uppercase_unique_form.csv
#
# 1190 total uppercase lines
# 999 uppercase character name lines
# 22 uppercase dialogue lines
# 169 uppercase lines removed
#               character  \
# 0              MEREDITH
# 1        MYSTERIOUS MAN
# 2              MEREDITH
# 3              MEREDITH
# 4        MYSTERIOUS MAN
# 5        MYSTERIOUS MAN
# 6              MEREDITH
# 7        MYSTERIOUS MAN
# 8              MEREDITH
# 9        MYSTERIOUS MAN
# 10             MEREDITH
# 11                QUILL
# 12               GAMORA
# 13                QUILL
# 14               GAMORA
# 15                QUILL
# 16               GAMORA
# 17                QUILL
# 18               GAMORA
# 19                 DRAX
# 20               GAMORA
# 21                 DRAX
# 22                 DRAX
# 23               ROCKET
# 24                 DRAX
# 25               ROCKET
# 26                QUILL
# 27               ROCKET
# 28                QUILL
# 29               ROCKET
# 30                 DRAX
# 31               ROCKET
# 32                GROOT
# 33               ROCKET
# 34               ROCKET
# 35                QUILL
# 36               GAMORA
# 37               GAMORA
# 38               ROCKET
# 39               ROCKET
# 40                 DRAX
# 41               GAMORA
# 42               GAMORA
# 43                QUILL
# 44               GAMORA
# 45                QUILL
# 46               GAMORA
# 47                QUILL
# 48               GAMORA
# 49                QUILL
# 50                QUILL
# 51                 DRAX
# 52                 DRAX
# 53                 DRAX
# 54                QUILL
# 55                 DRAX
# 56                QUILL
# 57                QUILL
# 58                 DRAX
# 59                QUILL
# 60               GAMORA
# 61               AYESHA
# 62               AYESHA
# 63                QUILL
# 64               AYESHA
# 65                QUILL
# 66                QUILL
# 67               GAMORA
# 68                QUILL
# 69               AYESHA
# 70               GAMORA
# 71               AYESHA
# 72                QUILL
# 73               AYESHA
# 74                QUILL
# 75               AYESHA
# 76                QUILL
# 77               AYESHA
# 78               ROCKET
# 79               ROCKET
# 80                 DRAX
# 81               ROCKET
# 82               ROCKET
# 83               GAMORA
# 84                QUILL
# 85               GAMORA
# 86                QUILL
# 87                QUILL
# 88               GAMORA
# 89                QUILL
# 90                 DRAX
# 91                 DRAX
# 92                QUILL
# 93                 DRAX
# 94                 DRAX
# 95                QUILL
# 96                 DRAX
# 97                QUILL
# 98                 DRAX
# 99               NEBULA
# 100              GAMORA
# 101              NEBULA
# 102              GAMORA
# 103              GAMORA
# 104              NEBULA
# 105              GAMORA
# 106              NEBULA
# 107              GAMORA
# 108              NEBULA
# 109              GAMORA
# 110              NEBULA
# 111              GAMORA
# 112               QUILL
# 113              GAMORA
# 114                DRAX
# 115              ROCKET
# 116                DRAX
# 117               QUILL
# 118              ROCKET
# 119              GAMORA
# 120              ROCKET
# 121               QUILL
# 122              ROCKET
# 123               QUILL
# 124              ROCKET
# 125               QUILL
# 126                DRAX
# 127              ROCKET
# 128                DRAX
# 129              ROCKET
# 130              GAMORA
# 131              ROCKET
# 132               QUILL
# 133              ROCKET
# 134               QUILL
# 135              ROCKET
# 136     SOVEREIGN PILOT
# 137              GAMORA
# 138              AYESHA
# 139             ADMIRAL
# 140              AYESHA
# 141             ADMIRAL
# 142             ADMIRAL
# 143               QUILL
# 144              GAMORA
# 145               QUILL
# 146              GAMORA
# 147                DRAX
# 148               QUILL
# 149              ROCKET
# 150              ROCKET
# 151               QUILL
# 152              ROCKET
# 153               QUILL
# 154              GAMORA
# 155              ROCKET
# 156               QUILL
# 157              ROCKET
# 158                DRAX
# 159              GAMORA
# 160                DRAX
# 161               QUILL
# 162              GAMORA
# 163              NEBULA
# 164              ROCKET
# 165              ROCKET
# 166              GAMORA
# 167               QUILL
# 168              GAMORA
# 169               QUILL
# 170    FRIGHTENED PILOT
# 171                DRAX
# 172              GAMORA
# 173              GAMORA
# 174                DRAX
# 175    FRIGHTENED PILOT
# 176              GAMORA
# 177               QUILL
# 178             ADMIRAL
# 179              AYESHA
# 180              ROCKET
# 181               QUILL
# 182              ROCKET
# 183              GAMORA
# 184               QUILL
# 185               QUILL
# 186                DRAX
# 187                DRAX
# 188              GAMORA
# 189               QUILL
# 190              GAMORA
# 191               QUILL
# 192                DRAX
# 193               QUILL
# 194              ROCKET
# 195              ROCKET
# 196               QUILL
# 197              ROCKET
# 198               QUILL
# 199              ROCKET
# 200                DRAX
# 201              ROCKET
# 202              GAMORA
# 203              ROCKET
# 204               QUILL
# 205              ROCKET
# 206               QUILL
# 207              ROCKET
# 208                DRAX
# 209               QUILL
# 210              ROCKET
# 211              NEBULA
# 212              NEBULA
# 213              GAMORA
# 214              NEBULA
# 215              GAMORA
# 216              NEBULA
# 217               QUILL
# 218                DRAX
# 219      MYSTERIOUS MAN
# 220               QUILL
# 221      MYSTERIOUS MAN
# 222               TULLK
# 223              STAKAR
# 224               YONDU
# 225               YONDU
# 226              STAKAR
# 227               YONDU
# 228              STAKAR
# 229          PROPRIETOR
# 230               YONDU
# 231              STAKAR
# 232               YONDU
# 233              STAKAR
# 234               YONDU
# 235              STAKAR
# 236               YONDU
# 237              STAKAR
# 238   MONSTROUS RAVAGER
# 239             KRAGLIN
# 240   MONSTROUS RAVAGER
# 241               TULLK
# 242               RETCH
# 243              AYESHA
# 244                 EGO
# 245                 EGO
# 246               QUILL
# 247                 EGO
# 248                DRAX
# 249               QUILL
# 250               QUILL
# 251                DRAX
# 252              ROCKET
# 253               QUILL
# 254                 EGO
# 255               QUILL
# 256                 EGO
# 257              GAMORA
# 258                 EGO
# 259                 EGO
# 260                 EGO
# 261               QUILL
# 262              GAMORA
# 263              MANTIS
# 264                DRAX
# 265              MANTIS
# 266                DRAX
# 267              MANTIS
# 268              MANTIS
# 269                DRAX
# 270              MANTIS
# 271                DRAX
# 272              MANTIS
# 273               QUILL
# 274              GAMORA
# 275               QUILL
# 276              GAMORA
# 277               QUILL
# 278              GAMORA
# 279               QUILL
# 280              GAMORA
# 281               QUILL
# 282              GAMORA
# 283               QUILL
# 284              GAMORA
# 285               QUILL
# 286              GAMORA
# 287               QUILL
# 288              GAMORA
# 289               QUILL
# 290              GAMORA
# 291              GAMORA
# 292              GAMORA
# 293              NEBULA
# 294              GAMORA
# 295              GAMORA
# 296              GAMORA
# 297                DRAX
# 298               QUILL
# 299                DRAX
# 300               QUILL
# 301                DRAX
# 302               QUILL
# 303                DRAX
# 304              ROCKET
# 305               QUILL
# 306               QUILL
# 307              MANTIS
# 308               QUILL
# 309              MANTIS
# 310                DRAX
# 311               QUILL
# 312                DRAX
# 313               QUILL
# 314              MANTIS
# 315                DRAX
# 316               QUILL
# 317              MANTIS
# 318              GAMORA
# 319              MANTIS
# 320               QUILL
# 321              MANTIS
# 322              MANTIS
# 323              MANTIS
# 324               QUILL
# 325              MANTIS
# 326               QUILL
# 327              MANTIS
# 328               QUILL
# 329                DRAX
# 330               QUILL
# 331                DRAX
# 332              MANTIS
# 333               QUILL
# 334               QUILL
# 335              GAMORA
# 336              MANTIS
# 337               QUILL
# 338              MANTIS
# 339                DRAX
# 340              MANTIS
# 341              GAMORA
# 342               QUILL
# 343        TALL RAVAGER
# 344               BRAHL
# 345              ROCKET
# 346               YONDU
# 347              ROCKET
# 348               YONDU
# 349              NEBULA
# 350              NEBULA
# 351               YONDU
# 352              ROCKET
# 353               YONDU
# 354   MONSTROUS RAVAGER
# 355               YONDU
# 356   MONSTROUS RAVAGER
# 357               YONDU
# 358                OBLO
# 359     GEF THE RAVAGER
# 360               YONDU
# 361     GEF THE RAVAGER
# 362               YONDU
# 363             KRAGLIN
# 364             KRAGLIN
# 365   MONSTROUS RAVAGER
# 366             KRAGLIN
# 367               TULLK
# 368              ROCKET
# 369              NEBULA
# 370              NEBULA
# 371                 EGO
# 372               QUILL
# 373                 EGO
# 374                DRAX
# 375               QUILL
# 376                 EGO
# 377                 EGO
# 378              GAMORA
# 379               QUILL
# 380              GAMORA
# 381                DRAX
# 382              GAMORA
# 383                DRAX
# 384              GAMORA
# 385                 EGO
# 386               QUILL
# 387                 EGO
# 388                 EGO
# 389                 EGO
# 390                 EGO
# 391                 EGO
# 392                 EGO
# 393               QUILL
# 394                 EGO
# 395                 EGO
# 396                 EGO
# 397                DRAX
# 398               QUILL
# 399                DRAX
# 400               QUILL
# 401                DRAX
# 402               QUILL
# 403                DRAX
# 404                 EGO
# 405               QUILL
# 406                 EGO
# 407                 EGO
# 408                 EGO
# 409               QUILL
# 410                 EGO
# 411                 EGO
# 412                 EGO
# 413               QUILL
# 414               TULLK
# 415               TULLK
# 416                OBLO
# 417   MONSTROUS RAVAGER
# 418   MONSTROUS RAVAGER
# 419   MONSTROUS RAVAGER
# 420   MONSTROUS RAVAGER
# 421              ROCKET
# 422           TASERFACE
# 423              ROCKET
# 424           TASERFACE
# 425              ROCKET
# 426           TASERFACE
# 427              ROCKET
# 428           TASERFACE
# 429           TASERFACE
# 430           TASERFACE
# 431              ROCKET
# 432              ROCKET
# 433           TASERFACE
# 434              ROCKET
# 435              NEBULA
# 436           TASERFACE
# 437              NEBULA
# 438              NEBULA
# 439              NEBULA
# 440             KRAGLIN
# 441              NEBULA
# 442             KRAGLIN
# 443              NEBULA
# 444             KRAGLIN
# 445              NEBULA
# 446             KRAGLIN
# 447             KRAGLIN
# 448               QUILL
# 449               QUILL
# 450                 EGO
# 451               QUILL
# 452                 EGO
# 453               QUILL
# 454                 EGO
# 455               QUILL
# 456                 EGO
# 457                 EGO
# 458               QUILL
# 459                 EGO
# 460                 EGO
# 461                 EGO
# 462               QUILL
# 463                 EGO
# 464                 EGO
# 465                 EGO
# 466                 EGO
# 467                 EGO
# 468                 EGO
# 469                DRAX
# 470              MANTIS
# 471                DRAX
# 472              MANTIS
# 473                DRAX
# 474              MANTIS
# 475                DRAX
# 476                DRAX
# 477              MANTIS
# 478                DRAX
# 479              MANTIS
# 480                DRAX
# 481              MANTIS
# 482                DRAX
# 483              MANTIS
# 484              MANTIS
# 485              GAMORA
# 486              MANTIS
# 487              GAMORA
# 488              GAMORA
# 489              GAMORA
# 490              MANTIS
# 491              GAMORA
# 492              MANTIS
# 493              GAMORA
# 494              MANTIS
# 495              MANTIS
# 496           TASERFACE
# 497              ROCKET
# 498     GEF THE RAVAGER
# 499           TASERFACE
# 500              ROCKET
# 501               YONDU
# 502              ROCKET
# 503               YONDU
# 504               YONDU
# 505              ROCKET
# 506               YONDU
# 507              ROCKET
# 508               YONDU
# 509              ROCKET
# 510              ROCKET
# 511               YONDU
# 512              ROCKET
# 513               YONDU
# 514               YONDU
# 515               RETCH
# 516               RETCH
# 517            HALF-NUT
# 518               YONDU
# 519              ROCKET
# 520               YONDU
# 521               YONDU
# 522               YONDU
# 523               YONDU
# 524               YONDU
# 525              ROCKET
# 526               YONDU
# 527              ROCKET
# 528               YONDU
# 529               YONDU
# 530              ROCKET
# 531               YONDU
# 532              ROCKET
# 533              ROCKET
# 534              ROCKET
# 535              ROCKET
# 536               YONDU
# 537               YONDU
# 538              ROCKET
# 539               YONDU
# 540               GROOT
# 541              ROCKET
# 542               GROOT
# 543              ROCKET
# 544               GROOT
# 545              ROCKET
# 546               GROOT
# 547              ROCKET
# 548               YONDU
# 549              ROCKET
# 550             KRAGLIN
# 551             KRAGLIN
# 552               YONDU
# 553              ROCKET
# 554              ROCKET
# 555           TASERFACE
# 556           TASERFACE
# 557               RETCH
# 558  SCURRILOUS RAVAGER
# 559              ROCKET
# 560               YONDU
# 561         CHAMBERMAID
# 562           TASERFACE
# 563               YONDU
# 564             KRAGLIN
# 565           TASERFACE
# 566             KRAGLIN
# 567              ROCKET
# 568               YONDU
# 569               YONDU
# 570              ROCKET
# 571               YONDU
# 572               QUILL
# 573              GAMORA
# 574              GAMORA
# 575               QUILL
# 576              GAMORA
# 577               QUILL
# 578               QUILL
# 579              GAMORA
# 580               QUILL
# 581              GAMORA
# 582               QUILL
# 583              GAMORA
# 584               QUILL
# 585              GAMORA
# 586              GAMORA
# 587               QUILL
# 588              GAMORA
# 589               QUILL
# 590              GAMORA
# 591               QUILL
# 592              GAMORA
# 593               QUILL
# 594              GAMORA
# 595               QUILL
# 596              GAMORA
# 597               QUILL
# 598              GAMORA
# 599               QUILL
# 600              GAMORA
# 601               QUILL
# 602              GAMORA
# 603               QUILL
# 604              GAMORA
# 605              GAMORA
# 606              GAMORA
# 607              GAMORA
# 608              NEBULA
# 609              NEBULA
# 610              GAMORA
# 611              NEBULA
# 612              GAMORA
# 613              NEBULA
# 614              GAMORA
# 615              NEBULA
# 616              GAMORA
# 617              NEBULA
# 618              GAMORA
# 619              NEBULA
# 620              NEBULA
# 621                 EGO
# 622                 EGO
# 623               QUILL
# 624                 EGO
# 625               QUILL
# 626                 EGO
# 627               QUILL
# 628                 EGO
# 629               QUILL
# 630                 EGO
# 631                 EGO
# 632                 EGO
# 633               QUILL
# 634                 EGO
# 635               QUILL
# 636                 EGO
# 637               QUILL
# 638                 EGO
# 639               QUILL
# 640                 EGO
# 641               QUILL
# 642                 EGO
# 643                 EGO
# 644               QUILL
# 645                 EGO
# 646              MANTIS
# 647              MANTIS
# 648                DRAX
# 649              MANTIS
# 650                DRAX
# 651              MANTIS
# 652              MANTIS
# 653                DRAX
# 654              MANTIS
# 655                DRAX
# 656              MANTIS
# 657              GAMORA
# 658                 EGO
# 659               QUILL
# 660                 EGO
# 661                 EGO
# 662                 EGO
# 663                 EGO
# 664                 EGO
# 665               QUILL
# 666              GAMORA
# 667              NEBULA
# 668            STAN LEE
# 669               YONDU
# 670              ROCKET
# 671               YONDU
# 672              ROCKET
# 673              ROCKET
# 674               YONDU
# 675              ROCKET
# 676               YONDU
# 677              ROCKET
# 678               YONDU
# 679              ROCKET
# 680               YONDU
# 681              ROCKET
# 682               YONDU
# 683              ROCKET
# 684               YONDU
# 685              ROCKET
# 686                DRAX
# 687              GAMORA
# 688                DRAX
# 689              NEBULA
# 690                DRAX
# 691              GAMORA
# 692              MANTIS
# 693                 EGO
# 694               QUILL
# 695                 EGO
# 696                 EGO
# 697              GAMORA
# 698                DRAX
# 699                 EGO
# 700              MANTIS
# 701                 EGO
# 702                 EGO
# 703                 EGO
# 704              GAMORA
# 705              MANTIS
# 706              NEBULA
# 707              GAMORA
# 708              NEBULA
# 709                DRAX
# 710              NEBULA
# 711                 EGO
# 712                 EGO
# 713               QUILL
# 714                 EGO
# 715               QUILL
# 716                 EGO
# 717               QUILL
# 718                 EGO
# 719               QUILL
# 720                 EGO
# 721               QUILL
# 722                 EGO
# 723               QUILL
# 724               QUILL
# 725                 EGO
# 726               QUILL
# 727                 EGO
# 728                 EGO
# 729               QUILL
# 730                 EGO
# 731                 EGO
# 732                 EGO
# 733              GAMORA
# 734              ROCKET
# 735              GAMORA
# 736              ROCKET
# 737               YONDU
# 738              ROCKET
# 739               YONDU
# 740              ROCKET
# 741               QUILL
# 742                 EGO
# 743               YONDU
# 744                DRAX
# 745              GAMORA
# 746               QUILL
# 747              GAMORA
# 748               QUILL
# 749              GAMORA
# 750                DRAX
# 751              ROCKET
# 752                DRAX
# 753              MANTIS
# 754               QUILL
# 755              NEBULA
# 756              ROCKET
# 757              NEBULA
# 758              GAMORA
# 759               GROOT
# 760              ROCKET
# 761               GROOT
# 762              ROCKET
# 763                DRAX
# 764               QUILL
# 765              MANTIS
# 766               QUILL
# 767              NEBULA
# 768               YONDU
# 769               QUILL
# 770               YONDU
# 771               QUILL
# 772               YONDU
# 773               QUILL
# 774               YONDU
# 775               QUILL
# 776              ROCKET
# 777               QUILL
# 778               YONDU
# 779               QUILL
# 780               QUILL
# 781              ROCKET
# 782              ROCKET
# 783               QUILL
# 784              ROCKET
# 785               QUILL
# 786              ROCKET
# 787               QUILL
# 788              ROCKET
# 789              MANTIS
# 790                DRAX
# 791              AYESHA
# 792              AYESHA
# 793              AYESHA
# 794             KRAGLIN
# 795             KRAGLIN
# 796               YONDU
# 797               QUILL
# 798               YONDU
# 799               QUILL
# 800               YONDU
# 801               QUILL
# 802               YONDU
# 803               YONDU
# 804               QUILL
# 805              GAMORA
# 806              MANTIS
# 807              GAMORA
# 808              MANTIS
# 809              ROCKET
# 810               QUILL
# 811               YONDU
# 812             KRAGLIN
# 813               YONDU
# 814               YONDU
# 815               QUILL
# 816              ROCKET
# 817              NEBULA
# 818              ROCKET
# 819               QUILL
# 820              ROCKET
# 821               QUILL
# 822              ROCKET
# 823               QUILL
# 824              MANTIS
# 825                DRAX
# 826              MANTIS
# 827                DRAX
# 828              MANTIS
# 829                DRAX
# 830              MANTIS
# 831              GAMORA
# 832              ROCKET
# 833               QUILL
# 834              ROCKET
# 835               QUILL
# 836              ROCKET
# 837               QUILL
# 838              ROCKET
# 839               GROOT
# 840              ROCKET
# 841               GROOT
# 842              ROCKET
# 843               GROOT
# 844              ROCKET
# 845               GROOT
# 846               GROOT
# 847               GROOT
# 848              ROCKET
# 849              ROCKET
# 850               QUILL
# 851              ROCKET
# 852               QUILL
# 853               QUILL
# 854               QUILL
# 855              ROCKET
# 856               QUILL
# 857              ROCKET
# 858               QUILL
# 859              ROCKET
# 860               YONDU
# 861              AYESHA
# 862              AYESHA
# 863               YONDU
# 864              NEBULA
# 865                DRAX
# 866              AYESHA
# 867              AYESHA
# 868               QUILL
# 869              GAMORA
# 870               YONDU
# 871               QUILL
# 872               YONDU
# 873               QUILL
# 874               YONDU
# 875               QUILL
# 876                DRAX
# 877               QUILL
# 878              ROCKET
# 879               YONDU
# 880               YONDU
# 881             KRAGLIN
# 882               QUILL
# 883                DRAX
# 884               QUILL
# 885              NEBULA
# 886              GAMORA
# 887                 EGO
# 888                 EGO
# 889  OFFICER FITZGIBBON
# 890       WEIRD OLD MAN
# 891       GRANDPA QUILL
# 892                 EGO
# 893                 EGO
# 894                 EGO
# 895                 EGO
# 896                 EGO
# 897                 EGO
# 898               YONDU
# 899               QUILL
# 900              ROCKET
# 901              ROCKET
# 902               YONDU
# 903              ROCKET
# 904               YONDU
# 905              ROCKET
# 906               YONDU
# 907              ROCKET
# 908               GROOT
# 909               YONDU
# 910              ROCKET
# 911               YONDU
# 912              ROCKET
# 913              GAMORA
# 914              GAMORA
# 915              GAMORA
# 916              GAMORA
# 917              ROCKET
# 918                DRAX
# 919                DRAX
# 920                 EGO
# 921                 EGO
# 922               QUILL
# 923                 EGO
# 924               YONDU
# 925               QUILL
# 926               YONDU
# 927               QUILL
# 928               QUILL
# 929               QUILL
# 930               QUILL
# 931               QUILL
# 932               QUILL
# 933               QUILL
# 934               QUILL
# 935               QUILL
# 936               GROOT
# 937              ROCKET
# 938               GROOT
# 939              ROCKET
# 940              GAMORA
# 941              GAMORA
# 942              GAMORA
# 943               QUILL
# 944              NEBULA
# 945              GAMORA
# 946              GAMORA
# 947             KRAGLIN
# 948             KRAGLIN
# 949             KRAGLIN
# 950               QUILL
# 951               QUILL
# 952             KRAGLIN
# 953              ROCKET
# 954                DRAX
# 955              ROCKET
# 956               QUILL
# 957            MARTINEX
# 958              STAKAR
# 959          CHARLIE-27
# 960               ALETA
# 961              ROCKET
# 962               QUILL
# 963              ROCKET
# 964              ROCKET
# 965              ROCKET
# 966               QUILL
# 967               QUILL
# 968              GAMORA
# 969              MANTIS
# 970                DRAX
# 971              STAKAR
# 972              STAKAR
# 973          CHARLIE-27
# 974            MARTINEX
# 975           MAINFRAME
# 976               ALETA
# 977         CHAMBERMAID
# 978              AYESHA
# 979              AYESHA
# 980         CHAMBERMAID
# 981              AYESHA
# 982              AYESHA
# 983               QUILL
# 984    ADOLESCENT GROOT
# 985               QUILL
# 986               QUILL
# 987               QUILL
# 988               QUILL
# 989               QUILL
# 990               QUILL
# 991               QUILL
# 992               QUILL
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     line
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Do do do do do do do do do do do!
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              This way, my river lily.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Where are you taking me?
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Oh. It’s beautiful.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      I was afraid it wouldn’t take to the soil, but it rooted quickly.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Soon it will be everywhere - all across the universe, fulfilling life’s one true purpose.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Which is what?
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Expansion.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 I’m not sure what you’re talking about. But I like the way you say it.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    My heart is yours, Meredith Quill.
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       I can’t believe I fell in love with a spaceman.
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Showtime, a-holes! It’ll be here any minute!
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Which will be its loss.
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Is that a rifle?
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       You don’t know what a rifle is?
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     I thought your thing was a sword.
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                   We’ve been hired to stop an interdimensional beast from feeding on those batteries’ energy, and I’m going to stop it with a sword?
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Don’t look at me like I’m stupid. You’re the one being all inconsistent.
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Drax, why aren’t you wearing one of Rocket’s aero-rigs?
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             It hurts.
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Hurts?
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             I have sensitive nipples.
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    What about him?! What’s he doing?!
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              If I finish this, we can listen to tunes while we work.
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               How is that a priority?
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Blame Quill! He’s the one who loves music so much!
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   I agree with Drax. It’s hardly important right now.
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Oh, sure, okayyyy, Quill.
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         No, I really agree with him.
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Sure, I know.
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        I can clearly see you winking.
# ...
# 965                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               And he stole batteries he didn’t need.
# 966                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Of course not.
# 967                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                What?
# 968                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       It’s just some unspoken thing.
# 969                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      It’s beautiful.
# 970                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               It is.  And so are you. On the inside.
# 971                                                                                                                                                                                                                                                                                                                                                                                                                               It’s a shame it takes a tragedy like losing Yondu to bring us all back together. But I think he’d be proud if he knew we were working as a team again.
# 972                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         What say we steal some shit?
# 973                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  In.
# 974                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Dope.
# 975                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   I MISSED you guys!
# 976                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Hell. Yes.
# 977                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             High Priestess, the Council is waiting.
# 978                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      They are perturbed I have wasted our resources.
# 979                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     When they see what I have created here, their wrath will dissipate, though it will be some time.
# 980                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       That is not just another birthing pod, ma’am?
# 981                                                                                                                                                                                                                                                                                                                                                                                                                                        That, my child, is the next step in our evolution: more powerful, more beautiful, and more capable of destroying the Guardians of the Galaxy.
# 982                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  I think I shall call him... ‘Adam’.
# 983                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Dude, seriously, you got to clean up your room. It’s a complete mess.
# 984                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          I am Groot.
# 985                                                                                                                                                                                                                                                                                                                                                                                                                 I’m not boring, man. You’re boring. Once I got stuck on a planet where everyone was just lines and dots. I had to use geometry to get out of prison. Is that boring?
# 986                                                                                                                                                                                                                                                                                                                                                                                                                                                                               You know what’s boring? Not doing the dishes. What’s boring is me tripping over your vines everywhere.
# 987                                                                                                                                                                                                                                                                                                                                                                                                                                                 Drax and I switched pants in the middle of that party last weekend. For no reason other than we’re awesome and very much not boring.
# 988                                                                                                                                                                                                                                                                                                                                                                                                                              Once I got a venereal disease that made me float for three days... Don’t tell Gamora... it’s dormant, but... If that’s boring then, I guess I’m boring.
# 989                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      I’m not boring.
# 990                                                                                                                                                                                                                                                                                                                                                                                                                                                        What’s boring is when you roll your eyes like that at me and make an exasperated sound like I’m an old, boring, stupid idiot.
# 991                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Now I know how Yondu felt.
# 992                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Yondu.
