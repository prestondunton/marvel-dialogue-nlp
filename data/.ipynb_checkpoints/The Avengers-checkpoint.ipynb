# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Script to CSV Process
#
# 1. Load script `.txt` file.  Use [PDF Extractor](https://pdfextractor.com/) to convert any `.pdf`s to `.txt`s.
# 2. Remove garbage rows
# 3. Inspect rows removed
# 4. Format lines
# 5. Create `uppercase_unique_form.csv`
# 6. Manually fill out `uppercase_unique_form.csv` columns `is_character_name` and `is_dialogue` in Excel or other `.csv` editor.
# 7. Load `uppercase_unique.csv` and filter out rows
# 8. Inspect rows removed
# 9. Merge lines into best guesses for columns "character" and "line"
# 10. Manually clean the "line" column by removing text that is not dialogue.  There will be a lot, so nearly every cell will have to be cleaned!
#
#
# See the Avengers Endgame script at the end of this notebook for an example of this process.

# %% [markdown]
# ## Remove Garbage Rows

# %%
def remove_regex_rows(df,string):
    rows_to_remove = df["line"].str.contains(string,case=True,regex=True)
    print("Removed",rows_to_remove.sum(),"rows that match regex \"" + string + "\"")
    
    return df[~rows_to_remove], df[rows_to_remove]

def remove_whitespace_rows(df):
    whitespace_rows = df["line"].str.isspace()
    print(whitespace_rows.sum(),"whitespace rows removed")
    return df[~whitespace_rows], df[whitespace_rows]

def remove_movie_text_rows(df):
    
    regex_strings = ["INTERCUT:",
                    "CUT TO",
                    "^THE END",
                    "^INT\.",
                    "^EXT\.",
                    "\(CONTINUED\)",
                    "CONTINUED: \(.\)",
                    "[0-9]+\.",
                    "\(.*radio\)",
                    "\(.*earpiece\)",
                    "\(.*headset\)",
                    "\(.*phone\)",
                    "\(.*cell\)",
                    "\(to .*\)",
                    "\(in .*\)",
                    "\(MORE\)",
                    "\(angry\)",
                    "TIME CUT:",
                    "TITLE:",
                    "MARVEL FLIP",
                    "SLAM TO",
                    "DISSOLVE TO",
                    "BEST ADAPTED SCREENPLAY",
                    "FADE TO BLACK",
                    "CUE MUSIC"]
    
    removed_rows = pd.DataFrame()
    
    for regex_string in regex_strings:
        df, new_rows_to_remove = remove_regex_rows(df,regex_string)
        
        removed_rows = pd.concat([removed_rows, new_rows_to_remove])
    
    return df, removed_rows


def remove_page_number_rows(df):
    page_rows = df["line"].str.isnumeric()
    print(page_rows.sum(),"page number rows removed")
    
    return df[~page_rows], df[page_rows]

def remove_garbage_rows(df):
    df, whitespace_rows = remove_whitespace_rows(df)
    df, page_number_rows = remove_page_number_rows(df)
    df, movie_text_rows = remove_movie_text_rows(df)
    
    garbage_rows = pd.concat([whitespace_rows, page_number_rows, movie_text_rows], 
                            keys = ["whitespace","page_numbers","movie_text"])
    
    print("-----------------------------------------")
    print(garbage_rows.shape[0],"total rows removed\n")
    
    return df, garbage_rows

# %% [markdown]
# ## Format Character Lines

# %%
def remove_regex(df,string):
    print("Removed",df["line"].str.count(string).sum(),"occurences of regex \"" + string + "\"")
    df["line"] = df["line"].str.replace(string,"",case=True,regex=True)

def remove_leading_trailing_whitespace(df):
    df["line"] = df["line"].str.replace("[ \t]+$","")
    df["line"] = df["line"].str.replace("^[ \t]+","")

def format_lines(df):
    remove_leading_trailing_whitespace(df)
    
    regex_strings = ["\(O\.S\)",
                    "\(V\.O\)",
                    "\(CONT’D\)",
                    "\(O\.S\.\)",
                    "\(ON SCREEN\)",
                    "\(OVER COM\)",
                    "\(ON COM\)",
                    "\(INTO COM\)",
                    "\(OVER SPEAKER\)",
                    "\(INTO PHONE\)",
                    "\(OVER PHONE\)",
                    "\(HOLO\)"]
    
    for regex_string in regex_strings:
        remove_regex(df, regex_string)
    
    print("")
    
    remove_leading_trailing_whitespace(df)

# %% [markdown]
# ## Remove Non Dialogue Uppercase Rows

# %%
def uppercase_rows(df):
    upper_lines = df["line"].str.isupper()
    
    return df[upper_lines]

def create_uppercase_unique_csv(df,script_name):
    '''
    Creates a csv file that is used for inspection of unique
    lines that are all uppercase.  These lines are manually labeled
    to be character names or dialogue.  The resulting table will be
    used to delete rows that are neither character names nor dialogue.
    '''
    
    upper_rows = uppercase_rows(df)
    unique_upper_rows = pd.DataFrame(upper_rows.line.unique())

    unique_upper_rows["words"] = unique_upper_rows[0].str.split(" ").str.len()
    unique_upper_rows["is_character_name"] = 0
    unique_upper_rows["is_dialogue"] = 0
    sorted_unique_upper_rows = unique_upper_rows.sort_values(by=["words"])
    sorted_unique_upper_rows.to_csv("./uppercase forms/" + script_name + "_uppercase_unique_form.csv",encoding='utf-8')
    
def remove_non_dialogue_upper_rows(df,upper_rows):
    '''
    Removes lines that are in all caps, and that are not dialogue or a character's name.
    '''
    unique_character_names = upper_rows[upper_rows["is_character_name"]]["line"]
    unique_dialogues = upper_rows[upper_rows["is_dialogue"]]["line"]
    
    all_character_name_lines = df[df["line"].isin(unique_character_names)]
    all_dialogue_lines = df[df["line"].isin(unique_dialogues)]
    
    print(df["line"].str.isupper().sum(),"total uppercase lines")
    print(all_character_name_lines.shape[0],"uppercase character name lines")
    print(all_dialogue_lines.shape[0],"uppercase dialogue lines")
    
    unique_lines_to_remove = upper_rows[~(upper_rows["is_character_name"]|upper_rows["is_dialogue"])]["line"]
    removed_lines = df["line"].isin(unique_lines_to_remove)
    print(removed_lines.sum(),"uppercase lines removed")
    
    return df[~removed_lines], df[removed_lines]

# %% [markdown]
# ## Merge Lines

# %%
def is_character_name(string,character_names):
    return string in character_names["line"].tolist()
    

def merge_lines(df,character_names):
    '''
    Starts at a character name and merges all lines until the next character's name.
    The result should be the best guess at columns "character" and "line".
    This will merge in some screenplay text that is not dialogue, so the result will 
    have to be manually cleaned as the final step.
    '''
    merged_df = pd.DataFrame(columns=["character","line"])
    
    for i in range(0,df.shape[0]):
        
        row = df.iloc[i]
        
        if is_character_name(row["line"],character_names):
            character = row["line"]
            line = ""
            
            j = i + 1
            while(j < len(df) and (not is_character_name(df.iloc[j]["line"],character_names))):
                line += df.iloc[j]["line"] + " "
                j += 1
            
            new_row = {"character": character,"line": line}
            
            merged_df = merged_df.append(new_row,ignore_index=True)
    
    return merged_df

# %% [markdown]
# ## The Avengers

# %%
avengers = pd.read_csv("./script txts/avengers-script-slug.txt",sep="\n",header=None,names=["line"])

avengers, garbage_rows = remove_garbage_rows(avengers)
format_lines(avengers)

create_uppercase_unique_csv(avengers,"avengers")
filled_out_upper_rows = pd.read_csv("./uppercase results/avengers_uppercase_unique.csv",
                                    names=["","line","words","is_character_name","is_dialogue"],
                                    dtype={"line":str, "words":int, "is_character_name":bool, "is_dialogue":bool},
                                    index_col=0)

avengers, upper_removed_rows = remove_non_dialogue_upper_rows(avengers, filled_out_upper_rows)
removed_rows = pd.concat([garbage_rows,pd.concat([upper_removed_rows],keys=[""])],keys=["garbage","uppercase"])

unique_character_names = pd.DataFrame(filled_out_upper_rows[filled_out_upper_rows["is_character_name"]]["line"])

avengers = merge_lines(avengers, unique_character_names)
avengers.reindex(copy=False)

avengers.to_csv("./uncleaned/avengers_uncleaned.csv", index=False)

avengers
# Out:
# 132 whitespace rows removed
# 440 page number rows removed
# Removed 6 rows that match regex "INTERCUT:"
# Removed 1 rows that match regex "CUT TO"
# Removed 1 rows that match regex "^THE END"
# Removed 122 rows that match regex "^INT\."
# Removed 98 rows that match regex "^EXT\."
# Removed 98 rows that match regex "\(CONTINUED\)"
# Removed 98 rows that match regex "CONTINUED: \(.\)"
# Removed 130 rows that match regex "[0-9]+\."
# Removed 28 rows that match regex "\(.*radio\)"
# Removed 26 rows that match regex "\(.*earpiece\)"
# Removed 9 rows that match regex "\(.*headset\)"
# Removed 1 rows that match regex "\(.*phone\)"
# Removed 12 rows that match regex "\(.*cell\)"
# Removed 40 rows that match regex "\(to .*\)"
# Removed 14 rows that match regex "\(in .*\)"
# Removed 3 rows that match regex "\(MORE\)"
# Removed 3 rows that match regex "\(angry\)"
# Removed 0 rows that match regex "TIME CUT:"
# Removed 0 rows that match regex "TITLE:"
# Removed 0 rows that match regex "MARVEL FLIP"
# Removed 0 rows that match regex "SLAM TO"
# Removed 0 rows that match regex "DISSOLVE TO"
# Removed 0 rows that match regex "BEST ADAPTED SCREENPLAY"
# Removed 0 rows that match regex "FADE TO BLACK"
# Removed 0 rows that match regex "CUE MUSIC"
# -----------------------------------------
# 1262 total rows removed
#
# Removed 8 occurences of regex "\(O\.S\)"
# Removed 39 occurences of regex "\(V\.O\)"
# Removed 19 occurences of regex "\(CONT’D\)"
# Removed 0 occurences of regex "\(O\.S\.\)"
# Removed 0 occurences of regex "\(ON SCREEN\)"
# Removed 0 occurences of regex "\(OVER COM\)"
# Removed 0 occurences of regex "\(ON COM\)"
# Removed 0 occurences of regex "\(INTO COM\)"
# Removed 0 occurences of regex "\(OVER SPEAKER\)"
# Removed 0 occurences of regex "\(INTO PHONE\)"
# Removed 0 occurences of regex "\(OVER PHONE\)"
# Removed 0 occurences of regex "\(HOLO\)"
#
# 1120 total uppercase lines
# 1031 uppercase character name lines
# 16 uppercase dialogue lines
# 73 uppercase lines removed
#                        character  \
# 0                      THE OTHER
# 1                      THE OTHER
# 2                      THE OTHER
# 3                 INTERCOM VOICE
# 4                 INTERCOM VOICE
# 5                 INTERCOM VOICE
# 6                           FURY
# 7                  AGENT COULSON
# 8                  AGENT COULSON
# 9                  AGENT COULSON
# 10                          FURY
# 11                 AGENT COULSON
# 12                    MARIA HILL
# 13                          FURY
# 14                 AGENT COULSON
# 15                          FURY
# 16                 AGENT COULSON
# 17                          FURY
# 18                    MARIA HILL
# 19                          FURY
# 20                    MARIA HILL
# 21                          FURY
# 22                    MARIA HILL
# 23                          FURY
# 24                    MARIA HILL
# 25                          FURY
# 26                        SELVIG
# 27                          FURY
# 28                        SELVIG
# 29                          FURY
# 30                        SELVIG
# 31                          FURY
# 32                        SELVIG
# 33                          FURY
# 34                        SELVIG
# 35                          FURY
# 36                        SELVIG
# 37                          FURY
# 38                          FURY
# 39                        BARTON
# 40                          FURY
# 41                NASA SCIENTIST
# 42                        BARTON
# 43                          FURY
# 44                        BARTON
# 45                        SELVIG
# 46                          FURY
# 47                          LOKI
# 48                          LOKI
# 49                          FURY
# 50                          LOKI
# 51                        SELVIG
# 52                          FURY
# 53                          LOKI
# 54                          FURY
# 55                          LOKI
# 56                          FURY
# 57                          LOKI
# 58                          FURY
# 59                        BARTON
# 60                          FURY
# 61                        SELVIG
# 62                          LOKI
# 63                        BARTON
# 64                    MARIA HILL
# 65                        BARTON
# 66                          FURY
# 67                          FURY
# 68                          FURY
# 69                          FURY
# 70                 AGENT COULSON
# 71                 AGENT COULSON
# 72                 AGENT COULSON
# 73                 AGENT COULSON
# 74                 AGENT COULSON
# 75                          FURY
# 76                    MARIA HILL
# 77                          FURY
# 78                          FURY
# 79                    MARIA HILL
# 80                          FURY
# 81                          FURY
# 82                          FURY
# 83                          FURY
# 84                 AGENT COULSON
# 85                GEORGI LUCHKOV
# 86                       NATASHA
# 87                GEORGI LUCHKOV
# 88                GEORGI LUCHKOV
# 89                       NATASHA
# 90                GEORGI LUCHKOV
# 91                       NATASHA
# 92                GEORGI LUCHKOV
# 93                 WEASELLY THUG
# 94                GEORGI LUCHKOV
# 95                 AGENT COULSON
# 96                       NATASHA
# 97                 AGENT COULSON
# 98                       NATASHA
# 99                GEORGI LUCHKOV
# 100                      NATASHA
# 101                AGENT COULSON
# 102                      NATASHA
# 103                      NATASHA
# 104                AGENT COULSON
# 105                      NATASHA
# 106                AGENT COULSON
# 107                      NATASHA
# 108                AGENT COULSON
# 109                      NATASHA
# 110               CALCUTTA WOMAN
# 111                   YOUNG GIRL
# 112                       BANNER
# 113                   YOUNG GIRL
# 114                       BANNER
# 115                   YOUNG GIRL
# 116                       BANNER
# 117                      NATASHA
# 118                      NATASHA
# 119                       BANNER
# 120                      NATASHA
# 121                       BANNER
# 122                      NATASHA
# 123                       BANNER
# 124                      NATASHA
# 125                       BANNER
# 126                      NATASHA
# 127                       BANNER
# 128                      NATASHA
# 129                       BANNER
# 130                      NATASHA
# 131                       BANNER
# 132                      NATASHA
# 133                       BANNER
# 134                      NATASHA
# 135                       BANNER
# 136                      NATASHA
# 137                       BANNER
# 138                      NATASHA
# 139                       BANNER
# 140                      NATASHA
# 141                       BANNER
# 142                      NATASHA
# 143                       BANNER
# 144                      NATASHA
# 145                       BANNER
# 146                      NATASHA
# 147                       BANNER
# 148                      NATASHA
# 149                       BANNER
# 150                      NATASHA
# 151                       BANNER
# 152                   COUNCILMAN
# 153                         FURY
# 154                   COUNCILMAN
# 155                         FURY
# 156                 COUNCILWOMAN
# 157                         FURY
# 158                   COUNCILMAN
# 159                         FURY
# 160                   COUNCILMAN
# 161                         FURY
# 162                   COUNCILMAN
# 163                         FURY
# 164                 COUNCILWOMAN
# 165                   COUNCILMAN
# 166                         FURY
# 167              CAPTAIN AMERICA
# 168                 PEGGY CARTER
# 169                    SCIENTIST
# 170                         FURY
# 171                        STEVE
# 172                         FURY
# 173                        STEVE
# 174                         FURY
# 175                        STEVE
# 176                         FURY
# 177                        STEVE
# 178                         FURY
# 179                        STEVE
# 180                         FURY
# 181                        STEVE
# 182                         FURY
# 183                        STEVE
# 184                         FURY
# 185                        STEVE
# 186                     IRON MAN
# 187                       PEPPER
# 188                         TONY
# 189                       PEPPER
# 190                         TONY
# 191                       PEPPER
# 192                         TONY
# 193                         TONY
# 194                       PEPPER
# 195                       PEPPER
# 196                         TONY
# 197                       PEPPER
# 198                       JARVIS
# 199                         TONY
# 200                       JARVIS
# 201                         TONY
# 202                       PEPPER
# 203                         TONY
# 204                       PEPPER
# 205                         TONY
# 206                       PEPPER
# 207                         TONY
# 208                       PEPPER
# 209                         TONY
# 210                       PEPPER
# 211                         TONY
# 212                       PEPPER
# 213                         TONY
# 214                       PEPPER
# 215                         TONY
# 216                       PEPPER
# 217                         TONY
# 218                       PEPPER
# 219                         TONY
# 220                       JARVIS
# 221                         TONY
# 222                AGENT COULSON
# 223                         TONY
# 224                AGENT COULSON
# 225                         TONY
# 226                       PEPPER
# 227                         TONY
# 228                AGENT COULSON
# 229                         TONY
# 230                       PEPPER
# 231                         TONY
# 232                AGENT COULSON
# 233                         TONY
# 234                       PEPPER
# 235                         TONY
# 236                AGENT COULSON
# 237                       PEPPER
# 238                         TONY
# 239                       PEPPER
# 240                         TONY
# 241                       PEPPER
# 242                AGENT COULSON
# 243                         TONY
# 244                       PEPPER
# 245                         TONY
# 246                       PEPPER
# 247                         TONY
# 248                       PEPPER
# 249                         TONY
# 250                       PEPPER
# 251                         TONY
# 252                       PEPPER
# 253                         TONY
# 254                       PEPPER
# 255                         TONY
# 256                       PEPPER
# 257                AGENT COULSON
# 258                       PEPPER
# 259                AGENT COULSON
# 260                       PEPPER
# 261               FACELESS PILOT
# 262                        STEVE
# 263                AGENT COULSON
# 264                        STEVE
# 265                AGENT COULSON
# 266                AGENT COULSON
# 267                        STEVE
# 268                AGENT COULSON
# 269                        STEVE
# 270                AGENT COULSON
# 271                    THE OTHER
# 272                         LOKI
# 273                    THE OTHER
# 274                         LOKI
# 275                    THE OTHER
# 276                         LOKI
# 277                    THE OTHER
# 278                         LOKI
# 279                    THE OTHER
# 280                AGENT COULSON
# 281                        STEVE
# 282                      NATASHA
# 283                AGENT COULSON
# 284                      NATASHA
# 285                        STEVE
# 286                      NATASHA
# 287                        STEVE
# 288                       BANNER
# 289                        STEVE
# 290                       BANNER
# 291                        STEVE
# 292                       BANNER
# 293                        STEVE
# 294                      NATASHA
# 295         HELICARRIER INTERCOM
# 296                        STEVE
# 297                       BANNER
# 298               CARRIER BRIDGE
# 299                       TECH 1
# 300               FEMALE CARRIER
# 301                  BRIDGE TECH
# 302                   MARIA HILL
# 303                         FURY
# 304                   MARIA HILL
# 305                   MALE AGENT
# 306                         FURY
# 307                       BANNER
# 308                         FURY
# 309                       BANNER
# 310                AGENT COULSON
# 311                      NATASHA
# 312                       BANNER
# 313                         FURY
# 314                       BANNER
# 315                         FURY
# 316                      NATASHA
# 317                       BANNER
# 318                      NATASHA
# 319                       BANNER
# 320                         FURY
# 321                   MARIA HILL
# 322                   MARIA HILL
# 323                         FURY
# 324                       SELVIG
# 325                       BARTON
# 326                       SELVIG
# 327                       BARTON
# 328                       SELVIG
# 329                         LOKI
# 330                       BARTON
# 331                       SELVIG
# 332                       BARTON
# 333                         LOKI
# 334                       BARTON
# 335                         LOKI
# 336                       BARTON
# 337                         LOKI
# 338                       BARTON
# 339                         LOKI
# 340                       BARTON
# 341                         LOKI
# 342                       BARTON
# 343                         LOKI
# 344                       BARTON
# 345                         LOKI
# 346                       BARTON
# 347                AGENT COULSON
# 348                        STEVE
# 349                AGENT COULSON
# 350         AGENT JASPER SITWELL
# 351                AGENT COULSON
# 352         AGENT JASPER SITWELL
# 353                         FURY
# 354                         LOKI
# 355               GERMAN OLD MAN
# 356                         LOKI
# 357               GERMAN OLD MAN
# 358                         LOKI
# 359              CAPTAIN AMERICA
# 360                         LOKI
# 361              CAPTAIN AMERICA
# 362                      NATASHA
# 363                         LOKI
# 364              CAPTAIN AMERICA
# 365                      NATASHA
# 366                         TONY
# 367                     IRON MAN
# 368              CAPTAIN AMERICA
# 369                     IRON MAN
# 370                         FURY
# 371                      NATASHA
# 372                         FURY
# 373                        STEVE
# 374                         TONY
# 375                        STEVE
# 376                         TONY
# 377                        STEVE
# 378                         TONY
# 379                        STEVE
# 380                         TONY
# 381                      NATASHA
# 382                        STEVE
# 383                         LOKI
# 384              CAPTAIN AMERICA
# 385                     IRON MAN
# 386                      NATASHA
# 387              CAPTAIN AMERICA
# 388                      NATASHA
# 389              CAPTAIN AMERICA
# 390                     IRON MAN
# 391                      NATASHA
# 392              CAPTAIN AMERICA
# 393                      NATASHA
# 394              CAPTAIN AMERICA
# 395                         THOR
# 396                         LOKI
# 397                         THOR
# 398                         LOKI
# 399                         THOR
# 400                         LOKI
# 401                         THOR
# 402                         LOKI
# 403                         THOR
# 404                         LOKI
# 405                         THOR
# 406                         LOKI
# 407                         THOR
# 408                         LOKI
# 409                         THOR
# 410                         LOKI
# 411                         THOR
# 412                         LOKI
# 413                         THOR
# 414                         LOKI
# 415                         THOR
# 416                         TONY
# 417                         THOR
# 418                         TONY
# 419                         THOR
# 420                         TONY
# 421                     IRON MAN
# 422                         TONY
# 423                       JARVIS
# 424                         TONY
# 425              CAPTAIN AMERICA
# 426              CAPTAIN AMERICA
# 427                         THOR
# 428              CAPTAIN AMERICA
# 429                     IRON MAN
# 430                         THOR
# 431              CAPTAIN AMERICA
# 432                         FURY
# 433                         LOKI
# 434                         FURY
# 435                         LOKI
# 436                         FURY
# 437                         LOKI
# 438                         FURY
# 439                       BANNER
# 440                        STEVE
# 441                         THOR
# 442                        STEVE
# 443                       BANNER
# 444                         THOR
# 445                       BANNER
# 446                         THOR
# 447                      NATASHA
# 448                        STEVE
# 449                       BANNER
# 450                         THOR
# 451                      NATASHA
# 452                         THOR
# 453                       BANNER
# 454                         TONY
# 455                         TONY
# 456                   MARIA HILL
# 457                         TONY
# 458                   MARIA HILL
# 459                         TONY
# 460                        STEVE
# 461                       BANNER
# 462                         TONY
# 463                       BANNER
# 464                         TONY
# 465                        STEVE
# 466                         TONY
# 467                       BANNER
# 468                         FURY
# 469                        STEVE
# 470                         FURY
# 471                         THOR
# 472                        STEVE
# 473                        STEVE
# 474                         TONY
# 475                       BANNER
# 476                       BANNER
# 477                         TONY
# 478                       BANNER
# 479                         TONY
# 480                       BANNER
# 481                         TONY
# 482                       BANNER
# 483                        STEVE
# 484                         TONY
# 485                        STEVE
# 486                         TONY
# 487                        STEVE
# 488                         TONY
# 489                        STEVE
# 490                       BANNER
# 491                         TONY
# 492                        STEVE
# 493                         TONY
# 494                        STEVE
# 495                         TONY
# 496                       BANNER
# 497                        STEVE
# 498                       BANNER
# 499                        STEVE
# 500                       BANNER
# 501                        STEVE
# 502                       BANNER
# 503                         TONY
# 504                       BANNER
# 505                         TONY
# 506                        STEVE
# 507                         TONY
# 508                        STEVE
# 509                         TONY
# 510                        STEVE
# 511                         TONY
# 512                        STEVE
# 513                         TONY
# 514                       BANNER
# 515                        STEVE
# 516                         TONY
# 517                       BANNER
# 518                         TONY
# 519                       BANNER
# 520                         TONY
# 521                       BANNER
# 522                         TONY
# 523                       BANNER
# 524                         TONY
# 525                       BANNER
# 526                         TONY
# 527                       BANNER
# 528                         TONY
# 529                       BANNER
# 530                         TONY
# 531                AGENT COULSON
# 532                AGENT COULSON
# 533                         THOR
# 534                AGENT COULSON
# 535                         THOR
# 536                AGENT COULSON
# 537                         THOR
# 538                AGENT COULSON
# 539                         THOR
# 540                         FURY
# 541                         THOR
# 542                         FURY
# 543                         THOR
# 544                         FURY
# 545                         THOR
# 546                         FURY
# 547                         LOKI
# 548                      NATASHA
# 549                         LOKI
# 550                      NATASHA
# 551                         LOKI
# 552                      NATASHA
# 553                         LOKI
# 554                      NATASHA
# 555                         LOKI
# 556                      NATASHA
# 557                         LOKI
# 558                      NATASHA
# 559                         LOKI
# 560                      NATASHA
# 561                         LOKI
# 562                      NATASHA
# 563                         LOKI
# 564                         LOKI
# 565                         LOKI
# 566                         LOKI
# 567                         LOKI
# 568                      NATASHA
# 569                         LOKI
# 570                      NATASHA
# 571                         LOKI
# 572                      NATASHA
# 573                         FURY
# 574                         TONY
# 575                         FURY
# 576                       BANNER
# 577                         TONY
# 578                        STEVE
# 579                         FURY
# 580                         TONY
# 581                        STEVE
# 582                       BANNER
# 583                      NATASHA
# 584                       BANNER
# 585                      NATASHA
# 586                       BANNER
# 587                      NATASHA
# 588                       BANNER
# 589                       BANNER
# 590                         FURY
# 591                         THOR
# 592                         FURY
# 593                         THOR
# 594                         FURY
# 595                        STEVE
# 596                         THOR
# 597                        STEVE
# 598                         FURY
# 599                         TONY
# 600                         FURY
# 601                        STEVE
# 602                         TONY
# 603                        STEVE
# 604                         THOR
# 605                         FURY
# 606                         THOR
# 607                         FURY
# 608                      NATASHA
# 609                         TONY
# 610                       BANNER
# 611                      NATASHA
# 612                         FURY
# 613                         TONY
# 614                        STEVE
# 615                         TONY
# 616                        STEVE
# 617                         TONY
# 618                       BANNER
# 619               INTERCOM VOICE
# 620                        PILOT
# 621                         THOR
# 622                       BANNER
# 623                         FURY
# 624                         TONY
# 625                        STEVE
# 626                         TONY
# 627                        STEVE
# 628                         TONY
# 629                        STEVE
# 630                         TONY
# 631                        STEVE
# 632                         TONY
# 633                        STEVE
# 634                         THOR
# 635                       BANNER
# 636                         FURY
# 637                       BANNER
# 638                         FURY
# 639                       BANNER
# 640                        STEVE
# 641                         FURY
# 642                       BANNER
# 643                         THOR
# 644                         TONY
# 645                        STEVE
# 646                        NOVAR
# 647                        STEVE
# 648                         TONY
# 649                        STEVE
# 650                         TONY
# 651                        STEVE
# 652                       BANNER
# 653                        STEVE
# 654                         TONY
# 655               INTERCOM VOICE
# 656                         FURY
# 657                   MARIA HILL
# 658   FEMALE CARRIER BRIDGE TECH
# 659                   MARIA HILL
# 660            OFF SCREEN WORKER
# 661        CARRIER BRIDGE TECH 1
# 662                   MARIA HILL
# 663                         FURY
# 664                         TONY
# 665                         FURY
# 666                         FURY
# 667                      NATASHA
# 668                      NATASHA
# 669                       BARTON
# 670                         TONY
# 671                      NATASHA
# 672              MAINTENANCE GUY
# 673                      NATASHA
# 674                       BANNER
# 675                      NATASHA
# 676                         FURY
# 677                 SHIELD AGENT
# 678                         FURY
# 679                 SHIELD AGENT
# 680                         FURY
# 681                        STEVE
# 682                     IRON MAN
# 683                         TONY
# 684                     IRON MAN
# 685                         TONY
# 686                        STEVE
# 687                         TONY
# 688                         THOR
# 689                        STEVE
# 690                        STEVE
# 691                     IRON MAN
# 692                         TONY
# 693                        STEVE
# 694                         TONY
# 695                        STEVE
# 696                         TONY
# 697                         TONY
# 698                         FURY
# 699                   MARIA HILL
# 700               INTERCOM VOICE
# 701               INTERCOM VOICE
# 702                   MARIA HILL
# 703                         FURY
# 704                   MARIA HILL
# 705                   MARIA HILL
# 706           YOUNG SHIELD PILOT
# 707           YOUNG SHIELD PILOT
# 708                         FURY
# 709               INTERCOM VOICE
# 710                SHIELD WORKER
# 711                         FURY
# 712                      NATASHA
# 713                         FURY
# 714                         TONY
# 715                         LOKI
# 716                         LOKI
# 717                AGENT COULSON
# 718                         THOR
# 719                       BARTON
# 720                AGENT COULSON
# 721                         LOKI
# 722                AGENT COULSON
# 723                         LOKI
# 724                AGENT COULSON
# 725                         LOKI
# 726                AGENT COULSON
# 727               INTERCOM VOICE
# 728                         TONY
# 729                        STEVE
# 730                         TONY
# 731                         TONY
# 732                AGENT COULSON
# 733                         FURY
# 734                AGENT COULSON
# 735                         FURY
# 736                AGENT COULSON
# 737                         FURY
# 738                SHIELD WORKER
# 739                         FURY
# 740                         FURY
# 741                         FURY
# 742               SECURITY GUARD
# 743                       BANNER
# 744               SECURITY GUARD
# 745                       BANNER
# 746               SECURITY GUARD
# 747                       BANNER
# 748               SECURITY GUARD
# 749                       BANNER
# 750               SECURITY GUARD
# 751                       BANNER
# 752               SECURITY GUARD
# 753                       BANNER
# 754               SECURITY GUARD
# 755               SECURITY GUARD
# 756                       BANNER
# 757               SECURITY GUARD
# 758                       BANNER
# 759               SECURITY GUARD
# 760                       BANNER
# 761               SECURITY GUARD
# 762                       BANNER
# 763               SECURITY GUARD
# 764                       BANNER
# 765               SECURITY GUARD
# 766                      NATASHA
# 767                       BARTON
# 768                      NATASHA
# 769                       BARTON
# 770                      NATASHA
# 771                       BARTON
# 772                      NATASHA
# 773                       BARTON
# 774                      NATASHA
# 775                       BARTON
# 776                      NATASHA
# 777                       BARTON
# 778                      NATASHA
# 779                       BARTON
# 780                      NATASHA
# 781                       BARTON
# 782                      NATASHA
# 783                       BARTON
# 784                      NATASHA
# 785                       BARTON
# 786                      NATASHA
# 787                        STEVE
# 788                         TONY
# 789                        STEVE
# 790                         TONY
# 791                        STEVE
# 792                         TONY
# 793                        STEVE
# 794                         TONY
# 795                        STEVE
# 796                         TONY
# 797                        STEVE
# 798                         TONY
# 799                        STEVE
# 800                         TONY
# 801                        STEVE
# 802                         TONY
# 803                        STEVE
# 804                         TONY
# 805                        STEVE
# 806                         TONY
# 807              CAPTAIN AMERICA
# 808                      NATASHA
# 809              CAPTAIN AMERICA
# 810                       BARTON
# 811              CAPTAIN AMERICA
# 812                       BARTON
# 813              CAPTAIN AMERICA
# 814              SHIELD ENGINEER
# 815              CAPTAIN AMERICA
# 816                   MARIA HILL
# 817                         FURY
# 818                   MARIA HILL
# 819                         FURY
# 820               INTERCOM VOICE
# 821                         FURY
# 822                   MARIA HILL
# 823                       JARVIS
# 824                     IRON MAN
# 825                       JARVIS
# 826                     IRON MAN
# 827                       JARVIS
# 828                     IRON MAN
# 829                       JARVIS
# 830                         TONY
# 831                         LOKI
# 832                         TONY
# 833                         LOKI
# 834                         TONY
# 835                         LOKI
# 836                         TONY
# 837                         LOKI
# 838                         TONY
# 839                         LOKI
# 840                         TONY
# 841                         LOKI
# 842                         TONY
# 843                         LOKI
# 844                         TONY
# 845                         LOKI
# 846                         TONY
# 847                         LOKI
# 848                         TONY
# 849                         LOKI
# 850                         TONY
# 851                         TONY
# 852                     IRON MAN
# 853                         TONY
# 854                         THOR
# 855                         LOKI
# 856                         THOR
# 857                      NATASHA
# 858                      NATASHA
# 859                         TONY
# 860                       JARVIS
# 861                         TONY
# 862                       BARTON
# 863                      NATASHA
# 864              CAPTAIN AMERICA
# 865              CAPTAIN AMERICA
# 866                         TONY
# 867                         TONY
# 868              CAPTAIN AMERICA
# 869                         TONY
# 870                         THOR
# 871                         LOKI
# 872                         THOR
# 873                         LOKI
# 874                       BARTON
# 875              CAPTAIN AMERICA
# 876                      NATASHA
# 877              CAPTAIN AMERICA
# 878                       BARTON
# 879                      NATASHA
# 880                       BARTON
# 881                    YOUNG COP
# 882              POLICE SERGEANT
# 883              POLICE SERGEANT
# 884                    YOUNG COP
# 885              CAPTAIN AMERICA
# 886              POLICE SERGEANT
# 887              POLICE SERGEANT
# 888                         TONY
# 889                     IRON MAN
# 890              CAPTAIN AMERICA
# 891                         THOR
# 892                         TONY
# 893                      NATASHA
# 894              CAPTAIN AMERICA
# 895                         THOR
# 896                       BARTON
# 897              CAPTAIN AMERICA
# 898                       BANNER
# 899                      NATASHA
# 900                       BANNER
# 901                      NATASHA
# 902              CAPTAIN AMERICA
# 903                         TONY
# 904              CAPTAIN AMERICA
# 905                         TONY
# 906                      NATASHA
# 907              CAPTAIN AMERICA
# 908                       BANNER
# 909                     IRON MAN
# 910                         LOKI
# 911                      NATASHA
# 912                     IRON MAN
# 913              CAPTAIN AMERICA
# 914                       BARTON
# 915                     IRON MAN
# 916              CAPTAIN AMERICA
# 917              CAPTAIN AMERICA
# 918                   MARIA HILL
# 919                       BARTON
# 920                         TONY
# 921                       BARTON
# 922                         TONY
# 923                         TONY
# 924                         TONY
# 925                       BARTON
# 926                         TONY
# 927                      NATASHA
# 928              CAPTAIN AMERICA
# 929                      NATASHA
# 930              CAPTAIN AMERICA
# 931                      NATASHA
# 932              CAPTAIN AMERICA
# 933                      NATASHA
# 934                      NATASHA
# 935                       BARTON
# 936              CAPTAIN AMERICA
# 937              CAPTAIN AMERICA
# 938                 COUNCILWOMAN
# 939                         FURY
# 940                   COUNCILMAN
# 941                         FURY
# 942                         FURY
# 943                   COUNCILMAN
# 944                         FURY
# 945                      NATASHA
# 946                       BARTON
# 947                      NATASHA
# 948                       BARTON
# 949                         LOKI
# 950                         HULK
# 951                       SELVIG
# 952                      NATASHA
# 953                       SELVIG
# 954                      NATASHA
# 955                       SELVIG
# 956                      NATASHA
# 957                       SELVIG
# 958                       JARVIS
# 959                         TONY
# 960                       JARVIS
# 961                 COUNCILWOMAN
# 962                    JET PILOT
# 963                   MARIA HILL
# 964                         FURY
# 965                     IRON MAN
# 966                         FURY
# 967                         TONY
# 968                       JARVIS
# 969                    JET PILOT
# 970                         THOR
# 971                        STEVE
# 972                       SELVIG
# 973                      NATASHA
# 974                        STEVE
# 975                         TONY
# 976                        STEVE
# 977                         TONY
# 978                         TONY
# 979                        STEVE
# 980                         TONY
# 981                       JARVIS
# 982                         TONY
# 983                     REPORTER
# 984                     REPORTER
# 985                       JARVIS
# 986                      NATASHA
# 987                        STEVE
# 988                        STEVE
# 989                         THOR
# 990                         TONY
# 991                        STEVE
# 992                         TONY
# 993                         THOR
# 994                         TONY
# 995                         LOKI
# 996                MALE REPORTER
# 997                MALE REPORTER
# 998                 MALE CITIZEN
# 999               FEMALE CITIZEN
# 1000                     HUSBAND
# 1001                        WIFE
# 1002                    STAN LEE
# 1003                 THE SENATOR
# 1004                    REPORTER
# 1005                    WAITRESS
# 1006                    WAITRESS
# 1007                COUNCILMAN 2
# 1008                        FURY
# 1009                COUNCILWOMAN
# 1010                        FURY
# 1011                  COUNCILMAN
# 1012                        FURY
# 1013                  COUNCILMAN
# 1014                  COUNCILMAN
# 1015                        FURY
# 1016                COUNCILWOMAN
# 1017                COUNCILWOMAN
# 1018                        FURY
# 1019                        FURY
# 1020                  COUNCILMAN
# 1021                        FURY
# 1022                  MARIA HILL
# 1023                  MARIA HILL
# 1024                        FURY
# 1025                  MARIA HILL
# 1026                        FURY
# 1027                  MARIA HILL
# 1028                        FURY
# 1029                   THE OTHER
# 1030                   THE OTHER
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       line
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               The Tesseract has awakened. It is on a little world, a human world. They would wield its power. THE OTHER hands LOKI a scepter with a glowing blue gem...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            But our ally knows its workings as they never will. He is ready to lead. And our force... The CHITAURI put on their face mask and get ready.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...our Chitauri, will follow. The world will be his...the universe, yours. And the humans, what can they do but burn? A 3d model of the Tesseract, we move inside it slowly A helicopter SPEEDS over this mountain at high-speed. The CAMERA pans up over the mountain and we see... This base is grand beyond belief. There is a frantic evacuation in progress. AGENTS, SCIENTISTS, and PERSONNEL rush around the base frantically.
# ...
# 1024                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           They’ll come back! The reach the air deck.
# 1025                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Really sure about that?
# 1026                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           I am. Fury looks out over the helicarrier.
# 1027                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Why?
# 1028                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Because we’ll need them to. Hill nods, in respect. She turns and walks back over the bridge and takes a folder from a SHIELD agent. Fury stands proud on the air deck. Pepper and Stark are looking at plans for a new tower. THE CAMERA slowly PULLS OUT... The huge STARK on the side of the tower has been destroyed, save for the letter "A". The Other kneels at the feet of another alien.
# 1029                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                The humans, they are not the cowering wretches we were promised. They stand. They are unruly and therefore cannot be ruled. DISEMBODIED FIGURE in a chair stands. The Other bows, like he is in pain.
# 1030                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        To challenge them, is to court Death. DISEMBODIED FIGURE turns and smiles, revealing himself to be the mad titan himself- The Avengers are sitting around a table, eating, stuffing their faces. They are silent, no one makes a peep. The workers are cleaning up this destroyed place. The place is silent.
