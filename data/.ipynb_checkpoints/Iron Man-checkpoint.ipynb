# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Script to CSV Process
#
# 1. Load script `.txt` file.  Use [PDF Extractor](https://pdfextractor.com/) to convert any `.pdf`s to `.txt`s.
# 2. Remove garbage rows
# 3. Inspect rows removed
# 4. Format lines
# 5. Create `uppercase_unique_form.csv`
# 6. Manually fill out `uppercase_unique_form.csv` columns `is_character_name` and `is_dialogue` in Excel or other `.csv` editor.
# 7. Load `uppercase_unique.csv` and filter out rows
# 8. Inspect rows removed
# 9. Merge lines into best guesses for columns "character" and "line"
# 10. Manually clean the "line" column by removing text that is not dialogue.  There will be a lot, so nearly every cell will have to be cleaned!
#
#
# See the Iron Man script at the end of this notebook for an example of this process.

# %% [markdown]
# ## Remove Garbage Rows

# %%
def remove_regex_rows(df,string):
    rows_to_remove = df["line"].str.contains(string,case=True,regex=True)
    print("Removed",rows_to_remove.sum(),"rows that match regex \"" + string + "\"")
    
    return df[~rows_to_remove], df[rows_to_remove]

def remove_whitespace_rows(df):
    whitespace_rows = df["line"].str.isspace()
    print(whitespace_rows.sum(),"whitespace rows removed")
    return df[~whitespace_rows], df[whitespace_rows]

def remove_movie_text_rows(df):
    
    regex_strings = ["INTERCUT",
                    "CUT TO",
                    "^THE END",
                    "^INT\.",
                    "^EXT\.",
                    "CONTINUED",
                    "^[0-9]+\.$",
                    "\(.*radio\)",
                    "\(.*earpiece\)",
                    "\(.*headset\)",
                    "\(.*phone\)",
                    "\(.*cell\)",
                    "\(to .*\)",
                    "\(in .*\)",
                    "\(MORE\)",
                    "\(angry\)",
                    "TIME CUT:",
                    "TITLE:",
                    "SLAM TO",
                    "DISSOLVE TO",
                    "FADE",
                    "BEST ADAPTED SCREENPLAY",
                    "MARVEL",
                    "FADE TO BLACK",
                    "CUE MUSIC",
                    "BLUE DRAFT 05/20/16",
                    "SALMON #2",
                    "../../..",
                    "OMITTED",
                    "MAIN TITLE",
                    "[A-J][0-9]+",
                    "[0-9]+[A-J]",
                    "\*",
                    "\(.*:\)",
                    "^\(beat\)$"]
    
    removed_rows = pd.DataFrame()
    
    for regex_string in regex_strings:
        df, new_rows_to_remove = remove_regex_rows(df,regex_string)
        
        removed_rows = pd.concat([removed_rows, new_rows_to_remove])
    
    return df, removed_rows


def remove_page_number_rows(df):
    page_rows = df["line"].str.isnumeric()
    print(page_rows.sum(),"page number rows removed")
    
    return df[~page_rows], df[page_rows]

def remove_garbage_rows(df):
    df, whitespace_rows = remove_whitespace_rows(df)
    df, page_number_rows = remove_page_number_rows(df)
    df, movie_text_rows = remove_movie_text_rows(df)
    
    garbage_rows = pd.concat([whitespace_rows, page_number_rows, movie_text_rows], 
                            keys = ["whitespace","page_numbers","movie_text"])
    
    print("-----------------------------------------")
    print(garbage_rows.shape[0],"total rows removed\n")
    
    return df, garbage_rows

# %% [markdown]
# ## Format Character Lines

# %%
def remove_regex(df,string):
    print("Removed",df["line"].str.count(string).sum(),"occurences of regex \"" + string + "\"")
    df["line"] = df["line"].str.replace(string,"",case=True,regex=True)

def remove_leading_trailing_whitespace(df):
    df["line"] = df["line"].str.replace("[ \t]+$","")
    df["line"] = df["line"].str.replace("^[ \t]+","")

def format_lines(df):
    remove_leading_trailing_whitespace(df)
    
    regex_strings = ["\(O\.S\)",
                    "\(V\.O\)",
                     "\(V\.O\.\)",
                    "\(CONT.D\)",
                    "\(cont.d\)",
                    "\(O\.S\.\)",
                    "\(ON.*\)",
                    "\(OVER.*\)",
                    "\(INTO.*\)",
                    "\(HOLO\)",
                    "\(ADR\)",
                    "\(then\)",
                    " \(RHODEY’S VOICE\)"]
    
    for regex_string in regex_strings:
        remove_regex(df, regex_string)
    
    print("")
    
    remove_leading_trailing_whitespace(df)

# %% [markdown]
# ## Remove Non Dialogue Uppercase Rows

# %%
def uppercase_rows(df):
    upper_lines = df["line"].str.isupper()
    
    return df[upper_lines]

def create_uppercase_unique_csv(df,script_name):
    '''
    Creates a csv file that is used for inspection of unique
    lines that are all uppercase.  These lines are manually labeled
    to be character names or dialogue.  The resulting table will be
    used to delete rows that are neither character names nor dialogue.
    '''
    
    upper_rows = uppercase_rows(df)
    unique_upper_rows = pd.DataFrame(upper_rows.line.unique())

    unique_upper_rows["words"] = unique_upper_rows[0].str.split(" ").str.len()
    unique_upper_rows["is_character_name"] = 0
    unique_upper_rows["is_dialogue"] = 0
    sorted_unique_upper_rows = unique_upper_rows.sort_values(by=["words"])
    sorted_unique_upper_rows.to_csv("./uppercase forms/" + script_name + "_uppercase_unique_form.csv",encoding='utf-8')
    
    print("Created " + "./uppercase forms/" + script_name + "_uppercase_unique_form.csv\n")
    
def remove_non_dialogue_upper_rows(df,upper_rows):
    '''
    Removes lines that are in all caps, and that are not dialogue or a character's name.
    '''
    unique_character_names = upper_rows[upper_rows["is_character_name"]]["line"]
    unique_dialogues = upper_rows[upper_rows["is_dialogue"]]["line"]
    
    all_character_name_lines = df[df["line"].isin(unique_character_names)]
    all_dialogue_lines = df[df["line"].isin(unique_dialogues)]
    
    print(df["line"].str.isupper().sum(),"total uppercase lines")
    print(all_character_name_lines.shape[0],"uppercase character name lines")
    print(all_dialogue_lines.shape[0],"uppercase dialogue lines")
    
    unique_lines_to_remove = upper_rows[~(upper_rows["is_character_name"]|upper_rows["is_dialogue"])]["line"]
    removed_lines = df["line"].isin(unique_lines_to_remove)
    print(removed_lines.sum(),"uppercase lines removed")
    
    return df[~removed_lines], df[removed_lines]

# %% [markdown]
# ## Merge Lines

# %%
def is_character_name(string,character_names):
    return string in character_names["line"].tolist()
    

def merge_lines(df,character_names):
    '''
    Starts at a character name and merges all lines until the next character's name.
    The result should be the best guess at columns "character" and "line".
    This will merge in some screenplay text that is not dialogue, so the result will 
    have to be manually cleaned as the final step.
    '''
    merged_df = pd.DataFrame(columns=["character","line"])
    
    for i in range(0,df.shape[0]):
        
        row = df.iloc[i]
        
        if is_character_name(row["line"],character_names):
            character = row["line"]
            line = ""
            
            j = i + 1
            while(j < len(df) and (not is_character_name(df.iloc[j]["line"],character_names))):
                line += df.iloc[j]["line"] + " "
                j += 1
            
            new_row = {"character": character,"line": line}
            
            merged_df = merged_df.append(new_row,ignore_index=True)
    
    return merged_df

# %% [markdown]
# ## Iron Man

# %%
iron_man = pd.read_csv("./script txts/iron-man-script-slug.txt",sep="\n",header=None,names=["line"])

iron_man, garbage_rows = remove_garbage_rows(iron_man)
format_lines(iron_man)

create_uppercase_unique_csv(iron_man,"iron_man")
filled_out_upper_rows = pd.read_csv("./uppercase results/iron_man_uppercase_unique.csv",
                                    names=["","line","words","is_character_name","is_dialogue"],
                                    dtype={"line":str, "words":int, "is_character_name":bool, "is_dialogue":bool},
                                    index_col=0)

iron_man, upper_removed_rows = remove_non_dialogue_upper_rows(iron_man, filled_out_upper_rows)
removed_rows = pd.concat([garbage_rows,pd.concat([upper_removed_rows],keys=[""])],keys=["garbage","uppercase"])

unique_character_names = pd.DataFrame(filled_out_upper_rows[filled_out_upper_rows["is_character_name"]]["line"])

iron_man = merge_lines(iron_man, unique_character_names)
iron_man.reindex(copy=False)

iron_man.to_csv("./uncleaned/iron_man_uncleaned.csv", index=False)

iron_man = pd.read_csv("./cleaned/iron_man.csv")

iron_man
# Out:
# 180 whitespace rows removed
# 516 page number rows removed
# Removed 13 rows that match regex "INTERCUT"
# Removed 80 rows that match regex "CUT TO"
# Removed 0 rows that match regex "^THE END"
# Removed 99 rows that match regex "^INT\."
# Removed 42 rows that match regex "^EXT\."
# Removed 216 rows that match regex "CONTINUED"
# Removed 86 rows that match regex "^[0-9]+\.$"
# Removed 0 rows that match regex "\(.*radio\)"
# Removed 0 rows that match regex "\(.*earpiece\)"
# Removed 0 rows that match regex "\(.*headset\)"
# Removed 0 rows that match regex "\(.*phone\)"
# Removed 0 rows that match regex "\(.*cell\)"
# Removed 8 rows that match regex "\(to .*\)"
# Removed 19 rows that match regex "\(in .*\)"
# Removed 10 rows that match regex "\(MORE\)"
# Removed 0 rows that match regex "\(angry\)"
# Removed 0 rows that match regex "TIME CUT:"
# Removed 0 rows that match regex "TITLE:"
# Removed 0 rows that match regex "SLAM TO"
# Removed 1 rows that match regex "DISSOLVE TO"
# Removed 2 rows that match regex "FADE"
# Removed 0 rows that match regex "BEST ADAPTED SCREENPLAY"
# Removed 361 rows that match regex "MARVEL"
# Removed 0 rows that match regex "FADE TO BLACK"
# Removed 1 rows that match regex "CUE MUSIC"
# Removed 0 rows that match regex "BLUE DRAFT 05/20/16"
# Removed 180 rows that match regex "SALMON #2"
# Removed 197 rows that match regex "../../.."
# Removed 89 rows that match regex "OMITTED"
# Removed 0 rows that match regex "MAIN TITLE"
# Removed 218 rows that match regex "[A-J][0-9]+"
# Removed 85 rows that match regex "[0-9]+[A-J]"
# Removed 130 rows that match regex "\*"
# Removed 0 rows that match regex "\(.*:\)"
# Removed 1 rows that match regex "^\(beat\)$"
# -----------------------------------------
# 2534 total rows removed
#
# Removed 0 occurences of regex "\(O\.S\)"
# Removed 0 occurences of regex "\(V\.O\)"
# Removed 0 occurences of regex "\(V\.O\.\)"
# Removed 7 occurences of regex "\(CONT.D\)"
# Removed 10 occurences of regex "\(cont.d\)"
# Removed 81 occurences of regex "\(O\.S\.\)"
# Removed 4 occurences of regex "\(ON.*\)"
# Removed 0 occurences of regex "\(OVER.*\)"
# Removed 0 occurences of regex "\(INTO.*\)"
# Removed 0 occurences of regex "\(HOLO\)"
# Removed 0 occurences of regex "\(ADR\)"
# Removed 20 occurences of regex "\(then\)"
# Removed 2 occurences of regex " \(RHODEY’S VOICE\)"
#
# Created ./uppercase forms/iron_man_uppercase_unique_form.csv
#
# 951 total uppercase lines
# 846 uppercase character name lines
# 21 uppercase dialogue lines
# 84 uppercase lines removed
#                character  \
# 0                   TONY
# 1                  JIMMY
# 2                   TONY
# 3                RAMIREZ
# 4                   TONY
# 5                   TONY
# 6                  JIMMY
# 7                   TONY
# 8                  JIMMY
# 9                   TONY
# 10                 PRATT
# 11                  TONY
# 12                 PRATT
# 13                  TONY
# 14                 PRATT
# 15                RHODEY
# 16              NARRATOR
# 17              NARRATOR
# 18              NARRATOR
# 19              NARRATOR
# 20              NARRATOR
# 21              NARRATOR
# 22              NARRATOR
# 23              NARRATOR
# 24              NARRATOR
# 25              NARRATOR
# 26              NARRATOR
# 27              NARRATOR
# 28              NARRATOR
# 29                RHODEY
# 30               OBADIAH
# 31                  TONY
# 32                 WOMAN
# 33                  TONY
# 34                  TONY
# 35                  TONY
# 36                RHODEY
# 37                  TONY
# 38                  TONY
# 39                  TONY
# 40                  TONY
# 41                  TONY
# 42                RHODEY
# 43                  TONY
# 44                RHODEY
# 45                  TONY
# 46                  TONY
# 47                RHODEY
# 48                  TONY
# 49                RHODEY
# 50                  TONY
# 51                RHODEY
# 52                  TONY
# 53                  TONY
# 54                RHODEY
# 55                  TONY
# 56                PEPPER
# 57                  TONY
# 58                PEPPER
# 59                  TONY
# 60                PEPPER
# 61         WOMAN’S VOICE
# 62             CHRISTINE
# 63                  TONY
# 64             CHRISTINE
# 65                  TONY
# 66             CHRISTINE
# 67                  TONY
# 68                  TONY
# 69             CHRISTINE
# 70                  TONY
# 71             CHRISTINE
# 72                  TONY
# 73             CHRISTINE
# 74                  TONY
# 75             CHRISTINE
# 76                  TONY
# 77             CHRISTINE
# 78                  TONY
# 79             CHRISTINE
# 80                JARVIS
# 81                PEPPER
# 82                PEPPER
# 83             CHRISTINE
# 84                PEPPER
# 85             CHRISTINE
# 86                PEPPER
# 87                PEPPER
# 88                  TONY
# 89                PEPPER
# 90                  TONY
# 91                PEPPER
# 92                  TONY
# 93                PEPPER
# 94                  TONY
# 95                  TONY
# 96                  TONY
# 97                PEPPER
# 98                  TONY
# 99                PEPPER
# 100                 TONY
# 101               PEPPER
# 102                 TONY
# 103               PEPPER
# 104                 TONY
# 105               PEPPER
# 106                 TONY
# 107                 TONY
# 108               RHODEY
# 109                 TONY
# 110                 TONY
# 111            ATTENDANT
# 112                 TONY
# 113               RHODEY
# 114                 TONY
# 115               RHODEY
# 116                 TONY
# 117               RHODEY
# 118                 TONY
# 119               RHODEY
# 120                 TONY
# 121               RHODEY
# 122                 TONY
# 123               RHODEY
# 124                 TONY
# 125               RHODEY
# 126                 TONY
# 127               RHODEY
# 128                 TONY
# 129               RHODEY
# 130               RHODEY
# 131                 TONY
# 132                 TONY
# 133                 TONY
# 134                 TONY
# 135                 TONY
# 136                 TONY
# 137                 TONY
# 138                 TONY
# 139              OBADIAH
# 140                 TONY
# 141              OBADIAH
# 142                 TONY
# 143              OBADIAH
# 144                 TONY
# 145                JIMMY
# 146                 TONY
# 147                 TONY
# 148               YINSEN
# 149                 TONY
# 150               YINSEN
# 151               YINSEN
# 152               YINSEN
# 153                 TONY
# 154               YINSEN
# 155                 TONY
# 156               YINSEN
# 157               YINSEN
# 158                  ABU
# 159               YINSEN
# 160                  ABU
# 161               YINSEN
# 162                 TONY
# 163               YINSEN
# 164               YINSEN
# 165               YINSEN
# 166               YINSEN
# 167               YINSEN
# 168                 TONY
# 169                  ABU
# 170               YINSEN
# 171                 TONY
# 172               YINSEN
# 173               RHODEY
# 174              GABRIEL
# 175               RHODEY
# 176              GABRIEL
# 177               RHODEY
# 178              GABRIEL
# 179               RHODEY
# 180              GABRIEL
# 181               YINSEN
# 182               YINSEN
# 183                 TONY
# 184               YINSEN
# 185                 TONY
# 186                 TONY
# 187               YINSEN
# 188                 TONY
# 189               YINSEN
# 190                 TONY
# 191               YINSEN
# 192                  ABU
# 193                 TONY
# 194               YINSEN
# 195                 TONY
# 196                 TONY
# 197               YINSEN
# 198                 TONY
# 199               YINSEN
# 200                 TONY
# 201                 TONY
# 202               YINSEN
# 203                 TONY
# 204               YINSEN
# 205                 TONY
# 206               YINSEN
# 207               YINSEN
# 208                 TONY
# 209                 TONY
# 210               YINSEN
# 211               YINSEN
# 212                 TONY
# 213               YINSEN
# 214                 TONY
# 215               YINSEN
# 216                 TONY
# 217               YINSEN
# 218                 TONY
# 219                 TONY
# 220              OBADIAH
# 221               PEPPER
# 222              OBADIAH
# 223               PEPPER
# 224               YINSEN
# 225                 TONY
# 226               YINSEN
# 227                 TONY
# 228               YINSEN
# 229                 TONY
# 230               YINSEN
# 231                 TONY
# 232               YINSEN
# 233                 TONY
# 234                 RAZA
# 235                 RAZA
# 236                 RAZA
# 237                 RAZA
# 238               YINSEN
# 239                 RAZA
# 240               YINSEN
# 241                 RAZA
# 242                 RAZA
# 243               YINSEN
# 244                 RAZA
# 245                 RAZA
# 246               YINSEN
# 247               YINSEN
# 248               YINSEN
# 249               YINSEN
# 250               YINSEN
# 251               YINSEN
# 252               YINSEN
# 253               PEPPER
# 254               RHODEY
# 255               PEPPER
# 256               PEPPER
# 257               RHODEY
# 258               PEPPER
# 259      GENERAL GABRIEL
# 260               RHODEY
# 261      GENERAL GABRIEL
# 262               RHODEY
# 263      GENERAL GABRIEL
# 264               RHODEY
# 265      GENERAL GABRIEL
# 266      GENERAL GABRIEL
# 267                 TONY
# 268               YINSEN
# 269               YINSEN
# 270                 TONY
# 271                 TONY
# 272               YINSEN
# 273                 TONY
# 274               YINSEN
# 275                 TONY
# 276               YINSEN
# 277               YINSEN
# 278                  ABU
# 279                 TONY
# 280                 RAZA
# 281                 RAZA
# 282               KHALID
# 283                 TONY
# 284               YINSEN
# 285                 TONY
# 286                 TONY
# 287               YINSEN
# 288                 TONY
# 289               YINSEN
# 290               RHODEY
# 291                 TONY
# 292               RHODEY
# 293               PEPPER
# 294                 TONY
# 295               PEPPER
# 296                HOGAN
# 297                 TONY
# 298                HOGAN
# 299                HOGAN
# 300               PEPPER
# 301                 TONY
# 302              OBADIAH
# 303              OBADIAH
# 304                 TONY
# 305               PEPPER
# 306              COULSON
# 307               PEPPER
# 308              COULSON
# 309               PEPPER
# 310              COULSON
# 311               PEPPER
# 312              COULSON
# 313               PEPPER
# 314                 TONY
# 315         REPORTER # 1
# 316                 TONY
# 317         REPORTER # 1
# 318                 TONY
# 319          REPORTER #2
# 320                 TONY
# 321               RHODEY
# 322          REPORTER #2
# 323                 TONY
# 324                 TONY
# 325          REPORTER #3
# 326                 TONY
# 327              OBADIAH
# 328               PEPPER
# 329                 TONY
# 330              OBADIAH
# 331              OBADIAH
# 332                 TONY
# 333              OBADIAH
# 334                 TONY
# 335              OBADIAH
# 336                 TONY
# 337              OBADIAH
# 338                 TONY
# 339               JARVIS
# 340                 TONY
# 341               JARVIS
# 342                 TONY
# 343               JARVIS
# 344                 TONY
# 345               JARVIS
# 346                 TONY
# 347               JARVIS
# 348                 TONY
# 349               JARVIS
# 350                 TONY
# 351               JARVIS
# 352                 TONY
# 353               JARVIS
# 354                 TONY
# 355               JARVIS
# 356                 TONY
# 357               JARVIS
# 358                 TONY
# 359               JARVIS
# 360                 TONY
# 361               JARVIS
# 362                 TONY
# 363                 RAZA
# 364               CRAMER
# 365              COULSON
# 366               PEPPER
# 367              COULSON
# 368               PEPPER
# 369              COULSON
# 370               PEPPER
# 371                 TONY
# 372              COULSON
# 373               PEPPER
# 374               PEPPER
# 375                 TONY
# 376               PEPPER
# 377                 TONY
# 378                 TONY
# 379               PEPPER
# 380                 TONY
# 381                 TONY
# 382               PEPPER
# 383                 TONY
# 384               PEPPER
# 385                 TONY
# 386               PEPPER
# 387                 TONY
# 388               PEPPER
# 389                 TONY
# 390               PEPPER
# 391                 TONY
# 392               PEPPER
# 393                 TONY
# 394               PEPPER
# 395                 TONY
# 396               PEPPER
# 397                 TONY
# 398               PEPPER
# 399                 TONY
# 400               PEPPER
# 401                 TONY
# 402               PEPPER
# 403                 TONY
# 404               PEPPER
# 405                 TONY
# 406               PEPPER
# 407                 TONY
# 408               PEPPER
# 409                 TONY
# 410               PEPPER
# 411                 TONY
# 412                 TONY
# 413               PEPPER
# 414                 TONY
# 415               PEPPER
# 416                 TONY
# 417               PEPPER
# 418                 TONY
# 419               PEPPER
# 420                 TONY
# 421               PEPPER
# 422                 TONY
# 423               PEPPER
# 424                 TONY
# 425               PEPPER
# 426                 TONY
# 427               PEPPER
# 428                 TONY
# 429                 TONY
# 430               PEPPER
# 431                 TONY
# 432               PEPPER
# 433                 TONY
# 434               PEPPER
# 435                 TONY
# 436               JARVIS
# 437                 TONY
# 438                 TONY
# 439               JARVIS
# 440                 TONY
# 441               JARVIS
# 442                 TONY
# 443               RHODEY
# 444                VOICE
# 445                 TONY
# 446               RHODEY
# 447                 TONY
# 448               RHODEY
# 449               RHODEY
# 450                 TONY
# 451               RHODEY
# 452                 TONY
# 453               RHODEY
# 454                 TONY
# 455               RHODEY
# 456                 TONY
# 457               RHODEY
# 458                 TONY
# 459               RHODEY
# 460                 TONY
# 461               RHODEY
# 462                 TONY
# 463               PEPPER
# 464                 TONY
# 465               PEPPER
# 466                 TONY
# 467                 TONY
# 468              OBADIAH
# 469                 TONY
# 470              OBADIAH
# 471                 TONY
# 472              OBADIAH
# 473                 TONY
# 474              OBADIAH
# 475                 TONY
# 476              OBADIAH
# 477                 TONY
# 478              OBADIAH
# 479              OBADIAH
# 480              OBADIAH
# 481                 TONY
# 482                 TONY
# 483                 TONY
# 484                 TONY
# 485                 TONY
# 486               JARVIS
# 487                 TONY
# 488               JARVIS
# 489                 TONY
# 490               JARVIS
# 491                 TONY
# 492               JARVIS
# 493                 TONY
# 494               JARVIS
# 495               JARVIS
# 496               JARVIS
# 497                 TONY
# 498                 TONY
# 499               JARVIS
# 500                 TONY
# 501               JARVIS
# 502                 TONY
# 503               JARVIS
# 504                 TONY
# 505                 TONY
# 506               JARVIS
# 507                 TONY
# 508               JARVIS
# 509                 TONY
# 510               JARVIS
# 511                 TONY
# 512                 TONY
# 513                 TONY
# 514             REPORTER
# 515             REPORTER
# 516               JARVIS
# 517                 TONY
# 518                 TONY
# 519                 TONY
# 520              OBADIAH
# 521                 TONY
# 522              OBADIAH
# 523                 TONY
# 524                 TONY
# 525                  MAN
# 526              COULSON
# 527                 TONY
# 528              COULSON
# 529                 TONY
# 530                 TONY
# 531               PEPPER
# 532                 TONY
# 533                 TONY
# 534               PEPPER
# 535                 TONY
# 536               PEPPER
# 537                 TONY
# 538               PEPPER
# 539                 TONY
# 540               PEPPER
# 541               PEPPER
# 542                 TONY
# 543               PEPPER
# 544                 TONY
# 545               PEPPER
# 546               PEPPER
# 547                 TONY
# 548            CHRISTINE
# 549                 TONY
# 550            CHRISTINE
# 551                 TONY
# 552            CHRISTINE
# 553                 TONY
# 554            CHRISTINE
# 555                 TONY
# 556            CHRISTINE
# 557                 TONY
# 558                 TONY
# 559              OBADIAH
# 560                 TONY
# 561              OBADIAH
# 562                 TONY
# 563              OBADIAH
# 564              OBADIAH
# 565              OBADIAH
# 566                 TONY
# 567              OBADIAH
# 568                 TONY
# 569              OBADIAH
# 570                 TONY
# 571              OBADIAH
# 572              OBADIAH
# 573                 TONY
# 574  TV REPORTER’S VOICE
# 575  TV REPORTER’S VOICE
# 576  TV REPORTER’S VOICE
# 577               PEPPER
# 578                 TONY
# 579               PEPPER
# 580               TYCOON
# 581                 TONY
# 582               PEPPER
# 583                 TONY
# 584      DUBAI BEAUTY #1
# 585               PEPPER
# 586                 TONY
# 587                  KID
# 588              SOLDIER
# 589          MAJOR ALLEN
# 590              OFFICER
# 591          MAJOR ALLEN
# 592              OFFICER
# 593          MAJOR ALLEN
# 594                 RAZA
# 595                 TONY
# 596          MAJOR ALLEN
# 597               RHODEY
# 598          MAJOR ALLEN
# 599               RHODEY
# 600                 TONY
# 601               RHODEY
# 602                 TONY
# 603               RHODEY
# 604                 TONY
# 605              OFFICER
# 606               RHODEY
# 607          MAJOR ALLEN
# 608                 TONY
# 609                 TONY
# 610              VIPER 1
# 611          MAJOR ALLEN
# 612              VIPER 1
# 613          MAJOR ALLEN
# 614       BITCHING-BETTY
# 615               JARVIS
# 616               JARVIS
# 617                 TONY
# 618              VIPER 1
# 619              VIPER 2
# 620              OFFICER
# 621               RHODEY
# 622                 TONY
# 623               RHODEY
# 624              VIPER 1
# 625              VIPER 2
# 626              VIPER 1
# 627          MAJOR ALLEN
# 628              VIPER 1
# 629               RHODEY
# 630              VIPER 1
# 631               JARVIS
# 632              VIPER 1
# 633          MAJOR ALLEN
# 634              VIPER 2
# 635               JARVIS
# 636              VIPER 2
# 637              VIPER 2
# 638          MAJOR ALLEN
# 639               RHODEY
# 640          MAJOR ALLEN
# 641               RHODEY
# 642          MAJOR ALLEN
# 643       BITCHING-BETTY
# 644              VIPER 2
# 645          MAJOR ALLEN
# 646               RHODEY
# 647          MAJOR ALLEN
# 648          MAJOR ALLEN
# 649              VIPER 2
# 650                 TONY
# 651                 RAZA
# 652                 RAZA
# 653              OBADIAH
# 654                 RAZA
# 655              OBADIAH
# 656                 RAZA
# 657                 RAZA
# 658              OBADIAH
# 659                 RAZA
# 660              OBADIAH
# 661                 RAZA
# 662                 RAZA
# 663                 RAZA
# 664                 RAZA
# 665              OBADIAH
# 666              OBADIAH
# 667              OBADIAH
# 668              OBADIAH
# 669              COULSON
# 670               PEPPER
# 671              COULSON
# 672               PEPPER
# 673              COULSON
# 674               PEPPER
# 675              COULSON
# 676               PEPPER
# 677               RHODEY
# 678               PEPPER
# 679              COULSON
# 680               PEPPER
# 681              COULSON
# 682               PEPPER
# 683               RHODEY
# 684               PEPPER
# 685               RHODEY
# 686               PEPPER
# 687               RHODEY
# 688               PEPPER
# 689               RHODEY
# 690                 TONY
# 691               RHODEY
# 692                 TONY
# 693               RHODEY
# 694                 TONY
# 695               RHODEY
# 696               RHODEY
# 697                 TONY
# 698               RHODEY
# 699                 TONY
# 700              OBADIAH
# 701        HEAD ENGINEER
# 702              OBADIAH
# 703               YINSEN
# 704                 TONY
# 705               PEPPER
# 706                 TONY
# 707               PEPPER
# 708                 TONY
# 709               PEPPER
# 710                 TONY
# 711               PEPPER
# 712                 TONY
# 713        HEAD ENGINEER
# 714              OBADIAH
# 715        HEAD ENGINEER
# 716              OBADIAH
# 717        HEAD ENGINEER
# 718               PEPPER
# 719               PEPPER
# 720               PEPPER
# 721              OBADIAH
# 722               PEPPER
# 723              OBADIAH
# 724               PEPPER
# 725              OBADIAH
# 726               PEPPER
# 727              OBADIAH
# 728               PEPPER
# 729              OBADIAH
# 730              OBADIAH
# 731              OBADIAH
# 732              OBADIAH
# 733               PEPPER
# 734              OBADIAH
# 735              COULSON
# 736               PEPPER
# 737                 TONY
# 738               JARVIS
# 739              OBADIAH
# 740              OBADIAH
# 741               JARVIS
# 742              OBADIAH
# 743                 TONY
# 744                 TONY
# 745              OBADIAH
# 746                 TONY
# 747              OBADIAH
# 748              OBADIAH
# 749              OBADIAH
# 750              OBADIAH
# 751              OBADIAH
# 752              OBADIAH
# 753              OBADIAH
# 754               RHODEY
# 755               PEPPER
# 756               PEPPER
# 757              COULSON
# 758                AGENT
# 759               RHODEY
# 760                 TONY
# 761               RHODEY
# 762                 TONY
# 763                AGENT
# 764               PEPPER
# 765                 TONY
# 766               PEPPER
# 767               PEPPER
# 768                 TONY
# 769              OBADIAH
# 770                 TONY
# 771              OBADIAH
# 772                 TONY
# 773              OBADIAH
# 774               PEPPER
# 775                 TONY
# 776               PEPPER
# 777                 TONY
# 778               PEPPER
# 779                 TONY
# 780              OBADIAH
# 781                 TONY
# 782               JARVIS
# 783                 TONY
# 784  KID IN THE BACKSEAT
# 785               PEPPER
# 786               PEPPER
# 787                 TONY
# 788               PEPPER
# 789                 TONY
# 790               PEPPER
# 791                 TONY
# 792               PEPPER
# 793                 TONY
# 794                 TONY
# 795              OBADIAH
# 796                 TONY
# 797               RHODEY
# 798                 TONY
# 799                 TONY
# 800               PEPPER
# 801                 TONY
# 802               PEPPER
# 803                 TONY
# 804                 TONY
# 805               PEPPER
# 806                 TONY
# 807               PEPPER
# 808                 TONY
# 809               PEPPER
# 810                 TONY
# 811                 TONY
# 812               PEPPER
# 813               PEPPER
# 814                 TONY
# 815              OBADIAH
# 816                 TONY
# 817              OBADIAH
# 818              OBADIAH
# 819                 TONY
# 820               PEPPER
# 821                 TONY
# 822               PEPPER
# 823                 TONY
# 824                 TONY
# 825               PEPPER
# 826               PEPPER
# 827                 TONY
# 828               RHODEY
# 829                 TONY
# 830                 TONY
# 831               RHODEY
# 832                 TONY
# 833               RHODEY
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       line
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Oh, I get it.  You guys aren’t allowed to talk.  Is that it?  Are you not allowed to talk?
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              No.  We’re allowed to talk.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Oh.  I see.  So it’s personal.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             I think they’re intimidated.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Good God, you’re a woman.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    I, honestly, I couldn’t have called that. I would apologize, but isn’t that what we’re going for here? I saw you as a soldier first.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 I have a question, sir.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Please.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Is it true you’re twelve for twelve with last years Maxim cover girls?
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                Excellent question. Yes and no. March and I had a schedule conflict but, thankfully, the Christmas cover was twins.  Anyone else? You, with the hand up.
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             It’s a little embarrassing.
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Join the club.
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Can I take a picture with you?
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Are you aware that Native Americans believe photographs steal a little piece of your soul?  Not to worry, mine’s long gone. Fire away.
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              STAY HERE!
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             GET DOWN, TONY.  GET THE --
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                       December 7, 1941: the day the world changed forever. President Roosevelt declares the United States will build fifty thousand planes to fight the armies of Hirohito and Hitler--
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Although no such capacity to build existed...
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Howard Stark, founder of the fledgling Stark Industries, answers his call to duty --
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    And builds not fifty, but a hundred thousand planes.
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Later, Stark’s work on the Manhattan project makes the end of the war possible.
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Stark Industries would go on to contribute to every major weapons system through the Cold War --
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            But Howard Stark’s greatest achievement would come in 1973--
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         From early on, it was clear that Tony Stark had a unique gift--
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         At seventeen he graduated summa cum laude from MIT.  Four years later, tragedy would pass the Stark mantle from father to son--
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 The loss of a titan.  But Tony did not let personal grief distract him from his duty --
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             At twenty-one, he became the youngest-ever CEO of a Fortune 500 company.  And with it came a new mandate --
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Smarter weapons, fewer casualties. A dedication to preserving life.
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Today Tony Stark’s ingenuity continues to protect freedom and American interest around the globe.
# 29                                                                                                                                                                                                                                                   As Program Manager and Liaison to Stark Industries, I’ve had the honor of serving with a real patriot, a man whose life has been dedicated to protecting our troops on the front lines.  He’s a friend. And a great mentor.  A man who has always been there for his friends and his country.  Ladies and gentlemen, this year’s ARES Award winner -- Mr. Tony Stark.
# 30                                                                                                                                                                                                                                                                                                                                                                                                      Thank you...I, uhhh, I’m not Tony Stark, but if I were Tony, I’d tell you how honored I am and...what a joy it is to receive this award. The best thing about Tony is also the worst thing -- he’s always working.
# 31                                                                                                                                                                                                                                                                                                                      ...you think we’re having a ‘moment’ here, but this is actually the logical conclusion of several mathematical truisms. Your hypothalamus is flooding your system with a chain of proteins called peptides, so that every cell in your body is opening itself up to the happy chemical: oxytocin.
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        That’s...wow....
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Hold on a second --
# 34                                                                                                                                                                                                                                                                                                                                                 -- so now your limbic system is positively...throbbing.  A Kirlian photograph of us right now, occupying this space, would show serious subatomic particles being exchanged between us, with a rapidity that transcends-- Are you getting this?  You will be quizzed --
# ...
# 808                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    See a red submarine hatch?  A wheel -- a red wheel.
# 809                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...no.  YES --
# 810                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Open it all the way, then standby to hit the master.  We’ve only got one shot at this.
# 811                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Pepper, hit the switch.  PEPPER --
# 812                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          TONY?  Which Master Switch --
# 813                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       I am so looking for another job.
# 814                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Take my hand...
# 815                                                                                                                                                                                                                                                                                                                                                                                                                       So this is the answer, Tony?  This is how you’re going to save the world?  It’s not in you.  Your father told me before he died, my boy doesn’t have a warrior’s heart. I should have listened.
# 816                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               My father never knew me.
# 817                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              But I do.
# 818                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Goodbye, my boy...
# 819                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is just the beginning.
# 820                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Here, your alibi.  You were on your yacht.  I’ve got port papers that put you in Avalon all night, and sworn statements from fifty of your guests.
# 821                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Maybe it was just the two of us. On the yacht, I mean.
# 822                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Focus, please.
# 823                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         “Iron Man”.  Not technically accurate, since it’s mostly carbon- fiber and ceramic.  But I like the ring of it.  “Iron Man”...
# 824                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                You know...that night at the concert hall.  Do you ever think about it?
# 825                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     I don’t know what you’re talking about, Mr. Stark.
# 826                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Will that be all, Mr. Stark?
# 827                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           That will be all Miss Potts.
# 828                                                                                                                                                                                                                                        --I can confirm that a series of military test-prototypes were involved in the incident at Stark Industries last night.  I can also confirm that there was, for a brief time, the danger of an Ark Reactor “incident”, which was rectified without injury to the public -- and all power outages have been restored.  Here now, to answer a few brief questions, is Tony Stark.
# 829                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          I’ve seen the papers.  I’ve heard the reports.  That’s why I want to put an end to all this wild speculation.  The truth is--
# 830                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         I am Iron Man.
# 831                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Good.  And I want a Gatling gun on the right shoulder.
# 832                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      --and a rocket launcher on the left?  Where are you going to store all that ammo?
# 833                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Who’s suit is this anyway? And do it in silver and black, would you?
